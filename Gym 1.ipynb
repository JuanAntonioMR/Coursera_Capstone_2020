# %%
import requests #Biblioteca para manejar solicitudes
import pandas as pd #Biblioteca para Análisis de datos
import numpy as np #Biblioteca para manejar datos de una manera vectorizada
import random #Biblioteca para la generación de números aleatorios

# !pip install geopy
from geopy.geocoders import Nominatim #Módulo para convertir una dirección en valores de latitud y longitud

#Bibliotecas para mostrar imágenes

from IPython.display import Image
from IPython.core.display import HTML

#Transformar un archivo JSON en una biblioteca de marco de datos de pandas
from pandas.io.json import json_normalize

! pip install folium==0.5.0
import folium #Biblioteca de representación

print("Folium installed")
print("Libraries imported")
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.50)
# Collecting folium==0.5.0
# Requirement already satisfied: branca in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (0.4.1)
# Requirement already satisfied: jinja2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (3.0.4)
# Installing collected packages: folium
#   Found existing installation: folium 0.11.0
#     Uninstalling folium-0.11.0:
#       Successfully uninstalled folium-0.11.0
# Successfully installed folium-0.5.0
# Folium installed
# Libraries imported

# %%
CLIENT_ID= "VYXHEB1JFDKLQWKXQVDHVO0BIK5COTAA00QDMGTTZSE0GQPI" #Tu ID de Foursquare
CLIENT_SECRET= "5KJIO12I3YHGWNTTX2MFS011R0V2VHRRE5N1CTRPEHYLDZOX" #Tu Foursquare secreto
VERSION="20180604 "
LIMIT=30
print("Your credentials:")
print("CLIENT_ID: " + CLIENT_ID)
print("CLIENT_SECRET:" + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: VYXHEB1JFDKLQWKXQVDHVO0BIK5COTAA00QDMGTTZSE0GQPI
# CLIENT_SECRET:5KJIO12I3YHGWNTTX2MFS011R0V2VHRRE5N1CTRPEHYLDZOX

# %%
#Vamos a trabajar con un Hotel llamado "The Roosevelt
#Hotel" que está en Nueva York, ubicado en Manhattan""
Dirección="East 45th st, New York, NY 10017, Estados Unidos"

geolocator =Nominatim(user_agent="foursquare_agent")
location=geolocator.geocode(Dirección)
latitude=location.latitude
longitude=location.longitude
print(latitude, longitude)
# Out:
# 40.7553525 -73.9793583

# %%
#Ahora vamos a definir la consulta para buscar comida japonesa, que se encuentre a 
#700 metros de "The Roosevelt Hotel".

search_query="Gym"
radius=700
print(search_query + ".... OK!")
# Out:
# Gym.... OK!

# %%
#Ahora definimos la correspondiente URL:

url= "https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}".format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=VYXHEB1JFDKLQWKXQVDHVO0BIK5COTAA00QDMGTTZSE0GQPI&client_secret=5KJIO12I3YHGWNTTX2MFS011R0V2VHRRE5N1CTRPEHYLDZOX&ll=40.7553525,-73.9793583&v=20180604 &query=Gym&radius=700&limit=30'

# %%
#Realizamos la solicitud de la url
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fc0808f72ff4663200f38a9'},
#  'response': {'venues': [{'id': '4ddadabf45dd588c72142bfb',
#     'name': 'Gym',
#     'location': {'lat': 40.75417222203689,
#      'lng': -73.9824146711259,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75417222203689,
#        'lng': -73.9824146711259}],
#      'distance': 289,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '4b18ff63f964a52004d723e3',
#     'name': 'The Gym at The Atlas',
#     'location': {'address': '66 W 38th St Fl 5',
#      'crossStreet': '6th Ave',
#      'lat': 40.751910352973866,
#      'lng': -73.9858935506665,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.751910352973866,
#        'lng': -73.9858935506665}],
#      'distance': 671,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['66 W 38th St Fl 5 (6th Ave)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '55a053b3498ee841ba348ecf',
#     'name': 'Ares Gym',
#     'location': {'address': '245 Park Ave',
#      'lat': 40.75473000726001,
#      'lng': -73.97473551696459,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75473000726001,
#        'lng': -73.97473551696459},
#       {'label': 'entrance', 'lat': 40.754851, 'lng': -73.97526}],
#      'distance': 395,
#      'postalCode': '10167',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['245 Park Ave',
#       'New York, NY 10167',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '4c578880d12a20a1fe1c67bd',
#     'name': 'W Hotel - Bliss Gym',
#     'location': {'address': '541 Lexington Ave',
#      'lat': 40.756304661511344,
#      'lng': -73.9723997271646,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.756304661511344,
#        'lng': -73.9723997271646}],
#      'distance': 596,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['541 Lexington Ave',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '5c053dce9411f2002c61226f',
#     'name': 'AKA Gym',
#     'location': {'address': '234',
#      'crossStreet': '46th Street',
#      'lat': 40.75257,
#      'lng': -73.971311,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75257,
#        'lng': -73.971311}],
#      'distance': 745,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['234 (46th Street)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '4fb38597e4b0b3ec72a82e98',
#     'name': 'The Gym At Andaz',
#     'location': {'lat': 40.752851884303766,
#      'lng': -73.98112335499499,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752851884303766,
#        'lng': -73.98112335499499}],
#      'distance': 315,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10036', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '51792893e4b09b29cfdb3b86',
#     'name': 'Gym@Club Quarters',
#     'location': {'lat': 40.75577220620581,
#      'lng': -73.98125535659763,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75577220620581,
#        'lng': -73.98125535659763}],
#      'distance': 166,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '526d137811d286493dc20b3a',
#     'name': 'Gym at the Mansfield',
#     'location': {'lat': 40.75498580932617,
#      'lng': -73.98172760009766,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75498580932617,
#        'lng': -73.98172760009766}],
#      'distance': 203,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '565738a2498e51f6dc82c731',
#     'name': '325 Lexington Avenue Gym',
#     'location': {'lat': 40.74931156116212,
#      'lng': -73.97709139346767,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74931156116212,
#        'lng': -73.97709139346767}],
#      'distance': 699,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '568a7cfc498e2cdedb4d2240',
#     'name': 'a gym',
#     'location': {'lat': 40.753692,
#      'lng': -73.98106,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.753692,
#        'lng': -73.98106}],
#      'distance': 234,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '4c082754009a0f47dba8e5bf',
#     'name': 'Harvard Club Gym',
#     'location': {'address': '27 W 44th St',
#      'crossStreet': 'At 5th',
#      'lat': 40.75561518484979,
#      'lng': -73.9815676208818,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75561518484979,
#        'lng': -73.9815676208818}],
#      'distance': 188,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['27 W 44th St (At 5th)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '4f859771e4b0a7ed05baf933',
#     'name': 'Gym @ White & Case LLP',
#     'location': {'lat': 40.75633597805604,
#      'lng': -73.98290249940592,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75633597805604,
#        'lng': -73.98290249940592}],
#      'distance': 318,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10036', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '4d99e1eed1bca09075a476b4',
#     'name': 'Yale Club Gym',
#     'location': {'address': '50 Vanderbilt Ave',
#      'crossStreet': 'at 44th St.',
#      'lat': 40.75400533056944,
#      'lng': -73.97748908850008,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75400533056944,
#        'lng': -73.97748908850008},
#       {'label': 'entrance', 'lat': 40.753958, 'lng': -73.977376}],
#      'distance': 217,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['50 Vanderbilt Ave (at 44th St.)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '51b7132d498ec7411466d22f',
#     'name': 'Centria Gym',
#     'location': {'address': '18 W 48th St',
#      'lat': 40.75791960653682,
#      'lng': -73.97917009561398,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75791960653682,
#        'lng': -73.97917009561398}],
#      'distance': 286,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['18 W 48th St',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '4cae3b1175ebb60cfca6b2ad',
#     'name': 'Gym @ Millenium Broadway Hotel',
#     'location': {'address': '144 W 44th St.',
#      'lat': 40.756595611572266,
#      'lng': -73.98501586914062,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.756595611572266,
#        'lng': -73.98501586914062}],
#      'distance': 496,
#      'postalCode': '10036-4012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['144 W 44th St.',
#       'New York, NY 10036-4012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '5c5b0e49396de0003912ac4d',
#     'name': 'Gym at The Lexington Hotel',
#     'location': {'lat': 40.754883,
#      'lng': -73.973658,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.754883,
#        'lng': -73.973658}],
#      'distance': 483,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10017', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '5a500e9f1987ec2748b64bb2',
#     'name': 'Gym At 34 E. 51st St.',
#     'location': {'address': '34 E 51st St',
#      'lat': 40.757971,
#      'lng': -73.974404,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.757971,
#        'lng': -73.974404}],
#      'distance': 509,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['34 E 51st St',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '5b93f55d5455b2002c8e411b',
#     'name': 'The Somerset Gym',
#     'location': {'lat': 40.758453,
#      'lng': -73.98344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.758453,
#        'lng': -73.98344}],
#      'distance': 487,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10036', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '507cb748e4b06a750c8aa3d7',
#     'name': 'My Fitness (Bank Of America Tower Gym)',
#     'location': {'address': '1 Bryant Park',
#      'lat': 40.754968059898005,
#      'lng': -73.98419337527665,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.754968059898005,
#        'lng': -73.98419337527665}],
#      'distance': 409,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 Bryant Park',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '5b1c3f22eaf49a002c7da96a',
#     'name': 'Face Gym',
#     'location': {'address': '611 5th Ave',
#      'lat': 40.758026,
#      'lng': -73.977261,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.758026,
#        'lng': -73.977261}],
#      'distance': 346,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['611 5th Ave',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '54541900498ea6ccd0202697',
#       'name': 'Health & Beauty Service',
#       'pluralName': 'Health & Beauty Services',
#       'shortName': 'Health & Beauty',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '53f3851c498e1cd3c3fa507b',
#     'name': 'gym source',
#     'location': {'address': '40E 52nd Street',
#      'crossStreet': 'Bet Park & Madison',
#      'lat': 40.758185650749226,
#      'lng': -73.97344988870044,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.758185650749226,
#        'lng': -73.97344988870044}],
#      'distance': 589,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['40E 52nd Street (Bet Park & Madison)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '56d82ff7cd10b0a0be638b76',
#     'name': 'Gym @ The Refinery',
#     'location': {'address': '63 W 38th St',
#      'crossStreet': '6th Ave',
#      'lat': 40.752357482910156,
#      'lng': -73.98515319824219,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752357482910156,
#        'lng': -73.98515319824219}],
#      'distance': 591,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['63 W 38th St (6th Ave)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '4ca0ecff542b224b7a3c0aa0',
#     'name': 'Morgan Stanley Gym',
#     'location': {'address': '1585 Broadway',
#      'lat': 40.75985207317243,
#      'lng': -73.98507102126582,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75985207317243,
#        'lng': -73.98507102126582}],
#      'distance': 694,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1585 Broadway',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '50f42c60e4b0dd739c764ea4',
#     'name': 'Trump World Tower Gym',
#     'location': {'lat': 40.75236243536285,
#      'lng': -73.97612444499029,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75236243536285,
#        'lng': -73.97612444499029}],
#      'distance': 430,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10017', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '4f452e9ce4b08406aaabb1ff',
#     'name': '445 5th Avenue Gym',
#     'location': {'address': '445 5th Ave',
#      'crossStreet': '39th St.',
#      'lat': 40.751590728759766,
#      'lng': -73.98175048828125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.751590728759766,
#        'lng': -73.98175048828125}],
#      'distance': 464,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['445 5th Ave (39th St.)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '5237b1ed11d24eb362ab1986',
#     'name': 'Gym At The Double Tree',
#     'location': {'address': '569 Lexington Ave',
#      'crossStreet': '51st Street',
#      'lat': 40.75665283203125,
#      'lng': -73.97158813476562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75665283203125,
#        'lng': -73.97158813476562}],
#      'distance': 671,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['569 Lexington Ave (51st Street)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '4f0cd2a4e4b023b3783d81e5',
#     'name': 'The Muse Gym',
#     'location': {'lat': 40.758110999808075,
#      'lng': -73.98363710906709,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.758110999808075,
#        'lng': -73.98363710906709}],
#      'distance': 473,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10036', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '4b465348f964a520ac1d26e3',
#     'name': 'Gym Source',
#     'location': {'address': '40e 52nd street',
#      'lat': 40.75887368444871,
#      'lng': -73.97254305645629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75887368444871,
#        'lng': -73.97254305645629}],
#      'distance': 695,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['40e 52nd street',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1b2941735',
#       'name': 'College Gym',
#       'pluralName': 'College Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '4e03351ed164b56ad5332dc5',
#     'name': 'Greenhill Gym',
#     'location': {'address': '300 Park Ave',
#      'crossStreet': '50th Street',
#      'lat': 40.757045,
#      'lng': -73.974711,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.757045,
#        'lng': -73.974711}],
#      'distance': 434,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['300 Park Ave (50th Street)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False},
#    {'id': '532754da498e973892dc0be8',
#     'name': 'Hyatt Stay Fit Gym',
#     'location': {'address': '135 W 45th St',
#      'lat': 40.757545471191406,
#      'lng': -73.9840316772461,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.757545471191406,
#        'lng': -73.9840316772461}],
#      'distance': 463,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['135 W 45th St',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606451343',
#     'hasPerk': False}]}}

# %%
#Asigna la parte relevante de JSON a lugares
venues=results["response"]["venues"]

# %%
#Transforma los lugares en un marco de datos

dataframe=pd.json_normalize(venues)
dataframe.head(30)
# Out:
#                           id                                    name  \
# 0   4ddadabf45dd588c72142bfb                                     Gym
# 1   4b18ff63f964a52004d723e3                    The Gym at The Atlas
# 2   55a053b3498ee841ba348ecf                                Ares Gym
# 3   4c578880d12a20a1fe1c67bd                     W Hotel - Bliss Gym
# 4   5c053dce9411f2002c61226f                                 AKA Gym
# 5   4fb38597e4b0b3ec72a82e98                        The Gym At Andaz
# 6   51792893e4b09b29cfdb3b86                       Gym@Club Quarters
# 7   526d137811d286493dc20b3a                    Gym at the Mansfield
# 8   565738a2498e51f6dc82c731                325 Lexington Avenue Gym
# 9   568a7cfc498e2cdedb4d2240                                   a gym
# 10  4c082754009a0f47dba8e5bf                        Harvard Club Gym
# 11  4f859771e4b0a7ed05baf933                  Gym @ White & Case LLP
# 12  4d99e1eed1bca09075a476b4                           Yale Club Gym
# 13  51b7132d498ec7411466d22f                             Centria Gym
# 14  4cae3b1175ebb60cfca6b2ad          Gym @ Millenium Broadway Hotel
# 15  5c5b0e49396de0003912ac4d              Gym at The Lexington Hotel
# 16  5a500e9f1987ec2748b64bb2                   Gym At 34 E. 51st St.
# 17  5b93f55d5455b2002c8e411b                        The Somerset Gym
# 18  507cb748e4b06a750c8aa3d7  My Fitness (Bank Of America Tower Gym)
# 19  5b1c3f22eaf49a002c7da96a                                Face Gym
# 20  53f3851c498e1cd3c3fa507b                              gym source
# 21  56d82ff7cd10b0a0be638b76                      Gym @ The Refinery
# 22  4ca0ecff542b224b7a3c0aa0                      Morgan Stanley Gym
# 23  50f42c60e4b0dd739c764ea4                   Trump World Tower Gym
# 24  4f452e9ce4b08406aaabb1ff                      445 5th Avenue Gym
# 25  5237b1ed11d24eb362ab1986                  Gym At The Double Tree
# 26  4f0cd2a4e4b023b3783d81e5                            The Muse Gym
# 27  4b465348f964a520ac1d26e3                              Gym Source
# 28  4e03351ed164b56ad5332dc5                           Greenhill Gym
# 29  532754da498e973892dc0be8                      Hyatt Stay Fit Gym
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 1   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 2   [{'id': '4bf58dd8d48988d130941735', 'name': 'B...  v-1606451343    False
# 3   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 4   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 5   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 6   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 7   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 8   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 9   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 10  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 11  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 12  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 13  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1606451343    False
# 14  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 15  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1606451343    False
# 16  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1606451343    False
# 17  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 18  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1606451343    False
# 19  [{'id': '54541900498ea6ccd0202697', 'name': 'H...  v-1606451343    False
# 20  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 21  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 22  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 23  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 24  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 25  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1606451343    False
# 26  [{'id': '4bf58dd8d48988d132951735', 'name': 'H...  v-1606451343    False
# 27  [{'id': '4bf58dd8d48988d1b2941735', 'name': 'C...  v-1606451343    False
# 28  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
# 29  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606451343    False
#
#     location.lat  location.lng  \
# 0      40.754172    -73.982415
# 1      40.751910    -73.985894
# 2      40.754730    -73.974736
# 3      40.756305    -73.972400
# 4      40.752570    -73.971311
# 5      40.752852    -73.981123
# 6      40.755772    -73.981255
# 7      40.754986    -73.981728
# 8      40.749312    -73.977091
# 9      40.753692    -73.981060
# 10     40.755615    -73.981568
# 11     40.756336    -73.982902
# 12     40.754005    -73.977489
# 13     40.757920    -73.979170
# 14     40.756596    -73.985016
# 15     40.754883    -73.973658
# 16     40.757971    -73.974404
# 17     40.758453    -73.983440
# 18     40.754968    -73.984193
# 19     40.758026    -73.977261
# 20     40.758186    -73.973450
# 21     40.752357    -73.985153
# 22     40.759852    -73.985071
# 23     40.752362    -73.976124
# 24     40.751591    -73.981750
# 25     40.756653    -73.971588
# 26     40.758111    -73.983637
# 27     40.758874    -73.972543
# 28     40.757045    -73.974711
# 29     40.757545    -73.984032
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 40.75417222203689...                289
# 1   [{'label': 'display', 'lat': 40.75191035297386...                671
# 2   [{'label': 'display', 'lat': 40.75473000726001...                395
# 3   [{'label': 'display', 'lat': 40.75630466151134...                596
# 4   [{'label': 'display', 'lat': 40.75257, 'lng': ...                745
# 5   [{'label': 'display', 'lat': 40.75285188430376...                315
# 6   [{'label': 'display', 'lat': 40.75577220620581...                166
# 7   [{'label': 'display', 'lat': 40.75498580932617...                203
# 8   [{'label': 'display', 'lat': 40.74931156116212...                699
# 9   [{'label': 'display', 'lat': 40.753692, 'lng':...                234
# 10  [{'label': 'display', 'lat': 40.75561518484979...                188
# 11  [{'label': 'display', 'lat': 40.75633597805604...                318
# 12  [{'label': 'display', 'lat': 40.75400533056944...                217
# 13  [{'label': 'display', 'lat': 40.75791960653682...                286
# 14  [{'label': 'display', 'lat': 40.75659561157226...                496
# 15  [{'label': 'display', 'lat': 40.754883, 'lng':...                483
# 16  [{'label': 'display', 'lat': 40.757971, 'lng':...                509
# 17  [{'label': 'display', 'lat': 40.758453, 'lng':...                487
# 18  [{'label': 'display', 'lat': 40.75496805989800...                409
# 19  [{'label': 'display', 'lat': 40.758026, 'lng':...                346
# 20  [{'label': 'display', 'lat': 40.75818565074922...                589
# 21  [{'label': 'display', 'lat': 40.75235748291015...                591
# 22  [{'label': 'display', 'lat': 40.75985207317243...                694
# 23  [{'label': 'display', 'lat': 40.75236243536285...                430
# 24  [{'label': 'display', 'lat': 40.75159072875976...                464
# 25  [{'label': 'display', 'lat': 40.75665283203125...                671
# 26  [{'label': 'display', 'lat': 40.75811099980807...                473
# 27  [{'label': 'display', 'lat': 40.75887368444871...                695
# 28  [{'label': 'display', 'lat': 40.757045, 'lng':...                434
# 29  [{'label': 'display', 'lat': 40.75754547119140...                463
#
#    location.cc location.city location.state location.country  \
# 0           US      New York             NY    United States
# 1           US      New York             NY    United States
# 2           US      New York             NY    United States
# 3           US      New York             NY    United States
# 4           US      New York             NY    United States
# 5           US      New York             NY    United States
# 6           US      New York             NY    United States
# 7           US      New York             NY    United States
# 8           US      New York             NY    United States
# 9           US      New York             NY    United States
# 10          US      New York             NY    United States
# 11          US      New York             NY    United States
# 12          US      New York             NY    United States
# 13          US      New York             NY    United States
# 14          US      New York             NY    United States
# 15          US      New York             NY    United States
# 16          US      New York             NY    United States
# 17          US      New York             NY    United States
# 18          US      New York             NY    United States
# 19          US      New York             NY    United States
# 20          US      New York             NY    United States
# 21          US      New York             NY    United States
# 22          US      New York             NY    United States
# 23          US      New York             NY    United States
# 24          US      New York             NY    United States
# 25          US      New York             NY    United States
# 26          US      New York             NY    United States
# 27          US      New York             NY    United States
# 28          US      New York             NY    United States
# 29          US      New York             NY    United States
#
#                             location.formattedAddress   location.address  \
# 0                       [New York, NY, United States]                NaN
# 1   [66 W 38th St Fl 5 (6th Ave), New York, NY 100...  66 W 38th St Fl 5
# 2   [245 Park Ave, New York, NY 10167, United States]       245 Park Ave
# 3   [541 Lexington Ave, New York, NY 10022, United...  541 Lexington Ave
# 4   [234 (46th Street), New York, NY 10017, United...                234
# 5                 [New York, NY 10036, United States]                NaN
# 6                       [New York, NY, United States]                NaN
# 7                       [New York, NY, United States]                NaN
# 8                       [New York, NY, United States]                NaN
# 9                       [New York, NY, United States]                NaN
# 10  [27 W 44th St (At 5th), New York, NY 10036, Un...       27 W 44th St
# 11                [New York, NY 10036, United States]                NaN
# 12  [50 Vanderbilt Ave (at 44th St.), New York, NY...  50 Vanderbilt Ave
# 13  [18 W 48th St, New York, NY 10036, United States]       18 W 48th St
# 14  [144 W 44th St., New York, NY 10036-4012, Unit...     144 W 44th St.
# 15                [New York, NY 10017, United States]                NaN
# 16  [34 E 51st St, New York, NY 10022, United States]       34 E 51st St
# 17                [New York, NY 10036, United States]                NaN
# 18  [1 Bryant Park, New York, NY 10036, United Sta...      1 Bryant Park
# 19   [611 5th Ave, New York, NY 10022, United States]        611 5th Ave
# 20  [40E 52nd Street (Bet Park & Madison), New Yor...    40E 52nd Street
# 21  [63 W 38th St (6th Ave), New York, NY 10018, U...       63 W 38th St
# 22  [1585 Broadway, New York, NY 10019, United Sta...      1585 Broadway
# 23                [New York, NY 10017, United States]                NaN
# 24  [445 5th Ave (39th St.), New York, NY 10016, U...        445 5th Ave
# 25  [569 Lexington Ave (51st Street), New York, NY...  569 Lexington Ave
# 26                [New York, NY 10036, United States]                NaN
# 27  [40e 52nd street, New York, NY 10022, United S...    40e 52nd street
# 28  [300 Park Ave (50th Street), New York, NY 1002...       300 Park Ave
# 29  [135 W 45th St, New York, NY 10036, United Sta...      135 W 45th St
#
#    location.crossStreet location.postalCode
# 0                   NaN                 NaN
# 1               6th Ave               10018
# 2                   NaN               10167
# 3                   NaN               10022
# 4           46th Street               10017
# 5                   NaN               10036
# 6                   NaN                 NaN
# 7                   NaN                 NaN
# 8                   NaN                 NaN
# 9                   NaN                 NaN
# 10               At 5th               10036
# 11                  NaN               10036
# 12          at 44th St.               10017
# 13                  NaN               10036
# 14                  NaN          10036-4012
# 15                  NaN               10017
# 16                  NaN               10022
# 17                  NaN               10036
# 18                  NaN               10036
# 19                  NaN               10022
# 20   Bet Park & Madison               10022
# 21              6th Ave               10018
# 22                  NaN               10019
# 23                  NaN               10017
# 24             39th St.               10016
# 25          51st Street               10022
# 26                  NaN               10036
# 27                  NaN               10022
# 28          50th Street               10022
# 29                  NaN               10036

# %%
#Mantén solo las columnas que incluyan el nombre del lugar, y cualquier cosas que esté asociada con la localización

filtered_columns =["name","categories"]+[col for col in dataframe.columns if col.startswith("location.")]+["id"]
dataframe_filtered = dataframe.loc[:, filtered_columns]

# %%
#A continuación, vamos a utilizar la función que extrae la categoría del lugar:

def get_category_type(row):
    try:
        categories_list = row["categories"]
    except:
        categories_list= row["venue.categories"]
    if len (categories_list)==0:
       return None
    else:
       return categories_list[0]["name"]

# %%
#Se filtra la categoría por cada fila
dataframe_filtered["categories"] = dataframe_filtered.apply(get_category_type, axis=1)

# %%
#Limpiamos los nombres de la columna manteniendo solo el último término
dataframe_filtered.columns =[column.split(".")[-1] for column in dataframe_filtered.columns]

# %%
dataframe_filtered
# Out:
#                                       name               categories  \
# 0                                      Gym                      Gym
# 1                     The Gym at The Atlas                      Gym
# 2                                 Ares Gym                 Building
# 3                      W Hotel - Bliss Gym                      Gym
# 4                                  AKA Gym                      Gym
# 5                         The Gym At Andaz                      Gym
# 6                        Gym@Club Quarters                      Gym
# 7                     Gym at the Mansfield                      Gym
# 8                 325 Lexington Avenue Gym                      Gym
# 9                                    a gym                      Gym
# 10                        Harvard Club Gym                      Gym
# 11                  Gym @ White & Case LLP                      Gym
# 12                           Yale Club Gym                      Gym
# 13                             Centria Gym     Gym / Fitness Center
# 14          Gym @ Millenium Broadway Hotel                      Gym
# 15              Gym at The Lexington Hotel     Gym / Fitness Center
# 16                   Gym At 34 E. 51st St.     Gym / Fitness Center
# 17                        The Somerset Gym                      Gym
# 18  My Fitness (Bank Of America Tower Gym)     Gym / Fitness Center
# 19                                Face Gym  Health & Beauty Service
# 20                              gym source                      Gym
# 21                      Gym @ The Refinery                      Gym
# 22                      Morgan Stanley Gym                      Gym
# 23                   Trump World Tower Gym                      Gym
# 24                      445 5th Avenue Gym                      Gym
# 25                  Gym At The Double Tree     Gym / Fitness Center
# 26                            The Muse Gym               Hotel Pool
# 27                              Gym Source              College Gym
# 28                           Greenhill Gym                      Gym
# 29                      Hyatt Stay Fit Gym                      Gym
#
#           lat        lng                                     labeledLatLngs  \
# 0   40.754172 -73.982415  [{'label': 'display', 'lat': 40.75417222203689...
# 1   40.751910 -73.985894  [{'label': 'display', 'lat': 40.75191035297386...
# 2   40.754730 -73.974736  [{'label': 'display', 'lat': 40.75473000726001...
# 3   40.756305 -73.972400  [{'label': 'display', 'lat': 40.75630466151134...
# 4   40.752570 -73.971311  [{'label': 'display', 'lat': 40.75257, 'lng': ...
# 5   40.752852 -73.981123  [{'label': 'display', 'lat': 40.75285188430376...
# 6   40.755772 -73.981255  [{'label': 'display', 'lat': 40.75577220620581...
# 7   40.754986 -73.981728  [{'label': 'display', 'lat': 40.75498580932617...
# 8   40.749312 -73.977091  [{'label': 'display', 'lat': 40.74931156116212...
# 9   40.753692 -73.981060  [{'label': 'display', 'lat': 40.753692, 'lng':...
# 10  40.755615 -73.981568  [{'label': 'display', 'lat': 40.75561518484979...
# 11  40.756336 -73.982902  [{'label': 'display', 'lat': 40.75633597805604...
# 12  40.754005 -73.977489  [{'label': 'display', 'lat': 40.75400533056944...
# 13  40.757920 -73.979170  [{'label': 'display', 'lat': 40.75791960653682...
# 14  40.756596 -73.985016  [{'label': 'display', 'lat': 40.75659561157226...
# 15  40.754883 -73.973658  [{'label': 'display', 'lat': 40.754883, 'lng':...
# 16  40.757971 -73.974404  [{'label': 'display', 'lat': 40.757971, 'lng':...
# 17  40.758453 -73.983440  [{'label': 'display', 'lat': 40.758453, 'lng':...
# 18  40.754968 -73.984193  [{'label': 'display', 'lat': 40.75496805989800...
# 19  40.758026 -73.977261  [{'label': 'display', 'lat': 40.758026, 'lng':...
# 20  40.758186 -73.973450  [{'label': 'display', 'lat': 40.75818565074922...
# 21  40.752357 -73.985153  [{'label': 'display', 'lat': 40.75235748291015...
# 22  40.759852 -73.985071  [{'label': 'display', 'lat': 40.75985207317243...
# 23  40.752362 -73.976124  [{'label': 'display', 'lat': 40.75236243536285...
# 24  40.751591 -73.981750  [{'label': 'display', 'lat': 40.75159072875976...
# 25  40.756653 -73.971588  [{'label': 'display', 'lat': 40.75665283203125...
# 26  40.758111 -73.983637  [{'label': 'display', 'lat': 40.75811099980807...
# 27  40.758874 -73.972543  [{'label': 'display', 'lat': 40.75887368444871...
# 28  40.757045 -73.974711  [{'label': 'display', 'lat': 40.757045, 'lng':...
# 29  40.757545 -73.984032  [{'label': 'display', 'lat': 40.75754547119140...
#
#     distance  cc      city state        country  \
# 0        289  US  New York    NY  United States
# 1        671  US  New York    NY  United States
# 2        395  US  New York    NY  United States
# 3        596  US  New York    NY  United States
# 4        745  US  New York    NY  United States
# 5        315  US  New York    NY  United States
# 6        166  US  New York    NY  United States
# 7        203  US  New York    NY  United States
# 8        699  US  New York    NY  United States
# 9        234  US  New York    NY  United States
# 10       188  US  New York    NY  United States
# 11       318  US  New York    NY  United States
# 12       217  US  New York    NY  United States
# 13       286  US  New York    NY  United States
# 14       496  US  New York    NY  United States
# 15       483  US  New York    NY  United States
# 16       509  US  New York    NY  United States
# 17       487  US  New York    NY  United States
# 18       409  US  New York    NY  United States
# 19       346  US  New York    NY  United States
# 20       589  US  New York    NY  United States
# 21       591  US  New York    NY  United States
# 22       694  US  New York    NY  United States
# 23       430  US  New York    NY  United States
# 24       464  US  New York    NY  United States
# 25       671  US  New York    NY  United States
# 26       473  US  New York    NY  United States
# 27       695  US  New York    NY  United States
# 28       434  US  New York    NY  United States
# 29       463  US  New York    NY  United States
#
#                                      formattedAddress            address  \
# 0                       [New York, NY, United States]                NaN
# 1   [66 W 38th St Fl 5 (6th Ave), New York, NY 100...  66 W 38th St Fl 5
# 2   [245 Park Ave, New York, NY 10167, United States]       245 Park Ave
# 3   [541 Lexington Ave, New York, NY 10022, United...  541 Lexington Ave
# 4   [234 (46th Street), New York, NY 10017, United...                234
# 5                 [New York, NY 10036, United States]                NaN
# 6                       [New York, NY, United States]                NaN
# 7                       [New York, NY, United States]                NaN
# 8                       [New York, NY, United States]                NaN
# 9                       [New York, NY, United States]                NaN
# 10  [27 W 44th St (At 5th), New York, NY 10036, Un...       27 W 44th St
# 11                [New York, NY 10036, United States]                NaN
# 12  [50 Vanderbilt Ave (at 44th St.), New York, NY...  50 Vanderbilt Ave
# 13  [18 W 48th St, New York, NY 10036, United States]       18 W 48th St
# 14  [144 W 44th St., New York, NY 10036-4012, Unit...     144 W 44th St.
# 15                [New York, NY 10017, United States]                NaN
# 16  [34 E 51st St, New York, NY 10022, United States]       34 E 51st St
# 17                [New York, NY 10036, United States]                NaN
# 18  [1 Bryant Park, New York, NY 10036, United Sta...      1 Bryant Park
# 19   [611 5th Ave, New York, NY 10022, United States]        611 5th Ave
# 20  [40E 52nd Street (Bet Park & Madison), New Yor...    40E 52nd Street
# 21  [63 W 38th St (6th Ave), New York, NY 10018, U...       63 W 38th St
# 22  [1585 Broadway, New York, NY 10019, United Sta...      1585 Broadway
# 23                [New York, NY 10017, United States]                NaN
# 24  [445 5th Ave (39th St.), New York, NY 10016, U...        445 5th Ave
# 25  [569 Lexington Ave (51st Street), New York, NY...  569 Lexington Ave
# 26                [New York, NY 10036, United States]                NaN
# 27  [40e 52nd street, New York, NY 10022, United S...    40e 52nd street
# 28  [300 Park Ave (50th Street), New York, NY 1002...       300 Park Ave
# 29  [135 W 45th St, New York, NY 10036, United Sta...      135 W 45th St
#
#            crossStreet  postalCode                        id
# 0                  NaN         NaN  4ddadabf45dd588c72142bfb
# 1              6th Ave       10018  4b18ff63f964a52004d723e3
# 2                  NaN       10167  55a053b3498ee841ba348ecf
# 3                  NaN       10022  4c578880d12a20a1fe1c67bd
# 4          46th Street       10017  5c053dce9411f2002c61226f
# 5                  NaN       10036  4fb38597e4b0b3ec72a82e98
# 6                  NaN         NaN  51792893e4b09b29cfdb3b86
# 7                  NaN         NaN  526d137811d286493dc20b3a
# 8                  NaN         NaN  565738a2498e51f6dc82c731
# 9                  NaN         NaN  568a7cfc498e2cdedb4d2240
# 10              At 5th       10036  4c082754009a0f47dba8e5bf
# 11                 NaN       10036  4f859771e4b0a7ed05baf933
# 12         at 44th St.       10017  4d99e1eed1bca09075a476b4
# 13                 NaN       10036  51b7132d498ec7411466d22f
# 14                 NaN  10036-4012  4cae3b1175ebb60cfca6b2ad
# 15                 NaN       10017  5c5b0e49396de0003912ac4d
# 16                 NaN       10022  5a500e9f1987ec2748b64bb2
# 17                 NaN       10036  5b93f55d5455b2002c8e411b
# 18                 NaN       10036  507cb748e4b06a750c8aa3d7
# 19                 NaN       10022  5b1c3f22eaf49a002c7da96a
# 20  Bet Park & Madison       10022  53f3851c498e1cd3c3fa507b
# 21             6th Ave       10018  56d82ff7cd10b0a0be638b76
# 22                 NaN       10019  4ca0ecff542b224b7a3c0aa0
# 23                 NaN       10017  50f42c60e4b0dd739c764ea4
# 24            39th St.       10016  4f452e9ce4b08406aaabb1ff
# 25         51st Street       10022  5237b1ed11d24eb362ab1986
# 26                 NaN       10036  4f0cd2a4e4b023b3783d81e5
# 27                 NaN       10022  4b465348f964a520ac1d26e3
# 28         50th Street       10022  4e03351ed164b56ad5332dc5
# 29                 NaN       10036  532754da498e973892dc0be8

# %%
#Vamos a visualizar los resultados de gimnasios que hemos encontrado
dataframe_filtered.name
# Out:
# 0                                        Gym
# 1                       The Gym at The Atlas
# 2                                   Ares Gym
# 3                        W Hotel - Bliss Gym
# 4                                    AKA Gym
# 5                           The Gym At Andaz
# 6                          Gym@Club Quarters
# 7                       Gym at the Mansfield
# 8                   325 Lexington Avenue Gym
# 9                                      a gym
# 10                          Harvard Club Gym
# 11                    Gym @ White & Case LLP
# 12                             Yale Club Gym
# 13                               Centria Gym
# 14            Gym @ Millenium Broadway Hotel
# 15                Gym at The Lexington Hotel
# 16                     Gym At 34 E. 51st St.
# 17                          The Somerset Gym
# 18    My Fitness (Bank Of America Tower Gym)
# 19                                  Face Gym
# 20                                gym source
# 21                        Gym @ The Refinery
# 22                        Morgan Stanley Gym
# 23                     Trump World Tower Gym
# 24                        445 5th Avenue Gym
# 25                    Gym At The Double Tree
# 26                              The Muse Gym
# 27                                Gym Source
# 28                             Greenhill Gym
# 29                        Hyatt Stay Fit Gym
# Name: name, dtype: object

# %%
#Vamos a mejorar folium con una actualización
# !pip install folium --upgrade
# Out:
# Collecting folium
#   Using cached https://files.pythonhosted.org/packages/a4/f0/44e69d50519880287cc41e7c8a6acc58daa9a9acf5f6afc52bcc70f69a6d/folium-0.11.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: numpy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (1.19.2)
# Requirement already satisfied, skipping upgrade: jinja2>=2.9 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.11.2)
# Requirement already satisfied, skipping upgrade: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.24.0)
# Requirement already satisfied, skipping upgrade: branca>=0.3.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (1.25.11)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Installing collected packages: folium
#   Found existing installation: folium 0.5.0
#     Uninstalling folium-0.5.0:
#       Successfully uninstalled folium-0.5.0
# Successfully installed folium-0.11.0

# %%
gym_map = folium.Map(location=[latitude, longitude], zoom_start=20) #genera una mapa centrado
#añade una marca de círculo naranja para representar "The Roosevelt Hotel"
          
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color="black",
    popup="The Roosevelt Hotel",
    fill=True,
    fill_color="orange",
    fill_opacity=0.6
).add_to(gym_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.CircleMarker(
        [lat,lng],
        radius=8,
        color="black",
        popup=label,
        fill=True,
        fill_color="red",
        fill_opacity=0.6
).add_to(gym_map)

# %%
#Muestra el mapa
gym_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#A continuación, vamos a explorar unos cuantos gimnasios. El 1 gimnasio es el
#Morgan Stanley Gym:

venue_id="4ca0ecff542b224b7a3c0aa0"
url = "https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}".format(venue_id, CLIENT_ID,
CLIENT_SECRET, VERSION)
print("Todo ha salido correcto")
# Out:
# Todo ha salido correcto

# %%
#Enviemos la solicitud del get para el resultado

gym1 = requests.get(url).json()
gym1
# Out:
# {'meta': {'code': 200, 'requestId': '5fc080ac14924349707b36d1'},
#  'response': {'venue': {'id': '4ca0ecff542b224b7a3c0aa0',
#    'name': 'Morgan Stanley Gym',
#    'contact': {},
#    'location': {'address': '1585 Broadway',
#     'lat': 40.75985207317243,
#     'lng': -73.98507102126582,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.75985207317243,
#       'lng': -73.98507102126582}],
#     'postalCode': '10019',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1585 Broadway',
#      'New York, NY 10019',
#      'United States']},
#    'canonicalUrl': 'https://foursquare.com/v/morgan-stanley-gym/4ca0ecff542b224b7a3c0aa0',
#    'categories': [{'id': '4bf58dd8d48988d176941735',
#      'name': 'Gym',
#      'pluralName': 'Gyms',
#      'shortName': 'Gym',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 2},
#    'likes': {'count': 7,
#     'groups': [{'type': 'others',
#       'count': 7,
#       'items': [{'isSanctioned': False,
#         'firstName': 'Kevin',
#         'lastName': 'N',
#         'countryCode': 'US'},
#        {'isSanctioned': False,
#         'firstName': 'Achin',
#         'lastName': 'B',
#         'countryCode': 'US'},
#        {'isSanctioned': False, 'firstName': 'A-L', 'countryCode': 'AE'},
#        {'isSanctioned': False,
#         'firstName': 'David',
#         'lastName': 'R',
#         'countryCode': 'US'}]}],
#     'summary': '7 Likes'},
#    'dislike': False,
#    'ok': False,
#    'rating': 6.5,
#    'ratingColor': 'FFC800',
#    'ratingSignals': 12,
#    'allowMenuUrlEdit': True,
#    'beenHere': {'count': 0,
#     'unconfirmedCount': 0,
#     'marked': False,
#     'lastCheckinExpiredAt': 0},
#    'specials': {'count': 0, 'items': []},
#    'photos': {'count': 1,
#     'groups': [{'type': 'venue',
#       'name': 'Venue photos',
#       'count': 1,
#       'items': [{'id': '59975272f8cbd46f1c226a06',
#         'createdAt': 1503089266,
#         'prefix': 'https://fastly.4sqi.net/img/general/',
#         'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#         'width': 3888,
#         'height': 2592,
#         'user': {'isSanctioned': False,
#          'firstName': 'pivot_photos',
#          'countryCode': 'US',
#          'type': 'page'},
#         'visibility': 'public'}]}]},
#    'reasons': {'count': 0, 'items': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'createdAt': 1285614847,
#    'tips': {'count': 2,
#     'groups': [{'type': 'others',
#       'name': 'All tips',
#       'count': 2,
#       'items': [{'id': '51694cfae4b095e8742d99a6',
#         'createdAt': 1365855482,
#         'text': 'Conveniently located in my building. Also very clean.',
#         'type': 'user',
#         'canonicalUrl': 'https://foursquare.com/item/51694cfae4b095e8742d99a6',
#         'lang': 'en',
#         'likes': {'count': 2,
#          'groups': [{'type': 'others',
#            'count': 2,
#            'items': [{'isSanctioned': False,
#              'firstName': 'Sebastien',
#              'lastName': 'L',
#              'countryCode': 'FR'},
#             {'isSanctioned': False,
#              'firstName': 'Miggs',
#              'lastName': 'C',
#              'countryCode': 'US'}]}],
#          'summary': '2 likes'},
#         'logView': True,
#         'agreeCount': 2,
#         'disagreeCount': 0,
#         'todo': {'count': 0},
#         'user': {'isSanctioned': False,
#          'firstName': 'Lissette',
#          'lastName': 'C',
#          'countryCode': 'US'}}]}]},
#    'shortUrl': 'http://4sq.com/bPxJqa',
#    'timeZone': 'America/New_York',
#    'listed': {'count': 0,
#     'groups': [{'type': 'others',
#       'name': 'Lists from other people',
#       'count': 0,
#       'items': []}]},
#    'popular': {'isOpen': False,
#     'isLocalHoliday': True,
#     'localHolidayName': 'Thanksgiving Day',
#     'timeframes': [{'days': 'Today',
#       'includesToday': True,
#       'open': [{'renderedTime': '6:00 AM–9:00 AM'},
#        {'renderedTime': 'Noon–8:00 PM'}],
#       'segments': []},
#      {'days': 'Fri',
#       'open': [{'renderedTime': '6:00 AM–8:00 AM'},
#        {'renderedTime': 'Noon–7:00 PM'}],
#       'segments': []},
#      {'days': 'Sat–Sun', 'open': [{'renderedTime': 'None'}], 'segments': []},
#      {'days': 'Mon–Tue',
#       'open': [{'renderedTime': '6:00 AM–9:00 AM'},
#        {'renderedTime': 'Noon–9:00 PM'}],
#       'segments': []},
#      {'days': 'Wed',
#       'open': [{'renderedTime': '6:00 AM–9:00 AM'},
#        {'renderedTime': 'Noon–8:00 PM'}],
#       'segments': []}]},
#    'seasonalHours': [],
#    'pageUpdates': {'count': 0, 'items': []},
#    'inbox': {'count': 0, 'items': []},
#    'attributes': {'groups': [{'type': 'payments',
#       'name': 'Credit Cards',
#       'summary': 'No Credit Cards',
#       'count': 7,
#       'items': [{'displayName': 'Credit Cards', 'displayValue': 'No'}]}]},
#    'bestPhoto': {'id': '59975272f8cbd46f1c226a06',
#     'createdAt': 1503089266,
#     'prefix': 'https://fastly.4sqi.net/img/general/',
#     'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#     'width': 3888,
#     'height': 2592,
#     'visibility': 'public'},
#    'colors': {'highlightColor': {'photoId': '59975272f8cbd46f1c226a06',
#      'value': -14145480},
#     'highlightTextColor': {'photoId': '59975272f8cbd46f1c226a06', 'value': -1},
#     'algoVersion': 3}}}}

# %%
#Vamos a definir la variable venues
venues=gym1["response"]["venue"]
venues
# Out:
# {'id': '4ca0ecff542b224b7a3c0aa0',
#  'name': 'Morgan Stanley Gym',
#  'contact': {},
#  'location': {'address': '1585 Broadway',
#   'lat': 40.75985207317243,
#   'lng': -73.98507102126582,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.75985207317243,
#     'lng': -73.98507102126582}],
#   'postalCode': '10019',
#   'cc': 'US',
#   'city': 'New York',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['1585 Broadway',
#    'New York, NY 10019',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/morgan-stanley-gym/4ca0ecff542b224b7a3c0aa0',
#  'categories': [{'id': '4bf58dd8d48988d176941735',
#    'name': 'Gym',
#    'pluralName': 'Gyms',
#    'shortName': 'Gym',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 2},
#  'likes': {'count': 7,
#   'groups': [{'type': 'others',
#     'count': 7,
#     'items': [{'isSanctioned': False,
#       'firstName': 'Kevin',
#       'lastName': 'N',
#       'countryCode': 'US'},
#      {'isSanctioned': False,
#       'firstName': 'Achin',
#       'lastName': 'B',
#       'countryCode': 'US'},
#      {'isSanctioned': False, 'firstName': 'A-L', 'countryCode': 'AE'},
#      {'isSanctioned': False,
#       'firstName': 'David',
#       'lastName': 'R',
#       'countryCode': 'US'}]}],
#   'summary': '7 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 6.5,
#  'ratingColor': 'FFC800',
#  'ratingSignals': 12,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 1,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 1,
#     'items': [{'id': '59975272f8cbd46f1c226a06',
#       'createdAt': 1503089266,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#       'width': 3888,
#       'height': 2592,
#       'user': {'isSanctioned': False,
#        'firstName': 'pivot_photos',
#        'countryCode': 'US',
#        'type': 'page'},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1285614847,
#  'tips': {'count': 2,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 2,
#     'items': [{'id': '51694cfae4b095e8742d99a6',
#       'createdAt': 1365855482,
#       'text': 'Conveniently located in my building. Also very clean.',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/51694cfae4b095e8742d99a6',
#       'lang': 'en',
#       'likes': {'count': 2,
#        'groups': [{'type': 'others',
#          'count': 2,
#          'items': [{'isSanctioned': False,
#            'firstName': 'Sebastien',
#            'lastName': 'L',
#            'countryCode': 'FR'},
#           {'isSanctioned': False,
#            'firstName': 'Miggs',
#            'lastName': 'C',
#            'countryCode': 'US'}]}],
#        'summary': '2 likes'},
#       'logView': True,
#       'agreeCount': 2,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'isSanctioned': False,
#        'firstName': 'Lissette',
#        'lastName': 'C',
#        'countryCode': 'US'}}]}]},
#  'shortUrl': 'http://4sq.com/bPxJqa',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 0,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 0,
#     'items': []}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': True,
#   'localHolidayName': 'Thanksgiving Day',
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '6:00 AM–9:00 AM'},
#      {'renderedTime': 'Noon–8:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '6:00 AM–8:00 AM'},
#      {'renderedTime': 'Noon–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sat–Sun', 'open': [{'renderedTime': 'None'}], 'segments': []},
#    {'days': 'Mon–Tue',
#     'open': [{'renderedTime': '6:00 AM–9:00 AM'},
#      {'renderedTime': 'Noon–9:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '6:00 AM–9:00 AM'},
#      {'renderedTime': 'Noon–8:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'No Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'No'}]}]},
#  'bestPhoto': {'id': '59975272f8cbd46f1c226a06',
#   'createdAt': 1503089266,
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#   'width': 3888,
#   'height': 2592,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '59975272f8cbd46f1c226a06',
#    'value': -14145480},
#   'highlightTextColor': {'photoId': '59975272f8cbd46f1c226a06', 'value': -1},
#   'algoVersion': 3}}

# %%
#En caso de que este calificado, ponemos que muestre la puntuación del gimnasio.
#En caso contrario, mostrar un mensaje de que "este lugar no ha sido puntuado aún"

try:
    print(gym1["response"]["venue"]["rating"])
except:
    print("This venue has not been rated yet.")
# Out:
# 6.5

# %%
#Como podemos observar este gimnasio no tiene muy buena reputación, así que 
#vamos a seguir analizando más gimnasios para ver si hay alguno de mejor opción.
#A continuación, vamos a analizar el 2ndo gimnasio "Yale Club Gym"

# %%
venue_id="4d99e1eed1bca09075a476b4"
url = "https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}".format(venue_id, CLIENT_ID,
CLIENT_SECRET, VERSION)
print("Todo ha salido correcto")
# Out:
# Todo ha salido correcto

# %%
#Enviemos la solicitud del get para el resultado

gym2 = requests.get(url).json()
gym2
# Out:
# {'meta': {'code': 200, 'requestId': '5fc080b072ff4663200f90c3'},
#  'response': {'venue': {'id': '4d99e1eed1bca09075a476b4',
#    'name': 'Yale Club Gym',
#    'contact': {'phone': '2127162100',
#     'formattedPhone': '(212) 716-2100',
#     'twitter': 'yaleclubnyc'},
#    'location': {'address': '50 Vanderbilt Ave',
#     'crossStreet': 'at 44th St.',
#     'lat': 40.75400533056944,
#     'lng': -73.97748908850008,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.75400533056944,
#       'lng': -73.97748908850008},
#      {'label': 'entrance', 'lat': 40.753958, 'lng': -73.977376}],
#     'postalCode': '10017',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['50 Vanderbilt Ave (at 44th St.)',
#      'New York, NY 10017',
#      'United States']},
#    'canonicalUrl': 'https://foursquare.com/v/yale-club-gym/4d99e1eed1bca09075a476b4',
#    'categories': [{'id': '4bf58dd8d48988d176941735',
#      'name': 'Gym',
#      'pluralName': 'Gyms',
#      'shortName': 'Gym',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 0},
#    'likes': {'count': 8,
#     'groups': [{'type': 'others',
#       'count': 8,
#       'items': [{'isSanctioned': False,
#         'firstName': 'John',
#         'lastName': 'B',
#         'countryCode': 'US'},
#        {'isSanctioned': False,
#         'firstName': 'John',
#         'lastName': 'B',
#         'countryCode': 'US'},
#        {'isSanctioned': False,
#         'firstName': 'martha',
#         'lastName': 'd',
#         'countryCode': 'US'}]}],
#     'summary': '8 Likes'},
#    'dislike': False,
#    'ok': False,
#    'rating': 7.7,
#    'ratingColor': 'C5DE35',
#    'ratingSignals': 10,
#    'allowMenuUrlEdit': True,
#    'beenHere': {'count': 0,
#     'unconfirmedCount': 0,
#     'marked': False,
#     'lastCheckinExpiredAt': 0},
#    'specials': {'count': 0, 'items': []},
#    'photos': {'count': 1,
#     'groups': [{'type': 'venue',
#       'name': 'Venue photos',
#       'count': 1,
#       'items': [{'id': '59975272f8cbd46f1c226a06',
#         'createdAt': 1503089266,
#         'prefix': 'https://fastly.4sqi.net/img/general/',
#         'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#         'width': 3888,
#         'height': 2592,
#         'user': {'isSanctioned': False,
#          'firstName': 'pivot_photos',
#          'countryCode': 'US',
#          'type': 'page'},
#         'visibility': 'public'}]}]},
#    'reasons': {'count': 0, 'items': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'createdAt': 1301930478,
#    'tips': {'count': 0, 'groups': []},
#    'shortUrl': 'http://4sq.com/gwRK3T',
#    'timeZone': 'America/New_York',
#    'listed': {'count': 1,
#     'groups': [{'type': 'others',
#       'name': 'Lists from other people',
#       'count': 1,
#       'items': [{'id': '53eb99c6498e70dab5708a1a',
#         'name': 'New York, my dear New York',
#         'description': '',
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'Ale',
#          'countryCode': 'VE'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/user/75642418/list/new-york-my-dear-new-york',
#         'canonicalUrl': 'https://foursquare.com/user/75642418/list/new-york-my-dear-new-york',
#         'createdAt': 1407949254,
#         'updatedAt': 1409260354,
#         'photo': {'id': '4fa7ed2be4b0217539d33c3b',
#          'createdAt': 1336405291,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/djktnuAoNM-IckT1uIYVkcMCC5yxnadVpLIk5gV1GWE.jpg',
#          'width': 720,
#          'height': 537,
#          'user': {'isSanctioned': False,
#           'firstName': 'd Todd',
#           'lastName': 'M',
#           'countryCode': 'US'},
#          'visibility': 'public'},
#         'followers': {'count': 0},
#         'listItems': {'count': 200,
#          'items': [{'id': 'v4d99e1eed1bca09075a476b4',
#            'createdAt': 1408033761}]}}]}]},
#    'popular': {'isOpen': False,
#     'isLocalHoliday': True,
#     'localHolidayName': 'Thanksgiving Day',
#     'timeframes': [{'days': 'Today',
#       'includesToday': True,
#       'open': [{'renderedTime': '7:00 AM–8:00 AM'},
#        {'renderedTime': '10:00 AM–11:00 AM'},
#        {'renderedTime': '4:00 PM–9:00 PM'}],
#       'segments': []},
#      {'days': 'Fri',
#       'open': [{'renderedTime': '8:00 AM–9:00 AM'},
#        {'renderedTime': '2:00 PM–7:00 PM'}],
#       'segments': []},
#      {'days': 'Sat',
#       'open': [{'renderedTime': '10:00 AM–6:00 PM'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': '10:00 AM–5:00 PM'}],
#       'segments': []},
#      {'days': 'Mon',
#       'open': [{'renderedTime': '7:00 AM–9:00 AM'},
#        {'renderedTime': '5:00 PM–9:00 PM'}],
#       'segments': []},
#      {'days': 'Tue',
#       'open': [{'renderedTime': '7:00 AM–10:00 AM'},
#        {'renderedTime': '4:00 PM–10:00 PM'}],
#       'segments': []},
#      {'days': 'Wed',
#       'open': [{'renderedTime': '7:00 AM–8:00 AM'},
#        {'renderedTime': '10:00 AM–11:00 AM'},
#        {'renderedTime': '3:00 PM–10:00 PM'}],
#       'segments': []}]},
#    'seasonalHours': [],
#    'pageUpdates': {'count': 0, 'items': []},
#    'inbox': {'count': 0, 'items': []},
#    'parent': {'id': '4593baa7f964a5204d401fe3',
#     'name': 'Yale Club of New York City',
#     'location': {'address': '50 Vanderbilt Ave',
#      'crossStreet': 'at E 44th St.',
#      'lat': 40.75393101383987,
#      'lng': -73.97737816151448,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75393101383987,
#        'lng': -73.97737816151448}],
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['50 Vanderbilt Ave (at E 44th St.)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a35',
#       'name': 'Club House',
#       'pluralName': 'Club Houses',
#       'shortName': 'Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '152003021'}},
#    'hierarchy': [{'name': 'Yale Club of New York City',
#      'lang': 'en',
#      'id': '4593baa7f964a5204d401fe3',
#      'canonicalUrl': 'https://foursquare.com/v/yale-club-of-new-york-city/4593baa7f964a5204d401fe3'}],
#    'attributes': {'groups': [{'type': 'payments',
#       'name': 'Credit Cards',
#       'summary': 'No Credit Cards',
#       'count': 7,
#       'items': [{'displayName': 'Credit Cards', 'displayValue': 'No'}]}]},
#    'bestPhoto': {'id': '59975272f8cbd46f1c226a06',
#     'createdAt': 1503089266,
#     'prefix': 'https://fastly.4sqi.net/img/general/',
#     'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#     'width': 3888,
#     'height': 2592,
#     'visibility': 'public'},
#    'colors': {'highlightColor': {'photoId': '59975272f8cbd46f1c226a06',
#      'value': -14145480},
#     'highlightTextColor': {'photoId': '59975272f8cbd46f1c226a06', 'value': -1},
#     'algoVersion': 3}}}}

# %%
#Definimos la variable venues
venues=gym2["response"]["venue"]
venues
# Out:
# {'id': '4d99e1eed1bca09075a476b4',
#  'name': 'Yale Club Gym',
#  'contact': {'phone': '2127162100',
#   'formattedPhone': '(212) 716-2100',
#   'twitter': 'yaleclubnyc'},
#  'location': {'address': '50 Vanderbilt Ave',
#   'crossStreet': 'at 44th St.',
#   'lat': 40.75400533056944,
#   'lng': -73.97748908850008,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.75400533056944,
#     'lng': -73.97748908850008},
#    {'label': 'entrance', 'lat': 40.753958, 'lng': -73.977376}],
#   'postalCode': '10017',
#   'cc': 'US',
#   'city': 'New York',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['50 Vanderbilt Ave (at 44th St.)',
#    'New York, NY 10017',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/yale-club-gym/4d99e1eed1bca09075a476b4',
#  'categories': [{'id': '4bf58dd8d48988d176941735',
#    'name': 'Gym',
#    'pluralName': 'Gyms',
#    'shortName': 'Gym',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 0},
#  'likes': {'count': 8,
#   'groups': [{'type': 'others',
#     'count': 8,
#     'items': [{'isSanctioned': False,
#       'firstName': 'John',
#       'lastName': 'B',
#       'countryCode': 'US'},
#      {'isSanctioned': False,
#       'firstName': 'John',
#       'lastName': 'B',
#       'countryCode': 'US'},
#      {'isSanctioned': False,
#       'firstName': 'martha',
#       'lastName': 'd',
#       'countryCode': 'US'}]}],
#   'summary': '8 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 7.7,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 10,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 1,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 1,
#     'items': [{'id': '59975272f8cbd46f1c226a06',
#       'createdAt': 1503089266,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#       'width': 3888,
#       'height': 2592,
#       'user': {'isSanctioned': False,
#        'firstName': 'pivot_photos',
#        'countryCode': 'US',
#        'type': 'page'},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1301930478,
#  'tips': {'count': 0, 'groups': []},
#  'shortUrl': 'http://4sq.com/gwRK3T',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 1,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 1,
#     'items': [{'id': '53eb99c6498e70dab5708a1a',
#       'name': 'New York, my dear New York',
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False, 'firstName': 'Ale', 'countryCode': 'VE'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/75642418/list/new-york-my-dear-new-york',
#       'canonicalUrl': 'https://foursquare.com/user/75642418/list/new-york-my-dear-new-york',
#       'createdAt': 1407949254,
#       'updatedAt': 1409260354,
#       'photo': {'id': '4fa7ed2be4b0217539d33c3b',
#        'createdAt': 1336405291,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/djktnuAoNM-IckT1uIYVkcMCC5yxnadVpLIk5gV1GWE.jpg',
#        'width': 720,
#        'height': 537,
#        'user': {'isSanctioned': False,
#         'firstName': 'd Todd',
#         'lastName': 'M',
#         'countryCode': 'US'},
#        'visibility': 'public'},
#       'followers': {'count': 0},
#       'listItems': {'count': 200,
#        'items': [{'id': 'v4d99e1eed1bca09075a476b4',
#          'createdAt': 1408033761}]}}]}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': True,
#   'localHolidayName': 'Thanksgiving Day',
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:00 AM–8:00 AM'},
#      {'renderedTime': '10:00 AM–11:00 AM'},
#      {'renderedTime': '4:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '8:00 AM–9:00 AM'},
#      {'renderedTime': '2:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '10:00 AM–6:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '10:00 AM–5:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '7:00 AM–9:00 AM'},
#      {'renderedTime': '5:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '7:00 AM–10:00 AM'},
#      {'renderedTime': '4:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '7:00 AM–8:00 AM'},
#      {'renderedTime': '10:00 AM–11:00 AM'},
#      {'renderedTime': '3:00 PM–10:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'parent': {'id': '4593baa7f964a5204d401fe3',
#   'name': 'Yale Club of New York City',
#   'location': {'address': '50 Vanderbilt Ave',
#    'crossStreet': 'at E 44th St.',
#    'lat': 40.75393101383987,
#    'lng': -73.97737816151448,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.75393101383987,
#      'lng': -73.97737816151448}],
#    'postalCode': '10017',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['50 Vanderbilt Ave (at E 44th St.)',
#     'New York, NY 10017',
#     'United States']},
#   'categories': [{'id': '52e81612bcbc57f1066b7a35',
#     'name': 'Club House',
#     'pluralName': 'Club Houses',
#     'shortName': 'Club',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '152003021'}},
#  'hierarchy': [{'name': 'Yale Club of New York City',
#    'lang': 'en',
#    'id': '4593baa7f964a5204d401fe3',
#    'canonicalUrl': 'https://foursquare.com/v/yale-club-of-new-york-city/4593baa7f964a5204d401fe3'}],
#  'attributes': {'groups': [{'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'No Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'No'}]}]},
#  'bestPhoto': {'id': '59975272f8cbd46f1c226a06',
#   'createdAt': 1503089266,
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#   'width': 3888,
#   'height': 2592,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '59975272f8cbd46f1c226a06',
#    'value': -14145480},
#   'highlightTextColor': {'photoId': '59975272f8cbd46f1c226a06', 'value': -1},
#   'algoVersion': 3}}

# %%
#En caso de que el lugar este puntuado, mostrar la puntuación
#En caso de que no, mostrar el mensaje de que no esta disponible
try:
    print(gym2["response"]["venue"]["rating"])
except:
    print("This venue has not been rated yet.")
# Out:
# 7.7

# %%
#A continuación, vamos a explorar otro gimnasio más. 
#El 3º se llama "The Gym at the Atlas"

# %%
venue_id="4b18ff63f964a52004d723e3"
url = "https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}".format(venue_id, CLIENT_ID,
CLIENT_SECRET, VERSION)
print("Todo ha salido correcto")
# Out:
# Todo ha salido correcto

# %%
#Enviemos la solicitud del get para el resultado

gym3 = requests.get(url).json()
gym3
# Out:
# {'meta': {'code': 200, 'requestId': '5fc080b39ec77475406d0bfc'},
#  'response': {'venue': {'id': '4b18ff63f964a52004d723e3',
#    'name': 'The Gym at The Atlas',
#    'contact': {'phone': '2124025300', 'formattedPhone': '(212) 402-5300'},
#    'location': {'address': '66 W 38th St Fl 5',
#     'crossStreet': '6th Ave',
#     'lat': 40.751910352973866,
#     'lng': -73.9858935506665,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.751910352973866,
#       'lng': -73.9858935506665}],
#     'postalCode': '10018',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['66 W 38th St Fl 5 (6th Ave)',
#      'New York, NY 10018',
#      'United States']},
#    'canonicalUrl': 'https://foursquare.com/v/the-gym-at-the-atlas/4b18ff63f964a52004d723e3',
#    'categories': [{'id': '4bf58dd8d48988d176941735',
#      'name': 'Gym',
#      'pluralName': 'Gyms',
#      'shortName': 'Gym',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 5},
#    'likes': {'count': 5,
#     'groups': [{'type': 'others',
#       'count': 5,
#       'items': [{'isSanctioned': False,
#         'firstName': 'Josh',
#         'lastName': 'W',
#         'countryCode': 'TW'},
#        {'isSanctioned': False, 'firstName': 'Gee👒👒', 'countryCode': 'ID'},
#        {'isSanctioned': False,
#         'firstName': 'Jenn',
#         'lastName': 'Z',
#         'countryCode': 'US'},
#        {'isSanctioned': False,
#         'firstName': 'Zach',
#         'lastName': 'M',
#         'countryCode': 'US'}]}],
#     'summary': '5 Likes'},
#    'dislike': False,
#    'ok': False,
#    'rating': 5.9,
#    'ratingColor': 'FF9600',
#    'ratingSignals': 9,
#    'allowMenuUrlEdit': True,
#    'beenHere': {'count': 0,
#     'unconfirmedCount': 0,
#     'marked': False,
#     'lastCheckinExpiredAt': 0},
#    'specials': {'count': 0, 'items': []},
#    'photos': {'count': 1,
#     'groups': [{'type': 'venue',
#       'name': 'Venue photos',
#       'count': 1,
#       'items': [{'id': '59975272f8cbd46f1c226a06',
#         'createdAt': 1503089266,
#         'prefix': 'https://fastly.4sqi.net/img/general/',
#         'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#         'width': 3888,
#         'height': 2592,
#         'user': {'isSanctioned': False,
#          'firstName': 'pivot_photos',
#          'countryCode': 'US',
#          'type': 'page'},
#         'visibility': 'public'}]}]},
#    'reasons': {'count': 0, 'items': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'createdAt': 1259929443,
#    'tips': {'count': 5,
#     'groups': [{'type': 'others',
#       'name': 'All tips',
#       'count': 5,
#       'items': [{'id': '5057b1fde4b07e9d89d88e82',
#         'createdAt': 1347924477,
#         'text': 'Use to have sushi/cocktail nights here before the economy tanked.',
#         'type': 'user',
#         'canonicalUrl': 'https://foursquare.com/item/5057b1fde4b07e9d89d88e82',
#         'lang': 'en',
#         'likes': {'count': 2,
#          'groups': [{'type': 'others',
#            'count': 2,
#            'items': [{'isSanctioned': False,
#              'firstName': 'Denis',
#              'lastName': 'S',
#              'countryCode': 'US'},
#             {'isSanctioned': False,
#              'firstName': 'Zach',
#              'lastName': 'M',
#              'countryCode': 'US'}]}],
#          'summary': '2 likes'},
#         'logView': True,
#         'agreeCount': 3,
#         'disagreeCount': 0,
#         'todo': {'count': 0},
#         'user': {'isSanctioned': False,
#          'firstName': 'Jenn',
#          'lastName': 'Z',
#          'countryCode': 'US'},
#         'authorInteractionType': 'liked'}]}]},
#    'shortUrl': 'http://4sq.com/axAgum',
#    'timeZone': 'America/New_York',
#    'listed': {'count': 1,
#     'groups': [{'type': 'others',
#       'name': 'Lists from other people',
#       'count': 1,
#       'items': [{'id': '543b1ecd498ed431d5a1f0b5',
#         'name': 'NYC Gyms',
#         'description': '',
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'Thomas',
#          'lastName': 'W',
#          'countryCode': 'US'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/tawong/list/nyc-gyms',
#         'canonicalUrl': 'https://foursquare.com/tawong/list/nyc-gyms',
#         'createdAt': 1413160653,
#         'updatedAt': 1413160653,
#         'photo': {'id': '502e9971e4b07730f4191fd6',
#          'createdAt': 1345231217,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/OWUPs_mLJxioX23TpNwV81cutrhNL1COIZ2DqHLCE9Q.jpg',
#          'width': 537,
#          'height': 720,
#          'user': {'isSanctioned': False,
#           'firstName': 'Lisa S',
#           'lastName': 'C',
#           'countryCode': 'KR'},
#          'visibility': 'public'},
#         'followers': {'count': 0},
#         'listItems': {'count': 1,
#          'items': [{'id': 'v4b18ff63f964a52004d723e3',
#            'createdAt': 1413160653,
#            'photo': {'id': '502e9971e4b07730f4191fd6',
#             'createdAt': 1345231217,
#             'prefix': 'https://fastly.4sqi.net/img/general/',
#             'suffix': '/OWUPs_mLJxioX23TpNwV81cutrhNL1COIZ2DqHLCE9Q.jpg',
#             'width': 537,
#             'height': 720,
#             'user': {'isSanctioned': False,
#              'firstName': 'Lisa S',
#              'lastName': 'C',
#              'countryCode': 'KR'},
#             'visibility': 'public'}}]}}]}]},
#    'popular': {'isOpen': False,
#     'isLocalHoliday': True,
#     'localHolidayName': 'Thanksgiving Day',
#     'timeframes': [{'days': 'Today',
#       'includesToday': True,
#       'open': [{'renderedTime': '7:00 AM–8:00 AM'},
#        {'renderedTime': '5:00 PM–11:00 PM'}],
#       'segments': []},
#      {'days': 'Fri',
#       'open': [{'renderedTime': '6:00 AM–7:00 AM'},
#        {'renderedTime': '5:00 PM–8:00 PM'},
#        {'renderedTime': '10:00 PM–11:00 PM'}],
#       'segments': []},
#      {'days': 'Sat',
#       'open': [{'renderedTime': '8:00 AM–10:00 AM'},
#        {'renderedTime': '5:00 PM–8:00 PM'},
#        {'renderedTime': '10:00 PM–11:00 PM'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': '9:00 AM–11:00 AM'},
#        {'renderedTime': '2:00 PM–5:00 PM'},
#        {'renderedTime': '8:00 PM–11:00 PM'}],
#       'segments': []},
#      {'days': 'Mon',
#       'open': [{'renderedTime': '6:00 AM–8:00 AM'},
#        {'renderedTime': '5:00 PM–11:00 PM'}],
#       'segments': []},
#      {'days': 'Tue',
#       'open': [{'renderedTime': '6:00 AM–7:00 AM'},
#        {'renderedTime': '5:00 PM–11:00 PM'}],
#       'segments': []},
#      {'days': 'Wed',
#       'open': [{'renderedTime': '6:00 AM–8:00 AM'},
#        {'renderedTime': '5:00 PM–11:00 PM'}],
#       'segments': []}]},
#    'seasonalHours': [],
#    'pageUpdates': {'count': 0, 'items': []},
#    'inbox': {'count': 0, 'items': []},
#    'parent': {'id': '4a7ceb1ef964a52016ee1fe3',
#     'name': 'Atlas New York',
#     'location': {'address': '66 W 38th St',
#      'crossStreet': 'at 6th Ave.',
#      'lat': 40.75185023181706,
#      'lng': -73.98566524487894,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75185023181706,
#        'lng': -73.98566524487894}],
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['66 W 38th St (at 6th Ave.)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}]},
#    'hierarchy': [{'name': 'Atlas New York',
#      'lang': 'en',
#      'id': '4a7ceb1ef964a52016ee1fe3',
#      'canonicalUrl': 'https://foursquare.com/v/atlas-new-york/4a7ceb1ef964a52016ee1fe3'}],
#    'attributes': {'groups': [{'type': 'payments',
#       'name': 'Credit Cards',
#       'summary': 'No Credit Cards',
#       'count': 7,
#       'items': [{'displayName': 'Credit Cards', 'displayValue': 'No'}]}]},
#    'bestPhoto': {'id': '59975272f8cbd46f1c226a06',
#     'createdAt': 1503089266,
#     'prefix': 'https://fastly.4sqi.net/img/general/',
#     'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#     'width': 3888,
#     'height': 2592,
#     'visibility': 'public'},
#    'colors': {'highlightColor': {'photoId': '59975272f8cbd46f1c226a06',
#      'value': -14145480},
#     'highlightTextColor': {'photoId': '59975272f8cbd46f1c226a06', 'value': -1},
#     'algoVersion': 3}}}}

# %%
#Definimos la variable venues
venues=gym3["response"]["venue"]
venues
# Out:
# {'id': '4b18ff63f964a52004d723e3',
#  'name': 'The Gym at The Atlas',
#  'contact': {'phone': '2124025300', 'formattedPhone': '(212) 402-5300'},
#  'location': {'address': '66 W 38th St Fl 5',
#   'crossStreet': '6th Ave',
#   'lat': 40.751910352973866,
#   'lng': -73.9858935506665,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.751910352973866,
#     'lng': -73.9858935506665}],
#   'postalCode': '10018',
#   'cc': 'US',
#   'city': 'New York',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['66 W 38th St Fl 5 (6th Ave)',
#    'New York, NY 10018',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/the-gym-at-the-atlas/4b18ff63f964a52004d723e3',
#  'categories': [{'id': '4bf58dd8d48988d176941735',
#    'name': 'Gym',
#    'pluralName': 'Gyms',
#    'shortName': 'Gym',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 5},
#  'likes': {'count': 5,
#   'groups': [{'type': 'others',
#     'count': 5,
#     'items': [{'isSanctioned': False,
#       'firstName': 'Josh',
#       'lastName': 'W',
#       'countryCode': 'TW'},
#      {'isSanctioned': False, 'firstName': 'Gee👒👒', 'countryCode': 'ID'},
#      {'isSanctioned': False,
#       'firstName': 'Jenn',
#       'lastName': 'Z',
#       'countryCode': 'US'},
#      {'isSanctioned': False,
#       'firstName': 'Zach',
#       'lastName': 'M',
#       'countryCode': 'US'}]}],
#   'summary': '5 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 5.9,
#  'ratingColor': 'FF9600',
#  'ratingSignals': 9,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 1,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 1,
#     'items': [{'id': '59975272f8cbd46f1c226a06',
#       'createdAt': 1503089266,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#       'width': 3888,
#       'height': 2592,
#       'user': {'isSanctioned': False,
#        'firstName': 'pivot_photos',
#        'countryCode': 'US',
#        'type': 'page'},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1259929443,
#  'tips': {'count': 5,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 5,
#     'items': [{'id': '5057b1fde4b07e9d89d88e82',
#       'createdAt': 1347924477,
#       'text': 'Use to have sushi/cocktail nights here before the economy tanked.',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/5057b1fde4b07e9d89d88e82',
#       'lang': 'en',
#       'likes': {'count': 2,
#        'groups': [{'type': 'others',
#          'count': 2,
#          'items': [{'isSanctioned': False,
#            'firstName': 'Denis',
#            'lastName': 'S',
#            'countryCode': 'US'},
#           {'isSanctioned': False,
#            'firstName': 'Zach',
#            'lastName': 'M',
#            'countryCode': 'US'}]}],
#        'summary': '2 likes'},
#       'logView': True,
#       'agreeCount': 3,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'isSanctioned': False,
#        'firstName': 'Jenn',
#        'lastName': 'Z',
#        'countryCode': 'US'},
#       'authorInteractionType': 'liked'}]}]},
#  'shortUrl': 'http://4sq.com/axAgum',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 1,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 1,
#     'items': [{'id': '543b1ecd498ed431d5a1f0b5',
#       'name': 'NYC Gyms',
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Thomas',
#        'lastName': 'W',
#        'countryCode': 'US'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/tawong/list/nyc-gyms',
#       'canonicalUrl': 'https://foursquare.com/tawong/list/nyc-gyms',
#       'createdAt': 1413160653,
#       'updatedAt': 1413160653,
#       'photo': {'id': '502e9971e4b07730f4191fd6',
#        'createdAt': 1345231217,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/OWUPs_mLJxioX23TpNwV81cutrhNL1COIZ2DqHLCE9Q.jpg',
#        'width': 537,
#        'height': 720,
#        'user': {'isSanctioned': False,
#         'firstName': 'Lisa S',
#         'lastName': 'C',
#         'countryCode': 'KR'},
#        'visibility': 'public'},
#       'followers': {'count': 0},
#       'listItems': {'count': 1,
#        'items': [{'id': 'v4b18ff63f964a52004d723e3',
#          'createdAt': 1413160653,
#          'photo': {'id': '502e9971e4b07730f4191fd6',
#           'createdAt': 1345231217,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/OWUPs_mLJxioX23TpNwV81cutrhNL1COIZ2DqHLCE9Q.jpg',
#           'width': 537,
#           'height': 720,
#           'user': {'isSanctioned': False,
#            'firstName': 'Lisa S',
#            'lastName': 'C',
#            'countryCode': 'KR'},
#           'visibility': 'public'}}]}}]}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': True,
#   'localHolidayName': 'Thanksgiving Day',
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:00 AM–8:00 AM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '6:00 AM–7:00 AM'},
#      {'renderedTime': '5:00 PM–8:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–10:00 AM'},
#      {'renderedTime': '5:00 PM–8:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '9:00 AM–11:00 AM'},
#      {'renderedTime': '2:00 PM–5:00 PM'},
#      {'renderedTime': '8:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '6:00 AM–8:00 AM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '6:00 AM–7:00 AM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '6:00 AM–8:00 AM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'parent': {'id': '4a7ceb1ef964a52016ee1fe3',
#   'name': 'Atlas New York',
#   'location': {'address': '66 W 38th St',
#    'crossStreet': 'at 6th Ave.',
#    'lat': 40.75185023181706,
#    'lng': -73.98566524487894,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.75185023181706,
#      'lng': -73.98566524487894}],
#    'postalCode': '10018',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['66 W 38th St (at 6th Ave.)',
#     'New York, NY 10018',
#     'United States']},
#   'categories': [{'id': '4d954b06a243a5684965b473',
#     'name': 'Residential Building (Apartment / Condo)',
#     'pluralName': 'Residential Buildings (Apartments / Condos)',
#     'shortName': 'Residential',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#      'suffix': '.png'},
#     'primary': True}]},
#  'hierarchy': [{'name': 'Atlas New York',
#    'lang': 'en',
#    'id': '4a7ceb1ef964a52016ee1fe3',
#    'canonicalUrl': 'https://foursquare.com/v/atlas-new-york/4a7ceb1ef964a52016ee1fe3'}],
#  'attributes': {'groups': [{'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'No Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'No'}]}]},
#  'bestPhoto': {'id': '59975272f8cbd46f1c226a06',
#   'createdAt': 1503089266,
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#   'width': 3888,
#   'height': 2592,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '59975272f8cbd46f1c226a06',
#    'value': -14145480},
#   'highlightTextColor': {'photoId': '59975272f8cbd46f1c226a06', 'value': -1},
#   'algoVersion': 3}}

# %%
#En caso de que el lugar este puntuado, mostrar la puntuación
#En caso de que no, mostrar el mensaje de que no esta disponible
try:
    print(gym3["response"]["venue"]["rating"])
except:
    print("This venue has not been rated yet.")
# Out:
# 5.9

# %%
#Después de hacer una criba de análisis de todos los gimnasios, nos pone que el mejor valorado
#es el "Yale Club Gym" pero no dispone de ninguna opinión, así que vamos a comprobar cuantas opiniones 
#hay disponibles "Morgan Stanley Gym"

# %%
gym1["response"]["venue"]["tips"]["count"]
# Out:
# 2

# %%
#Una vez que hemos comprobado el número de opiniones que hay sobre este restaurante, vamos a conseguir
#una opinión al azar de este

#Opinión del Restaurante

limit=2 #Define los límites para que sean mayor o igual al total de consejos para ese restaurante
url=url = "https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}".format(venue_id, CLIENT_ID,
CLIENT_SECRET, VERSION, limit)

TipsJapanese=requests.get(url).json()
TipsJapanese
# Out:
# {'meta': {'code': 200, 'requestId': '5fc080b60076b17a226e5f0e'},
#  'response': {'tips': {'count': 5,
#    'items': [{'id': '4f79f091e4b0488e3138c420',
#      'createdAt': 1333391505,
#      'text': "there are often personal instructors working with clients here, but it doesn't start getting busy until the evenings",
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/4f79f091e4b0488e3138c420',
#      'lang': 'en',
#      'likes': {'count': 1,
#       'groups': [{'type': 'others',
#         'count': 1,
#         'items': [{'isSanctioned': False,
#           'firstName': 'Zach',
#           'lastName': 'M',
#           'countryCode': 'US'}]}],
#       'summary': '1 like'},
#      'logView': True,
#      'agreeCount': 2,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'isSanctioned': False,
#       'firstName': 'Clayton',
#       'countryCode': 'US'}}]}}}

# %%
#Vamos a conseguir extraer la opinión del restaurante
tips= TipsJapanese["response"]["tips"]["items"]

tip = TipsJapanese["response"]["tips"]["items"][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user'])

# %%
#Formatea el ancho de las columnas y visualiza todos los consejos
pd.set_option("display.max_colwidth",-1)

tips_df=pd.json_normalize(tips)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
filtered_columns =["text","agreeCount", "disagreeCount", "id"]
tips_filtered =tips_df.loc[:,filtered_columns]

# %%
#Muestra el consejo

tips_filtered.reindex()
# Out:
#                                                                                                                    text  \
# 0  there are often personal instructors working with clients here, but it doesn't start getting busy until the evenings
#
#    agreeCount  disagreeCount                        id
# 0  2           0              4f79f091e4b0488e3138c420
