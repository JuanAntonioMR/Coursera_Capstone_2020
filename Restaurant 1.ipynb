# %%
import requests #Biblioteca para manejar solicitudes
import pandas as pd #Biblioteca para Análisis de datos
import numpy as np #Biblioteca para manejar datos de una manera vectorizada
import random #Biblioteca para la generación de números aleatorios

# !pip install geopy
from geopy.geocoders import Nominatim #Módulo para convertir una dirección en valores de latitud y longitud

#Bibliotecas para mostrar imágenes

from IPython.display import Image
from IPython.core.display import HTML

#Transformar un archivo JSON en una biblioteca de marco de datos de pandas
from pandas.io.json import json_normalize

! pip install folium==0.5.0
import folium #Biblioteca de representación

print("Folium installed")
print("Libraries imported")
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.50)
# Requirement already satisfied: folium==0.5.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: branca in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (0.4.1)
# Requirement already satisfied: jinja2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (3.0.4)
# Folium installed
# Libraries imported

# %%
CLIENT_ID= "VYXHEB1JFDKLQWKXQVDHVO0BIK5COTAA00QDMGTTZSE0GQPI" #Tu ID de Foursquare
CLIENT_SECRET= "5KJIO12I3YHGWNTTX2MFS011R0V2VHRRE5N1CTRPEHYLDZOX" #Tu Foursquare secreto
VERSION="20180604 "
LIMIT=30
print("Your credentials:")
print("CLIENT_ID: " + CLIENT_ID)
print("CLIENT_SECRET:" + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: VYXHEB1JFDKLQWKXQVDHVO0BIK5COTAA00QDMGTTZSE0GQPI
# CLIENT_SECRET:5KJIO12I3YHGWNTTX2MFS011R0V2VHRRE5N1CTRPEHYLDZOX

# %%
#Vamos a trabajar con un Hotel llamado "The Roosevelt
#Hotel" que está en Nueva York, ubicado en Manhattan"
Dirección="East 45th st, New York, NY 10017, Estados Unidos"

geolocator =Nominatim(user_agent="foursquare_agent")
location=geolocator.geocode(Dirección)
latitude=location.latitude
longitude=location.longitude
print(latitude, longitude)
# Out:
# 40.7553525 -73.9793583

# %%
#Ahora vamos a definir la consulta para buscar comida japonesa, que se encuentre a 
#700 metros de "The Roosevelt Hotel".

search_query="Japanese"
radius=700
print(search_query + ".... OK!")
# Out:
# Japanese.... OK!

# %%
#Ahora definimos la correspondiente URL:

url= "https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}".format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=VYXHEB1JFDKLQWKXQVDHVO0BIK5COTAA00QDMGTTZSE0GQPI&client_secret=5KJIO12I3YHGWNTTX2MFS011R0V2VHRRE5N1CTRPEHYLDZOX&ll=40.7553525,-73.9793583&v=20180604 &query=Japanese&radius=700&limit=30'

# %%
#Realizamos la solicitud de la url
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fc072f6da740e58ce03d144'},
#  'response': {'venues': [{'id': '4be20ec01dd22d7ffa3c93bd',
#     'name': 'Japanese American Association Of New York',
#     'location': {'lat': 40.75544369348851,
#      'lng': -73.98061087730353,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75544369348851,
#        'lng': -73.98061087730353}],
#      'distance': 106,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10036', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '48208c8cf964a520894f1fe3',
#     'name': 'Gyu-Kaku Japanese BBQ',
#     'location': {'address': '805 3rd Ave',
#      'crossStreet': 'btwn E 49th & E 50th St',
#      'lat': 40.755730504250046,
#      'lng': -73.9708969487331,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.755730504250046,
#        'lng': -73.9708969487331}],
#      'distance': 714,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['805 3rd Ave (btwn E 49th & E 50th St)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2251148',
#      'url': 'https://www.seamless.com/menu/gyu-kaku-japanese-bbq-805-3rd-ave-new-york/2251148?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2251148',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '4a8c4222f964a5207a0d20e3',
#     'name': 'Japanese Culinary Center',
#     'location': {'address': '711 3rd Ave',
#      'crossStreet': 'at E 45th St.',
#      'lat': 40.752658430165006,
#      'lng': -73.97291038142438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752658430165006,
#        'lng': -73.97291038142438}],
#      'distance': 620,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['711 3rd Ave (at E 45th St.)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'shortName': 'Furniture / Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '4d5b24ce6b2e3704ed237eee',
#     'name': 'FIT Japanese Class',
#     'location': {'address': '227 W 27th St',
#      'crossStreet': 'btwn 7th & 8th',
#      'lat': 40.75384633914933,
#      'lng': -73.98576057432156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75384633914933,
#        'lng': -73.98576057432156}],
#      'distance': 565,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['227 W 27th St (btwn 7th & 8th)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d199941735',
#       'name': 'College Arts Building',
#       'pluralName': 'College Arts Buildings',
#       'shortName': 'Arts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '5b3bdbf3535d6f002c31c06d',
#     'name': 'Japanese Medical Care',
#     'location': {'address': '315 Madison Ave Fl 17',
#      'lat': 40.752626,
#      'lng': -73.97921,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752626,
#        'lng': -73.97921}],
#      'distance': 303,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['315 Madison Ave Fl 17',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '4e25e793cc3fd40fdb752777',
#     'name': 'D-Dojo/ The School of Modern Japanese Karate',
#     'location': {'address': '2 W 47th St',
#      'lat': 40.75672149658203,
#      'lng': -73.9793701171875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75672149658203,
#        'lng': -73.9793701171875}],
#      'distance': 152,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2 W 47th St',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '5d2f6150e43d9300082d8c7d',
#     'name': 'Uncle Tetsu’s Japanese Cheesecake',
#     'location': {'address': '135 W 41st St',
#      'lat': 40.754811,
#      'lng': -73.985641,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.754811,
#        'lng': -73.985641}],
#      'distance': 533,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['135 W 41st St',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '4e6016d8b61cd7808787e93c',
#     'name': 'Mishima Japanese Restaurant',
#     'location': {'lat': 40.75574502439816,
#      'lng': -73.97697960643174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75574502439816,
#        'lng': -73.97697960643174}],
#      'distance': 205,
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['New York', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'shortName': 'Lounge',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '5a4d9fe986bc4977f41ad3e4',
#     'name': 'The Japanese Sushi Bar',
#     'location': {'address': '137 E 45th St',
#      'lat': 40.75332260131836,
#      'lng': -73.97398376464844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75332260131836,
#        'lng': -73.97398376464844}],
#      'distance': 506,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['137 E 45th St',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2032709',
#      'url': 'https://www.seamless.com/menu/the-japanese-sushi-bar-137-east-45th-street-new-york/2032709?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2032709',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '4f1dd96fe4b0288a058c5441',
#     'name': 'Japanese American Chiropractic',
#     'location': {'lat': 40.75139507985042,
#      'lng': -73.97596374308705,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75139507985042,
#        'lng': -73.97596374308705}],
#      'distance': 525,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10017', 'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3a',
#       'name': 'Chiropractor',
#       'pluralName': 'Chiropractors',
#       'shortName': 'Chiropractors',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '4e4e49f6bd4101d0d7a6ecb8',
#     'name': 'Taki Japanese Restaurant',
#     'location': {'address': '60 W 48th St',
#      'lat': 40.758096,
#      'lng': -73.980643,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.758096,
#        'lng': -73.980643}],
#      'distance': 324,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['60 W 48th St',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '5e70d06f408ac100082b620d',
#     'name': 'My Japanese Home',
#     'location': {'address': '244 Madison Ave',
#      'lat': 40.750638177173855,
#      'lng': -73.9809250831604,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.750638177173855,
#        'lng': -73.9809250831604}],
#      'distance': 541,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['244 Madison Ave',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1b4',
#       'name': 'Kitchen Supply Store',
#       'pluralName': 'Kitchen Supply Stores',
#       'shortName': 'Kitchen Supply',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_butcher_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '547b504f498eb0f50d0a9471',
#     'name': 'Aasira Japanese Restaurant',
#     'location': {'address': '692 3rd Ave',
#      'crossStreet': '43rd',
#      'lat': 40.75187683105469,
#      'lng': -73.9740219116211,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75187683105469,
#        'lng': -73.9740219116211}],
#      'distance': 593,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['692 3rd Ave (43rd)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '57e70046498eddfb9123debb',
#     'name': 'hama japanese',
#     'location': {'lat': 40.760548,
#      'lng': -73.976535,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.760548,
#        'lng': -73.976535}],
#      'distance': 625,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '519d0cef498e348ec1aab97b',
#     'name': 'New York Mutual Trading Japanese Culinary Center',
#     'location': {'lat': 40.75244379016836,
#      'lng': -73.97278411354567,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75244379016836,
#        'lng': -73.97278411354567}],
#      'distance': 642,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f9941735',
#       'name': 'Food & Drink Shop',
#       'pluralName': 'Food & Drink Shops',
#       'shortName': 'Food & Drink',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '50136c94e4b0c7c30cd3e94e',
#     'name': 'Azuma Japanese Restaurant',
#     'location': {'address': 'Uptown Avenue Seremban 2',
#      'lat': 40.749868,
#      'lng': -73.976019,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.749868,
#        'lng': -73.976019}],
#      'distance': 672,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Uptown Avenue Seremban 2',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '4f321b6519836c91c7b68fea',
#     'name': 'Hapon Japanese Restaurant',
#     'location': {'address': '211 E 43rd St',
#      'lat': 40.751447,
#      'lng': -73.972999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.751447,
#        'lng': -73.972999}],
#      'distance': 690,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['211 E 43rd St',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '4f32234519836c91c7b9d2f8',
#     'name': 'American Japanese Sky',
#     'location': {'address': '926 2nd Ave',
#      'lat': 40.75425720214844,
#      'lng': -73.96855163574219,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.754327,
#        'lng': -73.968656},
#       {'label': 'display',
#        'lat': 40.75425720214844,
#        'lng': -73.96855163574219}],
#      'distance': 919,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['926 2nd Ave',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '4a48fad7f964a520e2aa1fe3',
#     'name': 'Dainobu',
#     'location': {'address': '129 E 47th St',
#      'crossStreet': 'btwn Lexington & 3rd Ave',
#      'lat': 40.75453263511689,
#      'lng': -73.97345259897823,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75453263511689,
#        'lng': -73.97345259897823}],
#      'distance': 506,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['129 E 47th St (btwn Lexington & 3rd Ave)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '407f2200f964a5207df21ee3',
#     'name': 'Sakagura',
#     'location': {'address': '211 E 43rd St Lowr Level',
#      'crossStreet': 'btwn 2nd & 3rd Ave',
#      'lat': 40.751304870459144,
#      'lng': -73.9733141805895,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.751304870459144,
#        'lng': -73.9733141805895}],
#      'distance': 680,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['211 E 43rd St Lowr Level (btwn 2nd & 3rd Ave)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11c941735',
#       'name': 'Sake Bar',
#       'pluralName': 'Sake Bars',
#       'shortName': 'Sake Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sake_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '71886455'},
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '4e4e5584bd4101d0d7a7f097',
#     'name': 'Inagiku',
#     'location': {'address': '111 E 49th St',
#      'lat': 40.756503,
#      'lng': -73.97334599999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.756503,
#        'lng': -73.97334599999999},
#       {'label': 'entrance', 'lat': 40.756263, 'lng': -73.973519}],
#      'distance': 522,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['111 E 49th St',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False},
#    {'id': '4b707217f964a520e81a2de3',
#     'name': 'Consulate General of Japan',
#     'location': {'address': '299 Park Ave',
#      'crossStreet': 'btwn E 48th & E 49th St',
#      'lat': 40.75604694985082,
#      'lng': -73.97428929805756,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75604694985082,
#        'lng': -73.97428929805756},
#       {'label': 'entrance', 'lat': 40.756127, 'lng': -73.974407}],
#      'distance': 434,
#      'postalCode': '10171',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['299 Park Ave (btwn E 48th & E 49th St)',
#       'New York, NY 10171',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12c951735',
#       'name': 'Embassy / Consulate',
#       'pluralName': 'Embassies / Consulates',
#       'shortName': 'Embassy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/embassy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606447862',
#     'hasPerk': False}]}}

# %%
#Asigna la parte relevante de JSON a lugares
venues=results["response"]["venues"]

# %%
#Transforma los lugares en un marco de datos

dataframe=pd.json_normalize(venues)
dataframe.head(30)
# Out:
#                           id  \
# 0   4be20ec01dd22d7ffa3c93bd
# 1   48208c8cf964a520894f1fe3
# 2   4a8c4222f964a5207a0d20e3
# 3   4d5b24ce6b2e3704ed237eee
# 4   5b3bdbf3535d6f002c31c06d
# 5   4e25e793cc3fd40fdb752777
# 6   5d2f6150e43d9300082d8c7d
# 7   4e6016d8b61cd7808787e93c
# 8   5a4d9fe986bc4977f41ad3e4
# 9   4f1dd96fe4b0288a058c5441
# 10  4e4e49f6bd4101d0d7a6ecb8
# 11  5e70d06f408ac100082b620d
# 12  547b504f498eb0f50d0a9471
# 13  57e70046498eddfb9123debb
# 14  519d0cef498e348ec1aab97b
# 15  50136c94e4b0c7c30cd3e94e
# 16  4f321b6519836c91c7b68fea
# 17  4f32234519836c91c7b9d2f8
# 18  4a48fad7f964a520e2aa1fe3
# 19  407f2200f964a5207df21ee3
# 20  4e4e5584bd4101d0d7a7f097
# 21  4b707217f964a520e81a2de3
#
#                                                 name  \
# 0          Japanese American Association Of New York
# 1                              Gyu-Kaku Japanese BBQ
# 2                           Japanese Culinary Center
# 3                                 FIT Japanese Class
# 4                              Japanese Medical Care
# 5       D-Dojo/ The School of Modern Japanese Karate
# 6                  Uncle Tetsu’s Japanese Cheesecake
# 7                        Mishima Japanese Restaurant
# 8                             The Japanese Sushi Bar
# 9                     Japanese American Chiropractic
# 10                          Taki Japanese Restaurant
# 11                                  My Japanese Home
# 12                        Aasira Japanese Restaurant
# 13                                     hama japanese
# 14  New York Mutual Trading Japanese Culinary Center
# 15                         Azuma Japanese Restaurant
# 16                         Hapon Japanese Restaurant
# 17                             American Japanese Sky
# 18                                           Dainobu
# 19                                          Sakagura
# 20                                           Inagiku
# 21                        Consulate General of Japan
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d171941735', 'name': 'E...  v-1606447862    False
# 1   [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1606447862    False
# 2   [{'id': '4bf58dd8d48988d1f8941735', 'name': 'F...  v-1606447862    False
# 3   [{'id': '4bf58dd8d48988d199941735', 'name': 'C...  v-1606447862    False
# 4   [{'id': '4bf58dd8d48988d177941735', 'name': 'D...  v-1606447862    False
# 5   [{'id': '4bf58dd8d48988d1f1931735', 'name': 'G...  v-1606447862    False
# 6   [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...  v-1606447862    False
# 7   [{'id': '4bf58dd8d48988d121941735', 'name': 'L...  v-1606447862    False
# 8   [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1606447862    False
# 9   [{'id': '52e81612bcbc57f1066b7a3a', 'name': 'C...  v-1606447862    False
# 10  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1606447862    False
# 11  [{'id': '58daa1558bbb0b01f18ec1b4', 'name': 'K...  v-1606447862    False
# 12  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1606447862    False
# 13  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1606447862    False
# 14  [{'id': '4bf58dd8d48988d1f9941735', 'name': 'F...  v-1606447862    False
# 15  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1606447862    False
# 16  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1606447862    False
# 17  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1606447862    False
# 18  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...  v-1606447862    False
# 19  [{'id': '4bf58dd8d48988d11c941735', 'name': 'S...  v-1606447862    False
# 20  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1606447862    False
# 21  [{'id': '4bf58dd8d48988d12c951735', 'name': 'E...  v-1606447862    False
#
#     location.lat  location.lng  \
# 0      40.755444    -73.980611
# 1      40.755731    -73.970897
# 2      40.752658    -73.972910
# 3      40.753846    -73.985761
# 4      40.752626    -73.979210
# 5      40.756721    -73.979370
# 6      40.754811    -73.985641
# 7      40.755745    -73.976980
# 8      40.753323    -73.973984
# 9      40.751395    -73.975964
# 10     40.758096    -73.980643
# 11     40.750638    -73.980925
# 12     40.751877    -73.974022
# 13     40.760548    -73.976535
# 14     40.752444    -73.972784
# 15     40.749868    -73.976019
# 16     40.751447    -73.972999
# 17     40.754257    -73.968552
# 18     40.754533    -73.973453
# 19     40.751305    -73.973314
# 20     40.756503    -73.973346
# 21     40.756047    -73.974289
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 40.75544369348851...                106
# 1   [{'label': 'display', 'lat': 40.75573050425004...                714
# 2   [{'label': 'display', 'lat': 40.75265843016500...                620
# 3   [{'label': 'display', 'lat': 40.75384633914933...                565
# 4   [{'label': 'display', 'lat': 40.752626, 'lng':...                303
# 5   [{'label': 'display', 'lat': 40.75672149658203...                152
# 6   [{'label': 'display', 'lat': 40.754811, 'lng':...                533
# 7   [{'label': 'display', 'lat': 40.75574502439816...                205
# 8   [{'label': 'display', 'lat': 40.75332260131836...                506
# 9   [{'label': 'display', 'lat': 40.75139507985042...                525
# 10  [{'label': 'display', 'lat': 40.758096, 'lng':...                324
# 11  [{'label': 'display', 'lat': 40.75063817717385...                541
# 12  [{'label': 'display', 'lat': 40.75187683105469...                593
# 13  [{'label': 'display', 'lat': 40.760548, 'lng':...                625
# 14  [{'label': 'display', 'lat': 40.75244379016836...                642
# 15  [{'label': 'display', 'lat': 40.749868, 'lng':...                672
# 16  [{'label': 'display', 'lat': 40.751447, 'lng':...                690
# 17  [{'label': 'entrance', 'lat': 40.754327, 'lng'...                919
# 18  [{'label': 'display', 'lat': 40.75453263511689...                506
# 19  [{'label': 'display', 'lat': 40.75130487045914...                680
# 20  [{'label': 'display', 'lat': 40.756503, 'lng':...                522
# 21  [{'label': 'display', 'lat': 40.75604694985082...                434
#
#    location.postalCode  ...  \
# 0                10036  ...
# 1                10022  ...
# 2                10017  ...
# 3                10001  ...
# 4                10017  ...
# 5                10036  ...
# 6                10036  ...
# 7                  NaN  ...
# 8                10017  ...
# 9                10017  ...
# 10               10036  ...
# 11               10016  ...
# 12               10017  ...
# 13                 NaN  ...
# 14                 NaN  ...
# 15               10017  ...
# 16               10017  ...
# 17               10022  ...
# 18               10017  ...
# 19               10017  ...
# 20               10017  ...
# 21               10171  ...
#
#                             location.formattedAddress  \
# 0                 [New York, NY 10036, United States]
# 1   [805 3rd Ave (btwn E 49th & E 50th St), New Yo...
# 2   [711 3rd Ave (at E 45th St.), New York, NY 100...
# 3   [227 W 27th St (btwn 7th & 8th), New York, NY ...
# 4   [315 Madison Ave Fl 17, New York, NY 10017, Un...
# 5    [2 W 47th St, New York, NY 10036, United States]
# 6   [135 W 41st St, New York, NY 10036, United Sta...
# 7                           [New York, United States]
# 8   [137 E 45th St, New York, NY 10017, United Sta...
# 9                 [New York, NY 10017, United States]
# 10  [60 W 48th St, New York, NY 10036, United States]
# 11  [244 Madison Ave, New York, NY 10016, United S...
# 12  [692 3rd Ave (43rd), New York, NY 10017, Unite...
# 13                      [New York, NY, United States]
# 14                      [New York, NY, United States]
# 15  [Uptown Avenue Seremban 2, New York, NY 10017,...
# 16  [211 E 43rd St, New York, NY 10017, United Sta...
# 17   [926 2nd Ave, New York, NY 10022, United States]
# 18  [129 E 47th St (btwn Lexington & 3rd Ave), New...
# 19  [211 E 43rd St Lowr Level (btwn 2nd & 3rd Ave)...
# 20  [111 E 49th St, New York, NY 10017, United Sta...
# 21  [299 Park Ave (btwn E 48th & E 49th St), New Y...
#
#             location.address      location.crossStreet delivery.id  \
# 0                        NaN                       NaN         NaN
# 1                805 3rd Ave   btwn E 49th & E 50th St     2251148
# 2                711 3rd Ave             at E 45th St.         NaN
# 3              227 W 27th St            btwn 7th & 8th         NaN
# 4      315 Madison Ave Fl 17                       NaN         NaN
# 5                2 W 47th St                       NaN         NaN
# 6              135 W 41st St                       NaN         NaN
# 7                        NaN                       NaN         NaN
# 8              137 E 45th St                       NaN     2032709
# 9                        NaN                       NaN         NaN
# 10              60 W 48th St                       NaN         NaN
# 11           244 Madison Ave                       NaN         NaN
# 12               692 3rd Ave                      43rd         NaN
# 13                       NaN                       NaN         NaN
# 14                       NaN                       NaN         NaN
# 15  Uptown Avenue Seremban 2                       NaN         NaN
# 16             211 E 43rd St                       NaN         NaN
# 17               926 2nd Ave                       NaN         NaN
# 18             129 E 47th St  btwn Lexington & 3rd Ave         NaN
# 19  211 E 43rd St Lowr Level        btwn 2nd & 3rd Ave         NaN
# 20             111 E 49th St                       NaN         NaN
# 21              299 Park Ave   btwn E 48th & E 49th St         NaN
#
#                                          delivery.url delivery.provider.name  \
# 0                                                 NaN                    NaN
# 1   https://www.seamless.com/menu/gyu-kaku-japanes...               seamless
# 2                                                 NaN                    NaN
# 3                                                 NaN                    NaN
# 4                                                 NaN                    NaN
# 5                                                 NaN                    NaN
# 6                                                 NaN                    NaN
# 7                                                 NaN                    NaN
# 8   https://www.seamless.com/menu/the-japanese-sus...               seamless
# 9                                                 NaN                    NaN
# 10                                                NaN                    NaN
# 11                                                NaN                    NaN
# 12                                                NaN                    NaN
# 13                                                NaN                    NaN
# 14                                                NaN                    NaN
# 15                                                NaN                    NaN
# 16                                                NaN                    NaN
# 17                                                NaN                    NaN
# 18                                                NaN                    NaN
# 19                                                NaN                    NaN
# 20                                                NaN                    NaN
# 21                                                NaN                    NaN
#
#                delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                        NaN                          NaN
# 1   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# 5                                        NaN                          NaN
# 6                                        NaN                          NaN
# 7                                        NaN                          NaN
# 8   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 9                                        NaN                          NaN
# 10                                       NaN                          NaN
# 11                                       NaN                          NaN
# 12                                       NaN                          NaN
# 13                                       NaN                          NaN
# 14                                       NaN                          NaN
# 15                                       NaN                          NaN
# 16                                       NaN                          NaN
# 17                                       NaN                          NaN
# 18                                       NaN                          NaN
# 19                                       NaN                          NaN
# 20                                       NaN                          NaN
# 21                                       NaN                          NaN
#
#                  delivery.provider.icon.name venuePage.id
# 0                                        NaN          NaN
# 1   /delivery_provider_seamless_20180129.png          NaN
# 2                                        NaN          NaN
# 3                                        NaN          NaN
# 4                                        NaN          NaN
# 5                                        NaN          NaN
# 6                                        NaN          NaN
# 7                                        NaN          NaN
# 8   /delivery_provider_seamless_20180129.png          NaN
# 9                                        NaN          NaN
# 10                                       NaN          NaN
# 11                                       NaN          NaN
# 12                                       NaN          NaN
# 13                                       NaN          NaN
# 14                                       NaN          NaN
# 15                                       NaN          NaN
# 16                                       NaN          NaN
# 17                                       NaN          NaN
# 18                                       NaN          NaN
# 19                                       NaN     71886455
# 20                                       NaN          NaN
# 21                                       NaN          NaN
#
# [22 rows x 24 columns]

# %%
#Ahora tenemos que mantener solo las columnas que incluyan el nombre del lugar, y cualquier cosa que esté asociada con la localización

filtered_columns =["name","categories"]+[col for col in dataframe.columns if col.startswith("location.")]+["id"]
dataframe_filtered = dataframe.loc[:, filtered_columns]

# %%
#A contuinuación, vamos a aplicar la función que extrae la categoría del lugar:

def get_category_type(row):
    try:
        categories_list = row["categories"]
    except:
        categories_list= row["venue.categories"]
    if len (categories_list)==0:
       return None
    else:
       return categories_list[0]["name"]

# %%
#Se filtra la categoría por cada fila
dataframe_filtered["categories"] = dataframe_filtered.apply(get_category_type, axis=1)

# %%
#Limpiamos los nombres de la columna manteniendo solo el último término
dataframe_filtered.columns =[column.split(".")[-1] for column in dataframe_filtered.columns]

# %%
dataframe_filtered
# Out:
#                                                 name              categories  \
# 0          Japanese American Association Of New York             Event Space
# 1                              Gyu-Kaku Japanese BBQ     Japanese Restaurant
# 2                           Japanese Culinary Center  Furniture / Home Store
# 3                                 FIT Japanese Class   College Arts Building
# 4                              Japanese Medical Care         Doctor's Office
# 5       D-Dojo/ The School of Modern Japanese Karate   General Entertainment
# 6                  Uncle Tetsu’s Japanese Cheesecake            Dessert Shop
# 7                        Mishima Japanese Restaurant                  Lounge
# 8                             The Japanese Sushi Bar        Sushi Restaurant
# 9                     Japanese American Chiropractic            Chiropractor
# 10                          Taki Japanese Restaurant     Japanese Restaurant
# 11                                  My Japanese Home    Kitchen Supply Store
# 12                        Aasira Japanese Restaurant     Japanese Restaurant
# 13                                     hama japanese        Sushi Restaurant
# 14  New York Mutual Trading Japanese Culinary Center       Food & Drink Shop
# 15                         Azuma Japanese Restaurant     Japanese Restaurant
# 16                         Hapon Japanese Restaurant     Japanese Restaurant
# 17                             American Japanese Sky                    Food
# 18                                           Dainobu           Grocery Store
# 19                                          Sakagura                Sake Bar
# 20                                           Inagiku        Sushi Restaurant
# 21                        Consulate General of Japan     Embassy / Consulate
#
#           lat        lng                                     labeledLatLngs  \
# 0   40.755444 -73.980611  [{'label': 'display', 'lat': 40.75544369348851...
# 1   40.755731 -73.970897  [{'label': 'display', 'lat': 40.75573050425004...
# 2   40.752658 -73.972910  [{'label': 'display', 'lat': 40.75265843016500...
# 3   40.753846 -73.985761  [{'label': 'display', 'lat': 40.75384633914933...
# 4   40.752626 -73.979210  [{'label': 'display', 'lat': 40.752626, 'lng':...
# 5   40.756721 -73.979370  [{'label': 'display', 'lat': 40.75672149658203...
# 6   40.754811 -73.985641  [{'label': 'display', 'lat': 40.754811, 'lng':...
# 7   40.755745 -73.976980  [{'label': 'display', 'lat': 40.75574502439816...
# 8   40.753323 -73.973984  [{'label': 'display', 'lat': 40.75332260131836...
# 9   40.751395 -73.975964  [{'label': 'display', 'lat': 40.75139507985042...
# 10  40.758096 -73.980643  [{'label': 'display', 'lat': 40.758096, 'lng':...
# 11  40.750638 -73.980925  [{'label': 'display', 'lat': 40.75063817717385...
# 12  40.751877 -73.974022  [{'label': 'display', 'lat': 40.75187683105469...
# 13  40.760548 -73.976535  [{'label': 'display', 'lat': 40.760548, 'lng':...
# 14  40.752444 -73.972784  [{'label': 'display', 'lat': 40.75244379016836...
# 15  40.749868 -73.976019  [{'label': 'display', 'lat': 40.749868, 'lng':...
# 16  40.751447 -73.972999  [{'label': 'display', 'lat': 40.751447, 'lng':...
# 17  40.754257 -73.968552  [{'label': 'entrance', 'lat': 40.754327, 'lng'...
# 18  40.754533 -73.973453  [{'label': 'display', 'lat': 40.75453263511689...
# 19  40.751305 -73.973314  [{'label': 'display', 'lat': 40.75130487045914...
# 20  40.756503 -73.973346  [{'label': 'display', 'lat': 40.756503, 'lng':...
# 21  40.756047 -73.974289  [{'label': 'display', 'lat': 40.75604694985082...
#
#     distance postalCode  cc      city     state        country  \
# 0        106      10036  US  New York        NY  United States
# 1        714      10022  US  New York        NY  United States
# 2        620      10017  US  New York        NY  United States
# 3        565      10001  US  New York        NY  United States
# 4        303      10017  US  New York        NY  United States
# 5        152      10036  US  New York        NY  United States
# 6        533      10036  US  New York        NY  United States
# 7        205        NaN  US       NaN  New York  United States
# 8        506      10017  US  New York        NY  United States
# 9        525      10017  US  New York        NY  United States
# 10       324      10036  US  New York        NY  United States
# 11       541      10016  US  New York        NY  United States
# 12       593      10017  US  New York        NY  United States
# 13       625        NaN  US  New York        NY  United States
# 14       642        NaN  US  New York        NY  United States
# 15       672      10017  US  New York        NY  United States
# 16       690      10017  US  New York        NY  United States
# 17       919      10022  US  New York        NY  United States
# 18       506      10017  US  New York        NY  United States
# 19       680      10017  US  New York        NY  United States
# 20       522      10017  US  New York        NY  United States
# 21       434      10171  US  New York        NY  United States
#
#                                      formattedAddress  \
# 0                 [New York, NY 10036, United States]
# 1   [805 3rd Ave (btwn E 49th & E 50th St), New Yo...
# 2   [711 3rd Ave (at E 45th St.), New York, NY 100...
# 3   [227 W 27th St (btwn 7th & 8th), New York, NY ...
# 4   [315 Madison Ave Fl 17, New York, NY 10017, Un...
# 5    [2 W 47th St, New York, NY 10036, United States]
# 6   [135 W 41st St, New York, NY 10036, United Sta...
# 7                           [New York, United States]
# 8   [137 E 45th St, New York, NY 10017, United Sta...
# 9                 [New York, NY 10017, United States]
# 10  [60 W 48th St, New York, NY 10036, United States]
# 11  [244 Madison Ave, New York, NY 10016, United S...
# 12  [692 3rd Ave (43rd), New York, NY 10017, Unite...
# 13                      [New York, NY, United States]
# 14                      [New York, NY, United States]
# 15  [Uptown Avenue Seremban 2, New York, NY 10017,...
# 16  [211 E 43rd St, New York, NY 10017, United Sta...
# 17   [926 2nd Ave, New York, NY 10022, United States]
# 18  [129 E 47th St (btwn Lexington & 3rd Ave), New...
# 19  [211 E 43rd St Lowr Level (btwn 2nd & 3rd Ave)...
# 20  [111 E 49th St, New York, NY 10017, United Sta...
# 21  [299 Park Ave (btwn E 48th & E 49th St), New Y...
#
#                      address               crossStreet  \
# 0                        NaN                       NaN
# 1                805 3rd Ave   btwn E 49th & E 50th St
# 2                711 3rd Ave             at E 45th St.
# 3              227 W 27th St            btwn 7th & 8th
# 4      315 Madison Ave Fl 17                       NaN
# 5                2 W 47th St                       NaN
# 6              135 W 41st St                       NaN
# 7                        NaN                       NaN
# 8              137 E 45th St                       NaN
# 9                        NaN                       NaN
# 10              60 W 48th St                       NaN
# 11           244 Madison Ave                       NaN
# 12               692 3rd Ave                      43rd
# 13                       NaN                       NaN
# 14                       NaN                       NaN
# 15  Uptown Avenue Seremban 2                       NaN
# 16             211 E 43rd St                       NaN
# 17               926 2nd Ave                       NaN
# 18             129 E 47th St  btwn Lexington & 3rd Ave
# 19  211 E 43rd St Lowr Level        btwn 2nd & 3rd Ave
# 20             111 E 49th St                       NaN
# 21              299 Park Ave   btwn E 48th & E 49th St
#
#                           id
# 0   4be20ec01dd22d7ffa3c93bd
# 1   48208c8cf964a520894f1fe3
# 2   4a8c4222f964a5207a0d20e3
# 3   4d5b24ce6b2e3704ed237eee
# 4   5b3bdbf3535d6f002c31c06d
# 5   4e25e793cc3fd40fdb752777
# 6   5d2f6150e43d9300082d8c7d
# 7   4e6016d8b61cd7808787e93c
# 8   5a4d9fe986bc4977f41ad3e4
# 9   4f1dd96fe4b0288a058c5441
# 10  4e4e49f6bd4101d0d7a6ecb8
# 11  5e70d06f408ac100082b620d
# 12  547b504f498eb0f50d0a9471
# 13  57e70046498eddfb9123debb
# 14  519d0cef498e348ec1aab97b
# 15  50136c94e4b0c7c30cd3e94e
# 16  4f321b6519836c91c7b68fea
# 17  4f32234519836c91c7b9d2f8
# 18  4a48fad7f964a520e2aa1fe3
# 19  407f2200f964a5207df21ee3
# 20  4e4e5584bd4101d0d7a7f097
# 21  4b707217f964a520e81a2de3

# %%
#Vamos a visualizar los resultados japoneses que hemos encontrado
dataframe_filtered.name
# Out:
# 0            Japanese American Association Of New York
# 1                                Gyu-Kaku Japanese BBQ
# 2                             Japanese Culinary Center
# 3                                   FIT Japanese Class
# 4                                Japanese Medical Care
# 5         D-Dojo/ The School of Modern Japanese Karate
# 6                    Uncle Tetsu’s Japanese Cheesecake
# 7                          Mishima Japanese Restaurant
# 8                               The Japanese Sushi Bar
# 9                       Japanese American Chiropractic
# 10                            Taki Japanese Restaurant
# 11                                    My Japanese Home
# 12                          Aasira Japanese Restaurant
# 13                                       hama japanese
# 14    New York Mutual Trading Japanese Culinary Center
# 15                           Azuma Japanese Restaurant
# 16                           Hapon Japanese Restaurant
# 17                               American Japanese Sky
# 18                                             Dainobu
# 19                                            Sakagura
# 20                                             Inagiku
# 21                          Consulate General of Japan
# Name: name, dtype: object

# %%
#Vamos a mejorar folium con una actualización
# !pip install folium --upgrade
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/a4/f0/44e69d50519880287cc41e7c8a6acc58daa9a9acf5f6afc52bcc70f69a6d/folium-0.11.0-py2.py3-none-any.whl (93kB)
#      |████████████████████████████████| 102kB 5.9MB/s ta 0:00:011
# Requirement already satisfied, skipping upgrade: numpy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (1.19.2)
# Requirement already satisfied, skipping upgrade: jinja2>=2.9 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.11.2)
# Requirement already satisfied, skipping upgrade: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.24.0)
# Requirement already satisfied, skipping upgrade: branca>=0.3.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (1.25.11)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Installing collected packages: folium
#   Found existing installation: folium 0.5.0
#     Uninstalling folium-0.5.0:
#       Successfully uninstalled folium-0.5.0
# Successfully installed folium-0.11.0

# %%
japaneses_map = folium.Map(location=[latitude, longitude], zoom_start=20) #genera una mapa centrado
#añade una marca de círculo naranja para representar "The Roosevelt Hotel"
          
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color="black",
    popup="The Roosevelt Hotel",
    fill=True,
    fill_color="orange",
    fill_opacity=0.6
).add_to(japaneses_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.CircleMarker(
        [lat,lng],
        radius=8,
        color="black",
        popup=label,
        fill=True,
        fill_color="red",
        fill_opacity=0.6
).add_to(japaneses_map)

# %%
#Muestra el mapa
japaneses_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#A continuación, vamos a explorar unos cuantos restaurantes japoneses. El 1 restaurante va a ser el "Gyu-Kaku Japanese BBQ":

venue_id="48208c8cf964a520894f1fe3"
url = "https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}".format(venue_id, CLIENT_ID,
CLIENT_SECRET, VERSION)
print("Todo ha salido correcto")
# Out:
# Todo ha salido correcto

# %%
#Enviemos la solicitud del get para el resultado

resultJapanese1 = requests.get(url).json()
resultJapanese1
# Out:
# {'meta': {'code': 200, 'requestId': '5fc073106e59ad4ec777e96b'},
#  'response': {'venue': {'id': '48208c8cf964a520894f1fe3',
#    'name': 'Gyu-Kaku Japanese BBQ',
#    'contact': {'phone': '2127028816',
#     'formattedPhone': '(212) 702-8816',
#     'twitter': 'gyukakujbbq',
#     'facebook': '107675045957918',
#     'facebookUsername': 'GyuKakuMidtownNY',
#     'facebookName': 'Gyu-Kaku Japanese BBQ'},
#    'location': {'address': '805 3rd Ave',
#     'crossStreet': 'btwn E 49th & E 50th St',
#     'lat': 40.755730504250046,
#     'lng': -73.9708969487331,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.755730504250046,
#       'lng': -73.9708969487331}],
#     'postalCode': '10022',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['805 3rd Ave (btwn E 49th & E 50th St)',
#      'New York, NY 10022',
#      'United States']},
#    'canonicalUrl': 'https://foursquare.com/v/gyukaku-japanese-bbq/48208c8cf964a520894f1fe3',
#    'categories': [{'id': '4bf58dd8d48988d111941735',
#      'name': 'Japanese Restaurant',
#      'pluralName': 'Japanese Restaurants',
#      'shortName': 'Japanese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#       'suffix': '.png'},
#      'primary': True},
#     {'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'}}],
#    'verified': True,
#    'stats': {'tipCount': 161},
#    'url': 'http://www.gyu-kaku.com',
#    'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#    'hasMenu': True,
#    'likes': {'count': 487,
#     'groups': [{'type': 'others', 'count': 487, 'items': []}],
#     'summary': '487 Likes'},
#    'dislike': False,
#    'ok': False,
#    'rating': 8.6,
#    'ratingColor': '73CF42',
#    'ratingSignals': 682,
#    'delivery': {'id': '2251148',
#     'url': 'https://www.seamless.com/menu/gyu-kaku-japanese-bbq-805-3rd-ave-new-york/2251148?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2251148',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'menu': {'type': 'Menu',
#     'label': 'Menu',
#     'anchor': 'View Menu',
#     'url': 'https://foursquare.com/v/gyukaku-japanese-bbq/48208c8cf964a520894f1fe3/menu',
#     'mobileUrl': 'https://foursquare.com/v/48208c8cf964a520894f1fe3/device_menu'},
#    'allowMenuUrlEdit': True,
#    'beenHere': {'count': 0,
#     'unconfirmedCount': 0,
#     'marked': False,
#     'lastCheckinExpiredAt': 0},
#    'specials': {'count': 0, 'items': []},
#    'photos': {'count': 803,
#     'groups': [{'type': 'venue',
#       'name': 'Venue photos',
#       'count': 803,
#       'items': [{'id': '51e5d813498ebe6d1356b102',
#         'createdAt': 1374017555,
#         'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#         'prefix': 'https://fastly.4sqi.net/img/general/',
#         'suffix': '/3214562_E3kc33tBQtbzSaA29nWFVBI91uwZxNRfC69z4KXcV0c.jpg',
#         'width': 612,
#         'height': 612,
#         'user': {'isSanctioned': False,
#          'firstName': 'Misshattan',
#          'countryCode': 'US'},
#         'visibility': 'public'}]}]},
#    'reasons': {'count': 1,
#     'items': [{'summary': 'Lots of people like this place',
#       'type': 'general',
#       'reasonName': 'rawLikesReason'}]},
#    'description': 'Midtown, New York, NY',
#    'storeId': '',
#    'page': {'pageInfo': {'banner': 'https://is1.4sqi.net/userpix/WMLPYZJ41UHNMXPQ.jpg',
#      'links': {'count': 1, 'items': [{'url': 'http://www.gyu-kaku.com'}]}},
#     'user': {'isSanctioned': False,
#      'firstName': 'Gyu-Kaku Japanese BBQ',
#      'countryCode': 'US',
#      'type': 'chain',
#      'tips': {'count': 76},
#      'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#      'bio': ''}},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'createdAt': 1210092684,
#    'tips': {'count': 161,
#     'groups': [{'type': 'others',
#       'name': 'All tips',
#       'count': 161,
#       'items': [{'id': '4f00fcab77c885c336c5a52b',
#         'createdAt': 1325464747,
#         'text': 'This place is absurdly amazing. Go with a group and order their kobe beef combos for the best experience. Servers tip you on the best way to cook your meal and the Bibimbap is life altering.',
#         'type': 'user',
#         'canonicalUrl': 'https://foursquare.com/item/4f00fcab77c885c336c5a52b',
#         'lang': 'en',
#         'likes': {'count': 7,
#          'groups': [{'type': 'others',
#            'count': 7,
#            'items': [{'isSanctioned': False,
#              'firstName': 'Steph',
#              'lastName': 'O',
#              'countryCode': 'US'},
#             {'isSanctioned': False,
#              'firstName': 'Max',
#              'lastName': 'F',
#              'countryCode': 'US'},
#             {'isSanctioned': False,
#              'firstName': 'Daniel',
#              'lastName': 'P',
#              'countryCode': 'MX'},
#             {'isSanctioned': False,
#              'firstName': 'Suzie Q',
#              'countryCode': 'US'}]}],
#          'summary': '7 likes'},
#         'logView': True,
#         'agreeCount': 7,
#         'disagreeCount': 0,
#         'todo': {'count': 0},
#         'user': {'isSanctioned': False,
#          'firstName': 'Tony',
#          'lastName': 'X',
#          'countryCode': 'US'}}]}]},
#    'shortUrl': 'http://4sq.com/7gtoft',
#    'timeZone': 'America/New_York',
#    'listed': {'count': 423,
#     'groups': [{'type': 'others',
#       'name': 'Lists from other people',
#       'count': 423,
#       'items': [{'id': '4f556977e4b072b51d48d5c7',
#         'name': 'BBQ Porky Venue',
#         'description': '',
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'SMKN 5 Pandeglang',
#          'countryCode': 'ID',
#          'type': 'page'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/smkn5pandeglang/list/bbq-porky-venue',
#         'canonicalUrl': 'https://foursquare.com/smkn5pandeglang/list/bbq-porky-venue',
#         'createdAt': 1330997623,
#         'updatedAt': 1335348759,
#         'photo': {'id': '4f529ab0e4b07de37bc53cad',
#          'createdAt': 1330813616,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/MQrV1MMASycDKtFvkUBvHqN727phnoOjWN3viOyUwJU.jpg',
#          'width': 540,
#          'height': 720,
#          'user': {'isSanctioned': False,
#           'firstName': 'Chicago',
#           'lastName': 'G',
#           'countryCode': 'US'},
#          'visibility': 'public'},
#         'logView': True,
#         'followers': {'count': 34},
#         'listItems': {'count': 31,
#          'items': [{'id': 'v48208c8cf964a520894f1fe3',
#            'createdAt': 1330998416}]}},
#        {'id': '4f636ec7e4b0e78cff99bf86',
#         'name': 'The 3-Hour Lunch',
#         'description': '',
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'Andy',
#          'lastName': 'B',
#          'countryCode': 'US'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/dtandyb/list/the-3hour-lunch',
#         'canonicalUrl': 'https://foursquare.com/dtandyb/list/the-3hour-lunch',
#         'createdAt': 1331916487,
#         'updatedAt': 1467908092,
#         'followers': {'count': 64},
#         'listItems': {'count': 32,
#          'items': [{'id': 'v48208c8cf964a520894f1fe3',
#            'createdAt': 1430159682}]}},
#        {'id': '4fcbfacde4b08a3653abba20',
#         'name': 'Japan In New York',
#         'description': 'おいしい!!!!!',
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'Leigh',
#          'lastName': 'Q',
#          'countryCode': 'US'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/user/20574446/list/japan-in-new-york',
#         'canonicalUrl': 'https://foursquare.com/user/20574446/list/japan-in-new-york',
#         'createdAt': 1338768077,
#         'updatedAt': 1522452184,
#         'photo': {'id': '513b91abe4b0f8b1fb5b2e4d',
#          'createdAt': 1362858411,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/17614304_PeG2nCgBOrH5ASqNSog-uxFjw0Z0Z85X0phNPbVymd8.jpg',
#          'width': 960,
#          'height': 720,
#          'user': {'isSanctioned': False,
#           'firstName': 'Laurie',
#           'lastName': 'G',
#           'countryCode': 'US'},
#          'visibility': 'public'},
#         'followers': {'count': 43},
#         'listItems': {'count': 221,
#          'items': [{'id': 'v48208c8cf964a520894f1fe3',
#            'createdAt': 1453999675}]}},
#        {'id': '4e665a9dd164ddd5e76a695e',
#         'name': 'New York',
#         'description': '',
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'Tomohiro',
#          'lastName': 'G',
#          'countryCode': 'JP'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/miyamuweb/list/new-york',
#         'canonicalUrl': 'https://foursquare.com/miyamuweb/list/new-york',
#         'createdAt': 1315330717,
#         'updatedAt': 1399809574,
#         'photo': {'id': '4e3ae6541838961aff05ac18',
#          'createdAt': 1312482900,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/TINWCWPA31OVKY5FUJ5K13QTKPVHTJY0CJD3BVEGRTYWSI1K.jpg',
#          'width': 537,
#          'height': 720,
#          'user': {'isSanctioned': False,
#           'firstName': 'Daniela',
#           'lastName': 'A',
#           'countryCode': 'US'},
#          'visibility': 'public'},
#         'followers': {'count': 135},
#         'listItems': {'count': 73,
#          'items': [{'id': 'v48208c8cf964a520894f1fe3',
#            'createdAt': 1317647908,
#            'photo': {'id': '4e73aa3c8998f94a5866ca8b',
#             'createdAt': 1316203068,
#             'prefix': 'https://fastly.4sqi.net/img/general/',
#             'suffix': '/LONUIGQ0SCP0ZSQZ2QEJGTJ4SPMR2FUW0DTEDJT3KNJKNPXP.jpg',
#             'width': 460,
#             'height': 345,
#             'user': {'isSanctioned': False,
#              'firstName': 'Josean',
#              'lastName': 'P',
#              'countryCode': 'US'},
#             'visibility': 'public'}}]}}]}]},
#    'hours': {'status': 'Open until 11:00 PM',
#     'richStatus': {'entities': [], 'text': 'Open until 11:00 PM'},
#     'isOpen': True,
#     'isLocalHoliday': True,
#     'localHolidayName': 'Thanksgiving Day',
#     'dayData': [],
#     'timeframes': [{'days': 'Mon–Thu',
#       'includesToday': True,
#       'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#       'segments': []},
#      {'days': 'Fri–Sat',
#       'open': [{'renderedTime': '11:30 AM–Midnight'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': '11:30 AM–10:00 PM'}],
#       'segments': []}]},
#    'popular': {'status': 'Likely open',
#     'richStatus': {'entities': [], 'text': 'Likely open'},
#     'isOpen': True,
#     'isLocalHoliday': True,
#     'localHolidayName': 'Thanksgiving Day',
#     'timeframes': [{'days': 'Today',
#       'includesToday': True,
#       'open': [{'renderedTime': 'Noon–2:00 PM'},
#        {'renderedTime': '5:00 PM–11:00 PM'}],
#       'segments': []},
#      {'days': 'Fri–Sat',
#       'open': [{'renderedTime': 'Noon–11:00 PM'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': 'Noon–9:00 PM'}],
#       'segments': []},
#      {'days': 'Mon',
#       'open': [{'renderedTime': 'Noon–1:00 PM'},
#        {'renderedTime': '5:00 PM–10:00 PM'}],
#       'segments': []},
#      {'days': 'Tue–Wed',
#       'open': [{'renderedTime': 'Noon–2:00 PM'},
#        {'renderedTime': '5:00 PM–11:00 PM'}],
#       'segments': []}]},
#    'seasonalHours': [],
#    'defaultHours': {'status': 'Open until 11:00 PM',
#     'richStatus': {'entities': [], 'text': 'Open until 11:00 PM'},
#     'isOpen': True,
#     'isLocalHoliday': True,
#     'localHolidayName': 'Thanksgiving Day',
#     'dayData': [],
#     'timeframes': [{'days': 'Mon–Thu',
#       'includesToday': True,
#       'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#       'segments': []},
#      {'days': 'Fri–Sat',
#       'open': [{'renderedTime': '11:30 AM–Midnight'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': '11:30 AM–10:00 PM'}],
#       'segments': []}]},
#    'pageUpdates': {'count': 0, 'items': []},
#    'inbox': {'count': 0, 'items': []},
#    'attributes': {'groups': [{'type': 'price',
#       'name': 'Price',
#       'summary': '$$',
#       'count': 1,
#       'items': [{'displayName': 'Price',
#         'displayValue': '$$',
#         'priceTier': 2}]},
#      {'type': 'payments',
#       'name': 'Credit Cards',
#       'summary': 'Credit Cards',
#       'count': 7,
#       'items': [{'displayName': 'Credit Cards',
#         'displayValue': 'Yes (incl. Discover & Visa)'}]},
#      {'type': 'outdoorSeating',
#       'name': 'Outdoor Seating',
#       'count': 1,
#       'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]},
#      {'type': 'music',
#       'name': 'Music',
#       'summary': 'Music',
#       'count': 3,
#       'items': [{'displayName': 'Music', 'displayValue': 'Yes'}]},
#      {'type': 'wifi',
#       'name': 'Wi-Fi',
#       'summary': 'Wi-Fi',
#       'count': 1,
#       'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Yes'}]},
#      {'type': 'serves',
#       'name': 'Menus',
#       'summary': 'Happy Hour, Dinner & more',
#       'count': 8,
#       'items': [{'displayName': 'Lunch', 'displayValue': 'Lunch'},
#        {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#        {'displayName': 'Happy Hour', 'displayValue': 'Happy Hour'}]},
#      {'type': 'drinks',
#       'name': 'Drinks',
#       'summary': 'Beer, Full Bar & Cocktails',
#       'count': 5,
#       'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
#        {'displayName': 'Full Bar', 'displayValue': 'Full Bar'},
#        {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}]},
#      {'type': 'diningOptions',
#       'name': 'Dining Options',
#       'summary': 'Take-out & Delivery',
#       'count': 5,
#       'items': [{'displayName': 'Take-out', 'displayValue': 'Take-out'},
#        {'displayName': 'Delivery', 'displayValue': 'Delivery'}]},
#      {'type': 'parking',
#       'name': 'Parking',
#       'summary': 'Street Parking',
#       'count': 5,
#       'items': [{'displayName': 'Street Parking', 'displayValue': 'Street'}]},
#      {'type': 'restroom',
#       'name': 'Restroom',
#       'summary': 'Restroom',
#       'count': 1,
#       'items': [{'displayName': 'Restroom', 'displayValue': 'Yes'}]},
#      {'type': 'wheelchairAccessible',
#       'name': 'Wheelchair Accessible',
#       'summary': 'Wheelchair Accessible',
#       'count': 1,
#       'items': [{'displayName': 'Wheelchair Accessible',
#         'displayValue': 'Yes'}]}]},
#    'bestPhoto': {'id': '51e5d813498ebe6d1356b102',
#     'createdAt': 1374017555,
#     'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#     'prefix': 'https://fastly.4sqi.net/img/general/',
#     'suffix': '/3214562_E3kc33tBQtbzSaA29nWFVBI91uwZxNRfC69z4KXcV0c.jpg',
#     'width': 612,
#     'height': 612,
#     'visibility': 'public'},
#    'colors': {'highlightColor': {'photoId': '51e5d813498ebe6d1356b102',
#      'value': -12566464},
#     'highlightTextColor': {'photoId': '51e5d813498ebe6d1356b102', 'value': -1},
#     'algoVersion': 3}}}}

# %%
#Vamos a definir la variable venues

venues=resultJapanese1["response"]["venue"]
venues
# Out:
# {'id': '48208c8cf964a520894f1fe3',
#  'name': 'Gyu-Kaku Japanese BBQ',
#  'contact': {'phone': '2127028816',
#   'formattedPhone': '(212) 702-8816',
#   'twitter': 'gyukakujbbq',
#   'facebook': '107675045957918',
#   'facebookUsername': 'GyuKakuMidtownNY',
#   'facebookName': 'Gyu-Kaku Japanese BBQ'},
#  'location': {'address': '805 3rd Ave',
#   'crossStreet': 'btwn E 49th & E 50th St',
#   'lat': 40.755730504250046,
#   'lng': -73.9708969487331,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.755730504250046,
#     'lng': -73.9708969487331}],
#   'postalCode': '10022',
#   'cc': 'US',
#   'city': 'New York',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['805 3rd Ave (btwn E 49th & E 50th St)',
#    'New York, NY 10022',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/gyukaku-japanese-bbq/48208c8cf964a520894f1fe3',
#  'categories': [{'id': '4bf58dd8d48988d111941735',
#    'name': 'Japanese Restaurant',
#    'pluralName': 'Japanese Restaurants',
#    'shortName': 'Japanese',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d1df931735',
#    'name': 'BBQ Joint',
#    'pluralName': 'BBQ Joints',
#    'shortName': 'BBQ',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#     'suffix': '.png'}}],
#  'verified': True,
#  'stats': {'tipCount': 161},
#  'url': 'http://www.gyu-kaku.com',
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'hasMenu': True,
#  'likes': {'count': 487,
#   'groups': [{'type': 'others', 'count': 487, 'items': []}],
#   'summary': '487 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 8.6,
#  'ratingColor': '73CF42',
#  'ratingSignals': 682,
#  'delivery': {'id': '2251148',
#   'url': 'https://www.seamless.com/menu/gyu-kaku-japanese-bbq-805-3rd-ave-new-york/2251148?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2251148',
#   'provider': {'name': 'seamless',
#    'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#     'sizes': [40, 50],
#     'name': '/delivery_provider_seamless_20180129.png'}}},
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'https://foursquare.com/v/gyukaku-japanese-bbq/48208c8cf964a520894f1fe3/menu',
#   'mobileUrl': 'https://foursquare.com/v/48208c8cf964a520894f1fe3/device_menu'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 803,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 803,
#     'items': [{'id': '51e5d813498ebe6d1356b102',
#       'createdAt': 1374017555,
#       'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/3214562_E3kc33tBQtbzSaA29nWFVBI91uwZxNRfC69z4KXcV0c.jpg',
#       'width': 612,
#       'height': 612,
#       'user': {'isSanctioned': False,
#        'firstName': 'Misshattan',
#        'countryCode': 'US'},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'description': 'Midtown, New York, NY',
#  'storeId': '',
#  'page': {'pageInfo': {'banner': 'https://is1.4sqi.net/userpix/WMLPYZJ41UHNMXPQ.jpg',
#    'links': {'count': 1, 'items': [{'url': 'http://www.gyu-kaku.com'}]}},
#   'user': {'isSanctioned': False,
#    'firstName': 'Gyu-Kaku Japanese BBQ',
#    'countryCode': 'US',
#    'type': 'chain',
#    'tips': {'count': 76},
#    'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#    'bio': ''}},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1210092684,
#  'tips': {'count': 161,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 161,
#     'items': [{'id': '4f00fcab77c885c336c5a52b',
#       'createdAt': 1325464747,
#       'text': 'This place is absurdly amazing. Go with a group and order their kobe beef combos for the best experience. Servers tip you on the best way to cook your meal and the Bibimbap is life altering.',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4f00fcab77c885c336c5a52b',
#       'lang': 'en',
#       'likes': {'count': 7,
#        'groups': [{'type': 'others',
#          'count': 7,
#          'items': [{'isSanctioned': False,
#            'firstName': 'Steph',
#            'lastName': 'O',
#            'countryCode': 'US'},
#           {'isSanctioned': False,
#            'firstName': 'Max',
#            'lastName': 'F',
#            'countryCode': 'US'},
#           {'isSanctioned': False,
#            'firstName': 'Daniel',
#            'lastName': 'P',
#            'countryCode': 'MX'},
#           {'isSanctioned': False,
#            'firstName': 'Suzie Q',
#            'countryCode': 'US'}]}],
#        'summary': '7 likes'},
#       'logView': True,
#       'agreeCount': 7,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'isSanctioned': False,
#        'firstName': 'Tony',
#        'lastName': 'X',
#        'countryCode': 'US'}}]}]},
#  'shortUrl': 'http://4sq.com/7gtoft',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 423,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 423,
#     'items': [{'id': '4f556977e4b072b51d48d5c7',
#       'name': 'BBQ Porky Venue',
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'SMKN 5 Pandeglang',
#        'countryCode': 'ID',
#        'type': 'page'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/smkn5pandeglang/list/bbq-porky-venue',
#       'canonicalUrl': 'https://foursquare.com/smkn5pandeglang/list/bbq-porky-venue',
#       'createdAt': 1330997623,
#       'updatedAt': 1335348759,
#       'photo': {'id': '4f529ab0e4b07de37bc53cad',
#        'createdAt': 1330813616,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/MQrV1MMASycDKtFvkUBvHqN727phnoOjWN3viOyUwJU.jpg',
#        'width': 540,
#        'height': 720,
#        'user': {'isSanctioned': False,
#         'firstName': 'Chicago',
#         'lastName': 'G',
#         'countryCode': 'US'},
#        'visibility': 'public'},
#       'logView': True,
#       'followers': {'count': 34},
#       'listItems': {'count': 31,
#        'items': [{'id': 'v48208c8cf964a520894f1fe3',
#          'createdAt': 1330998416}]}},
#      {'id': '4f636ec7e4b0e78cff99bf86',
#       'name': 'The 3-Hour Lunch',
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Andy',
#        'lastName': 'B',
#        'countryCode': 'US'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/dtandyb/list/the-3hour-lunch',
#       'canonicalUrl': 'https://foursquare.com/dtandyb/list/the-3hour-lunch',
#       'createdAt': 1331916487,
#       'updatedAt': 1467908092,
#       'followers': {'count': 64},
#       'listItems': {'count': 32,
#        'items': [{'id': 'v48208c8cf964a520894f1fe3',
#          'createdAt': 1430159682}]}},
#      {'id': '4fcbfacde4b08a3653abba20',
#       'name': 'Japan In New York',
#       'description': 'おいしい!!!!!',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Leigh',
#        'lastName': 'Q',
#        'countryCode': 'US'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/20574446/list/japan-in-new-york',
#       'canonicalUrl': 'https://foursquare.com/user/20574446/list/japan-in-new-york',
#       'createdAt': 1338768077,
#       'updatedAt': 1522452184,
#       'photo': {'id': '513b91abe4b0f8b1fb5b2e4d',
#        'createdAt': 1362858411,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/17614304_PeG2nCgBOrH5ASqNSog-uxFjw0Z0Z85X0phNPbVymd8.jpg',
#        'width': 960,
#        'height': 720,
#        'user': {'isSanctioned': False,
#         'firstName': 'Laurie',
#         'lastName': 'G',
#         'countryCode': 'US'},
#        'visibility': 'public'},
#       'followers': {'count': 43},
#       'listItems': {'count': 221,
#        'items': [{'id': 'v48208c8cf964a520894f1fe3',
#          'createdAt': 1453999675}]}},
#      {'id': '4e665a9dd164ddd5e76a695e',
#       'name': 'New York',
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Tomohiro',
#        'lastName': 'G',
#        'countryCode': 'JP'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/miyamuweb/list/new-york',
#       'canonicalUrl': 'https://foursquare.com/miyamuweb/list/new-york',
#       'createdAt': 1315330717,
#       'updatedAt': 1399809574,
#       'photo': {'id': '4e3ae6541838961aff05ac18',
#        'createdAt': 1312482900,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/TINWCWPA31OVKY5FUJ5K13QTKPVHTJY0CJD3BVEGRTYWSI1K.jpg',
#        'width': 537,
#        'height': 720,
#        'user': {'isSanctioned': False,
#         'firstName': 'Daniela',
#         'lastName': 'A',
#         'countryCode': 'US'},
#        'visibility': 'public'},
#       'followers': {'count': 135},
#       'listItems': {'count': 73,
#        'items': [{'id': 'v48208c8cf964a520894f1fe3',
#          'createdAt': 1317647908,
#          'photo': {'id': '4e73aa3c8998f94a5866ca8b',
#           'createdAt': 1316203068,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/LONUIGQ0SCP0ZSQZ2QEJGTJ4SPMR2FUW0DTEDJT3KNJKNPXP.jpg',
#           'width': 460,
#           'height': 345,
#           'user': {'isSanctioned': False,
#            'firstName': 'Josean',
#            'lastName': 'P',
#            'countryCode': 'US'},
#           'visibility': 'public'}}]}}]}]},
#  'hours': {'status': 'Open until 11:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 11:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': True,
#   'localHolidayName': 'Thanksgiving Day',
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Thu',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Fri–Sat',
#     'open': [{'renderedTime': '11:30 AM–Midnight'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '11:30 AM–10:00 PM'}],
#     'segments': []}]},
#  'popular': {'status': 'Likely open',
#   'richStatus': {'entities': [], 'text': 'Likely open'},
#   'isOpen': True,
#   'isLocalHoliday': True,
#   'localHolidayName': 'Thanksgiving Day',
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Fri–Sat',
#     'open': [{'renderedTime': 'Noon–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sun', 'open': [{'renderedTime': 'Noon–9:00 PM'}], 'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': 'Noon–1:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Tue–Wed',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'defaultHours': {'status': 'Open until 11:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 11:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': True,
#   'localHolidayName': 'Thanksgiving Day',
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Thu',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Fri–Sat',
#     'open': [{'renderedTime': '11:30 AM–Midnight'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '11:30 AM–10:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. Discover & Visa)'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]},
#    {'type': 'music',
#     'name': 'Music',
#     'summary': 'Music',
#     'count': 3,
#     'items': [{'displayName': 'Music', 'displayValue': 'Yes'}]},
#    {'type': 'wifi',
#     'name': 'Wi-Fi',
#     'summary': 'Wi-Fi',
#     'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Yes'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Happy Hour, Dinner & more',
#     'count': 8,
#     'items': [{'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#      {'displayName': 'Happy Hour', 'displayValue': 'Happy Hour'}]},
#    {'type': 'drinks',
#     'name': 'Drinks',
#     'summary': 'Beer, Full Bar & Cocktails',
#     'count': 5,
#     'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
#      {'displayName': 'Full Bar', 'displayValue': 'Full Bar'},
#      {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'summary': 'Take-out & Delivery',
#     'count': 5,
#     'items': [{'displayName': 'Take-out', 'displayValue': 'Take-out'},
#      {'displayName': 'Delivery', 'displayValue': 'Delivery'}]},
#    {'type': 'parking',
#     'name': 'Parking',
#     'summary': 'Street Parking',
#     'count': 5,
#     'items': [{'displayName': 'Street Parking', 'displayValue': 'Street'}]},
#    {'type': 'restroom',
#     'name': 'Restroom',
#     'summary': 'Restroom',
#     'count': 1,
#     'items': [{'displayName': 'Restroom', 'displayValue': 'Yes'}]},
#    {'type': 'wheelchairAccessible',
#     'name': 'Wheelchair Accessible',
#     'summary': 'Wheelchair Accessible',
#     'count': 1,
#     'items': [{'displayName': 'Wheelchair Accessible',
#       'displayValue': 'Yes'}]}]},
#  'bestPhoto': {'id': '51e5d813498ebe6d1356b102',
#   'createdAt': 1374017555,
#   'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/3214562_E3kc33tBQtbzSaA29nWFVBI91uwZxNRfC69z4KXcV0c.jpg',
#   'width': 612,
#   'height': 612,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '51e5d813498ebe6d1356b102',
#    'value': -12566464},
#   'highlightTextColor': {'photoId': '51e5d813498ebe6d1356b102', 'value': -1},
#   'algoVersion': 3}}

# %%
#En caso de que este calificado, ponemos que muestre la puntuación del restaurante.
#En caso contrario, mostrar un mensaje de que "este lugar no ha sido puntuado aún"

try:
    print(resultJapanese1["response"]["venue"]["rating"])
except:
    print("This venue has not been rated yet.")
# Out:
# 8.6

# %%
#A continuación, vamos a explorar otro restaurante japonés. 2 restaurante "Sakagura"

venue_id="407f2200f964a5207df21ee3"
url = "https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}".format(venue_id, CLIENT_ID,
CLIENT_SECRET, VERSION)
print("Todo ha salido correcto")
# Out:
# Todo ha salido correcto

# %%
#Enviemos la solicitud del get para el resultado

resultJapanese2 = requests.get(url).json()
resultJapanese2
# Out:
# {'meta': {'code': 200, 'requestId': '5fc073149a95b82e63725889'},
#  'response': {'venue': {'id': '407f2200f964a5207df21ee3',
#    'name': 'Sakagura',
#    'contact': {'phone': '2129537253', 'formattedPhone': '(212) 953-7253'},
#    'location': {'address': '211 E 43rd St Lowr Level',
#     'crossStreet': 'btwn 2nd & 3rd Ave',
#     'lat': 40.751304870459144,
#     'lng': -73.9733141805895,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.751304870459144,
#       'lng': -73.9733141805895}],
#     'postalCode': '10017',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['211 E 43rd St Lowr Level (btwn 2nd & 3rd Ave)',
#      'New York, NY 10017',
#      'United States']},
#    'canonicalUrl': 'https://foursquare.com/v/sakagura/407f2200f964a5207df21ee3',
#    'categories': [{'id': '4bf58dd8d48988d11c941735',
#      'name': 'Sake Bar',
#      'pluralName': 'Sake Bars',
#      'shortName': 'Sake Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sake_',
#       'suffix': '.png'},
#      'primary': True},
#     {'id': '4bf58dd8d48988d111941735',
#      'name': 'Japanese Restaurant',
#      'pluralName': 'Japanese Restaurants',
#      'shortName': 'Japanese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#       'suffix': '.png'}}],
#    'verified': True,
#    'stats': {'tipCount': 221},
#    'url': 'http://www.sakagura.com',
#    'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'},
#    'hasMenu': True,
#    'likes': {'count': 588,
#     'groups': [{'type': 'others', 'count': 588, 'items': []}],
#     'summary': '588 Likes'},
#    'dislike': False,
#    'ok': False,
#    'rating': 9.0,
#    'ratingColor': '00B551',
#    'ratingSignals': 779,
#    'menu': {'type': 'Menu',
#     'label': 'Menu',
#     'anchor': 'View Menu',
#     'url': 'https://foursquare.com/v/sakagura/407f2200f964a5207df21ee3/menu',
#     'mobileUrl': 'https://foursquare.com/v/407f2200f964a5207df21ee3/device_menu'},
#    'allowMenuUrlEdit': True,
#    'beenHere': {'count': 0,
#     'unconfirmedCount': 0,
#     'marked': False,
#     'lastCheckinExpiredAt': 0},
#    'specials': {'count': 0, 'items': []},
#    'photos': {'count': 740,
#     'groups': [{'type': 'venue',
#       'name': 'Venue photos',
#       'count': 740,
#       'items': [{'id': '508b65efe4b0a1c84722f185',
#         'createdAt': 1351312879,
#         'source': {'name': 'Foursquare for iOS',
#          'url': 'https://foursquare.com/download/#/iphone'},
#         'prefix': 'https://fastly.4sqi.net/img/general/',
#         'suffix': '/22998173_V2m6-bIXuZg38oQW2eilhCK4H3hy2Kuf8kvLPFnl3-0.jpg',
#         'width': 537,
#         'height': 720,
#         'user': {'isSanctioned': False,
#          'firstName': 'Ellen C',
#          'countryCode': 'US'},
#         'visibility': 'public'}]}]},
#    'venuePage': {'id': '71886455'},
#    'reasons': {'count': 1,
#     'items': [{'summary': 'Lots of people like this place',
#       'type': 'general',
#       'reasonName': 'rawLikesReason'}]},
#    'description': 'Sakagura was founded in 1996 and has become one of the top sake bars in the United States, attracting countless sake lovers. When you visit our unique location in the basement of a Midtown East office building, you’ll understand why we have earned the nickname “hidden jewel.”',
#    'storeId': '',
#    'page': {'user': {'isSanctioned': False,
#      'firstName': 'Sakagura',
#      'countryCode': 'US',
#      'type': 'venuePage',
#      'venue': {'id': '407f2200f964a5207df21ee3'},
#      'tips': {'count': 0},
#      'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#      'bio': ''}},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'createdAt': 1082073600,
#    'tips': {'count': 221,
#     'groups': [{'type': 'others',
#       'name': 'All tips',
#       'count': 221,
#       'items': [{'id': '4a5bd67470c603bbd6398eb4',
#         'createdAt': 1247532660,
#         'text': 'best izakaya-style Japanese food in the city',
#         'type': 'user',
#         'canonicalUrl': 'https://foursquare.com/item/4a5bd67470c603bbd6398eb4',
#         'lang': 'en',
#         'likes': {'count': 13,
#          'groups': [{'type': 'others', 'count': 13, 'items': []}],
#          'summary': '13 likes'},
#         'logView': True,
#         'agreeCount': 2,
#         'disagreeCount': 0,
#         'todo': {'count': 3},
#         'user': {'isSanctioned': False,
#          'firstName': 'Miko',
#          'lastName': 'M',
#          'countryCode': 'US'}}]}]},
#    'shortUrl': 'http://4sq.com/4u8pub',
#    'timeZone': 'America/New_York',
#    'listed': {'count': 1791,
#     'groups': [{'type': 'others',
#       'name': 'Lists from other people',
#       'count': 1791,
#       'items': [{'id': '4ec3dce68231d4c9fee0567b',
#         'name': "NYC's Midtown",
#         'description': 'The most visited area of Manhattan and the headquarters for dozens of well known companies, Midtown has much to offer, from hidden restaurants to popular attractions.  Discover our favorites here.',
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'New York Habitat',
#          'countryCode': 'US',
#          'type': 'chain'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/newyorkhabitat/list/nycs-midtown',
#         'canonicalUrl': 'https://foursquare.com/newyorkhabitat/list/nycs-midtown',
#         'createdAt': 1321458918,
#         'updatedAt': 1337625780,
#         'photo': {'id': '4ecfc555e3007feb7caec837',
#          'createdAt': 1322239317,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/GYOLBUQJQ0MBHSJ5TKFL0XYBTDD43KPTNTHDQKP3GZSYKLAD.jpg',
#          'width': 537,
#          'height': 720,
#          'user': {'isSanctioned': False,
#           'firstName': 'Jason',
#           'lastName': 'H',
#           'countryCode': 'US'},
#          'visibility': 'public'},
#         'logView': True,
#         'followers': {'count': 737},
#         'listItems': {'count': 76,
#          'items': [{'id': 't4ed90784775bcc53f8d92290',
#            'createdAt': 1322846088,
#            'photo': {'id': '4eb6b0e15c5c5a53208b341e',
#             'createdAt': 1320595681,
#             'prefix': 'https://fastly.4sqi.net/img/general/',
#             'suffix': '/JTPZIU3FK0MMXLHPBJYC2JUGVVVIK4A0XBYS1KSVACCBPT34.jpg',
#             'width': 720,
#             'height': 537,
#             'user': {'isSanctioned': False,
#              'firstName': 'Sara',
#              'lastName': 'Z',
#              'countryCode': 'US'},
#             'visibility': 'public'}}]}},
#        {'id': '50a695c9e4b06baebe3d94fe',
#         'name': 'Hidden Bars & Restaurants in NYC',
#         'description': 'This list will get you beyond the trendy to some of the more unique hidden restaurants in New York City.',
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'Untapped Cities',
#          'countryCode': 'US',
#          'type': 'page'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/untappedcities/list/hidden-bars--restaurants-in-nyc',
#         'canonicalUrl': 'https://foursquare.com/untappedcities/list/hidden-bars--restaurants-in-nyc',
#         'createdAt': 1353094601,
#         'updatedAt': 1447347530,
#         'photo': {'id': '50a69836fe70df02fd35a0a6',
#          'createdAt': 1353095222,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/24933846_EnR1USgozVR5ZlOgw5pMWEddtmJRIZzeeZpSFSm_yIw.jpg',
#          'width': 575,
#          'height': 357,
#          'user': {'isSanctioned': False,
#           'firstName': 'Untapped Cities',
#           'countryCode': 'US',
#           'type': 'page'},
#          'visibility': 'public'},
#         'logView': True,
#         'followers': {'count': 1312},
#         'listItems': {'count': 43,
#          'items': [{'id': 't5644c3b2498eb8eddd31b98f',
#            'createdAt': 1447347498}]}},
#        {'id': '4f06192a0e0199f87c8392e4',
#         'name': 'Quick, I need a date spot.',
#         'description': 'My favorite date spots in various neighborhoods at various price points. Some trendy, some hidden, all relatively calm and civilized.',
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'Dan',
#          'lastName': 'K',
#          'countryCode': 'US'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/user/23355/list/quick-i-need-a-date-spot',
#         'canonicalUrl': 'https://foursquare.com/user/23355/list/quick-i-need-a-date-spot',
#         'createdAt': 1325799722,
#         'updatedAt': 1583879230,
#         'photo': {'id': '4eadcfc9490170218c74db8a',
#          'createdAt': 1320013769,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/Y1KLPFVKNEKQLS5GW4MW42JKAG3DZY32HXKPVAJKDH2ED4AM.jpg',
#          'width': 612,
#          'height': 612,
#          'user': {'isSanctioned': False,
#           'firstName': 'Ben',
#           'countryCode': 'US'},
#          'visibility': 'public'},
#         'followers': {'count': 842},
#         'listItems': {'count': 204,
#          'items': [{'id': 'v407f2200f964a5207df21ee3',
#            'createdAt': 1325799744,
#            'photo': {'id': '4ed1b175490168f8d17248fd',
#             'createdAt': 1322365301,
#             'prefix': 'https://fastly.4sqi.net/img/general/',
#             'suffix': '/V0SWEYQGJUKWKHJWT2J1BWLJTOUAXTC0A0VWG0TSVCOXALAK.jpg',
#             'width': 720,
#             'height': 431,
#             'user': {'isSanctioned': False,
#              'firstName': 'Winnie',
#              'lastName': 'D',
#              'countryCode': 'US'},
#             'visibility': 'public'}}]}},
#        {'id': '4ff63dd2e4b01a84ed428bd9',
#         'name': 'Speakeasy bars and secret restaurants in NYC',
#         'description': '',
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'Meng',
#          'lastName': 'H',
#          'countryCode': 'US'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/menghe/list/speakeasy-bars-and-secret-restaurants-in-nyc',
#         'canonicalUrl': 'https://foursquare.com/menghe/list/speakeasy-bars-and-secret-restaurants-in-nyc',
#         'createdAt': 1341537746,
#         'updatedAt': 1467205482,
#         'photo': {'id': '4ee26aab4fc6a6fab596014b',
#          'createdAt': 1323461291,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/Q3HOHYY4THONJUCUCJ5MCMSH1ORZJDO0Z5E4L0PXHUEXQKZQ.jpg',
#          'width': 220,
#          'height': 220,
#          'user': {'isSanctioned': False,
#           'firstName': 'AskMen',
#           'countryCode': 'US',
#           'type': 'page'},
#          'visibility': 'public'},
#         'followers': {'count': 935},
#         'listItems': {'count': 67,
#          'items': [{'id': 'v407f2200f964a5207df21ee3',
#            'createdAt': 1341537952}]}}]}]},
#    'hours': {'status': 'Open until Midnight',
#     'richStatus': {'entities': [], 'text': 'Open until Midnight'},
#     'isOpen': True,
#     'isLocalHoliday': True,
#     'localHolidayName': 'Thanksgiving Day',
#     'dayData': [],
#     'timeframes': [{'days': 'Mon–Thu',
#       'includesToday': True,
#       'open': [{'renderedTime': '11:30 AM–2:20 PM'},
#        {'renderedTime': '6:00 PM–Midnight'}],
#       'segments': []},
#      {'days': 'Fri',
#       'open': [{'renderedTime': '11:30 AM–2:20 PM'},
#        {'renderedTime': '6:00 PM–1:00 AM'}],
#       'segments': []},
#      {'days': 'Sat',
#       'open': [{'renderedTime': '6:00 PM–1:00 AM'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': '6:00 PM–11:00 PM'}],
#       'segments': []}]},
#    'popular': {'status': 'Likely open',
#     'richStatus': {'entities': [], 'text': 'Likely open'},
#     'isOpen': True,
#     'isLocalHoliday': True,
#     'localHolidayName': 'Thanksgiving Day',
#     'timeframes': [{'days': 'Today',
#       'includesToday': True,
#       'open': [{'renderedTime': '11:00 AM–3:00 PM'},
#        {'renderedTime': '6:00 PM–11:00 PM'}],
#       'segments': []},
#      {'days': 'Fri',
#       'open': [{'renderedTime': '11:00 AM–3:00 PM'},
#        {'renderedTime': '6:00 PM–Midnight'}],
#       'segments': []},
#      {'days': 'Sat',
#       'open': [{'renderedTime': '6:00 PM–Midnight'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': '6:00 PM–11:00 PM'}],
#       'segments': []},
#      {'days': 'Mon–Wed',
#       'open': [{'renderedTime': '11:00 AM–3:00 PM'},
#        {'renderedTime': '6:00 PM–11:00 PM'}],
#       'segments': []}]},
#    'seasonalHours': [],
#    'defaultHours': {'status': 'Open until Midnight',
#     'richStatus': {'entities': [], 'text': 'Open until Midnight'},
#     'isOpen': True,
#     'isLocalHoliday': True,
#     'localHolidayName': 'Thanksgiving Day',
#     'dayData': [],
#     'timeframes': [{'days': 'Mon–Thu',
#       'includesToday': True,
#       'open': [{'renderedTime': '11:30 AM–2:20 PM'},
#        {'renderedTime': '6:00 PM–Midnight'}],
#       'segments': []},
#      {'days': 'Fri',
#       'open': [{'renderedTime': '11:30 AM–2:20 PM'},
#        {'renderedTime': '6:00 PM–1:00 AM'}],
#       'segments': []},
#      {'days': 'Sat',
#       'open': [{'renderedTime': '6:00 PM–1:00 AM'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': '6:00 PM–11:00 PM'}],
#       'segments': []}]},
#    'pageUpdates': {'count': 0, 'items': []},
#    'inbox': {'count': 0, 'items': []},
#    'attributes': {'groups': [{'type': 'price',
#       'name': 'Price',
#       'summary': '$$$',
#       'count': 1,
#       'items': [{'displayName': 'Price',
#         'displayValue': '$$$',
#         'priceTier': 3}]},
#      {'type': 'payments',
#       'name': 'Credit Cards',
#       'summary': 'Credit Cards',
#       'count': 7,
#       'items': [{'displayName': 'Credit Cards',
#         'displayValue': 'Yes (incl. American Express & MasterCard)'}]},
#      {'type': 'outdoorSeating',
#       'name': 'Outdoor Seating',
#       'count': 1,
#       'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]},
#      {'type': 'serves',
#       'name': 'Menus',
#       'summary': 'Dessert, Dinner & more',
#       'count': 8,
#       'items': [{'displayName': 'Lunch', 'displayValue': 'Lunch'},
#        {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#        {'displayName': 'Dessert', 'displayValue': 'Dessert'}]},
#      {'type': 'drinks',
#       'name': 'Drinks',
#       'summary': 'Full Bar',
#       'count': 5,
#       'items': [{'displayName': 'Full Bar', 'displayValue': 'Full Bar'}]},
#      {'type': 'parking',
#       'name': 'Parking',
#       'summary': 'Street Parking',
#       'count': 5,
#       'items': [{'displayName': 'Street Parking', 'displayValue': 'Street'}]},
#      {'type': 'restroom',
#       'name': 'Restroom',
#       'summary': 'Restroom',
#       'count': 1,
#       'items': [{'displayName': 'Restroom', 'displayValue': 'Yes'}]},
#      {'type': 'wheelchairAccessible',
#       'name': 'Wheelchair Accessible',
#       'summary': 'Wheelchair Accessible',
#       'count': 1,
#       'items': [{'displayName': 'Wheelchair Accessible',
#         'displayValue': 'Yes'}]}]},
#    'bestPhoto': {'id': '508b65efe4b0a1c84722f185',
#     'createdAt': 1351312879,
#     'source': {'name': 'Foursquare for iOS',
#      'url': 'https://foursquare.com/download/#/iphone'},
#     'prefix': 'https://fastly.4sqi.net/img/general/',
#     'suffix': '/22998173_V2m6-bIXuZg38oQW2eilhCK4H3hy2Kuf8kvLPFnl3-0.jpg',
#     'width': 537,
#     'height': 720,
#     'visibility': 'public'},
#    'colors': {'highlightColor': {'photoId': '508b65efe4b0a1c84722f185',
#      'value': -10477560},
#     'highlightTextColor': {'photoId': '508b65efe4b0a1c84722f185', 'value': -1},
#     'algoVersion': 0}}}}

# %%
#Definimos la variable venues
venues=resultJapanese2["response"]["venue"]
venues
# Out:
# {'id': '407f2200f964a5207df21ee3',
#  'name': 'Sakagura',
#  'contact': {'phone': '2129537253', 'formattedPhone': '(212) 953-7253'},
#  'location': {'address': '211 E 43rd St Lowr Level',
#   'crossStreet': 'btwn 2nd & 3rd Ave',
#   'lat': 40.751304870459144,
#   'lng': -73.9733141805895,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.751304870459144,
#     'lng': -73.9733141805895}],
#   'postalCode': '10017',
#   'cc': 'US',
#   'city': 'New York',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['211 E 43rd St Lowr Level (btwn 2nd & 3rd Ave)',
#    'New York, NY 10017',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/sakagura/407f2200f964a5207df21ee3',
#  'categories': [{'id': '4bf58dd8d48988d11c941735',
#    'name': 'Sake Bar',
#    'pluralName': 'Sake Bars',
#    'shortName': 'Sake Bar',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sake_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d111941735',
#    'name': 'Japanese Restaurant',
#    'pluralName': 'Japanese Restaurants',
#    'shortName': 'Japanese',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#     'suffix': '.png'}}],
#  'verified': True,
#  'stats': {'tipCount': 221},
#  'url': 'http://www.sakagura.com',
#  'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'},
#  'hasMenu': True,
#  'likes': {'count': 588,
#   'groups': [{'type': 'others', 'count': 588, 'items': []}],
#   'summary': '588 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 9.0,
#  'ratingColor': '00B551',
#  'ratingSignals': 779,
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'https://foursquare.com/v/sakagura/407f2200f964a5207df21ee3/menu',
#   'mobileUrl': 'https://foursquare.com/v/407f2200f964a5207df21ee3/device_menu'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 740,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 740,
#     'items': [{'id': '508b65efe4b0a1c84722f185',
#       'createdAt': 1351312879,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/22998173_V2m6-bIXuZg38oQW2eilhCK4H3hy2Kuf8kvLPFnl3-0.jpg',
#       'width': 537,
#       'height': 720,
#       'user': {'isSanctioned': False,
#        'firstName': 'Ellen C',
#        'countryCode': 'US'},
#       'visibility': 'public'}]}]},
#  'venuePage': {'id': '71886455'},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'description': 'Sakagura was founded in 1996 and has become one of the top sake bars in the United States, attracting countless sake lovers. When you visit our unique location in the basement of a Midtown East office building, you’ll understand why we have earned the nickname “hidden jewel.”',
#  'storeId': '',
#  'page': {'user': {'isSanctioned': False,
#    'firstName': 'Sakagura',
#    'countryCode': 'US',
#    'type': 'venuePage',
#    'venue': {'id': '407f2200f964a5207df21ee3'},
#    'tips': {'count': 0},
#    'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#    'bio': ''}},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1082073600,
#  'tips': {'count': 221,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 221,
#     'items': [{'id': '4a5bd67470c603bbd6398eb4',
#       'createdAt': 1247532660,
#       'text': 'best izakaya-style Japanese food in the city',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4a5bd67470c603bbd6398eb4',
#       'lang': 'en',
#       'likes': {'count': 13,
#        'groups': [{'type': 'others', 'count': 13, 'items': []}],
#        'summary': '13 likes'},
#       'logView': True,
#       'agreeCount': 2,
#       'disagreeCount': 0,
#       'todo': {'count': 3},
#       'user': {'isSanctioned': False,
#        'firstName': 'Miko',
#        'lastName': 'M',
#        'countryCode': 'US'}}]}]},
#  'shortUrl': 'http://4sq.com/4u8pub',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 1791,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 1791,
#     'items': [{'id': '4ec3dce68231d4c9fee0567b',
#       'name': "NYC's Midtown",
#       'description': 'The most visited area of Manhattan and the headquarters for dozens of well known companies, Midtown has much to offer, from hidden restaurants to popular attractions.  Discover our favorites here.',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'New York Habitat',
#        'countryCode': 'US',
#        'type': 'chain'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/newyorkhabitat/list/nycs-midtown',
#       'canonicalUrl': 'https://foursquare.com/newyorkhabitat/list/nycs-midtown',
#       'createdAt': 1321458918,
#       'updatedAt': 1337625780,
#       'photo': {'id': '4ecfc555e3007feb7caec837',
#        'createdAt': 1322239317,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/GYOLBUQJQ0MBHSJ5TKFL0XYBTDD43KPTNTHDQKP3GZSYKLAD.jpg',
#        'width': 537,
#        'height': 720,
#        'user': {'isSanctioned': False,
#         'firstName': 'Jason',
#         'lastName': 'H',
#         'countryCode': 'US'},
#        'visibility': 'public'},
#       'logView': True,
#       'followers': {'count': 737},
#       'listItems': {'count': 76,
#        'items': [{'id': 't4ed90784775bcc53f8d92290',
#          'createdAt': 1322846088,
#          'photo': {'id': '4eb6b0e15c5c5a53208b341e',
#           'createdAt': 1320595681,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/JTPZIU3FK0MMXLHPBJYC2JUGVVVIK4A0XBYS1KSVACCBPT34.jpg',
#           'width': 720,
#           'height': 537,
#           'user': {'isSanctioned': False,
#            'firstName': 'Sara',
#            'lastName': 'Z',
#            'countryCode': 'US'},
#           'visibility': 'public'}}]}},
#      {'id': '50a695c9e4b06baebe3d94fe',
#       'name': 'Hidden Bars & Restaurants in NYC',
#       'description': 'This list will get you beyond the trendy to some of the more unique hidden restaurants in New York City.',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Untapped Cities',
#        'countryCode': 'US',
#        'type': 'page'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/untappedcities/list/hidden-bars--restaurants-in-nyc',
#       'canonicalUrl': 'https://foursquare.com/untappedcities/list/hidden-bars--restaurants-in-nyc',
#       'createdAt': 1353094601,
#       'updatedAt': 1447347530,
#       'photo': {'id': '50a69836fe70df02fd35a0a6',
#        'createdAt': 1353095222,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/24933846_EnR1USgozVR5ZlOgw5pMWEddtmJRIZzeeZpSFSm_yIw.jpg',
#        'width': 575,
#        'height': 357,
#        'user': {'isSanctioned': False,
#         'firstName': 'Untapped Cities',
#         'countryCode': 'US',
#         'type': 'page'},
#        'visibility': 'public'},
#       'logView': True,
#       'followers': {'count': 1312},
#       'listItems': {'count': 43,
#        'items': [{'id': 't5644c3b2498eb8eddd31b98f',
#          'createdAt': 1447347498}]}},
#      {'id': '4f06192a0e0199f87c8392e4',
#       'name': 'Quick, I need a date spot.',
#       'description': 'My favorite date spots in various neighborhoods at various price points. Some trendy, some hidden, all relatively calm and civilized.',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Dan',
#        'lastName': 'K',
#        'countryCode': 'US'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/23355/list/quick-i-need-a-date-spot',
#       'canonicalUrl': 'https://foursquare.com/user/23355/list/quick-i-need-a-date-spot',
#       'createdAt': 1325799722,
#       'updatedAt': 1583879230,
#       'photo': {'id': '4eadcfc9490170218c74db8a',
#        'createdAt': 1320013769,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/Y1KLPFVKNEKQLS5GW4MW42JKAG3DZY32HXKPVAJKDH2ED4AM.jpg',
#        'width': 612,
#        'height': 612,
#        'user': {'isSanctioned': False,
#         'firstName': 'Ben',
#         'countryCode': 'US'},
#        'visibility': 'public'},
#       'followers': {'count': 842},
#       'listItems': {'count': 204,
#        'items': [{'id': 'v407f2200f964a5207df21ee3',
#          'createdAt': 1325799744,
#          'photo': {'id': '4ed1b175490168f8d17248fd',
#           'createdAt': 1322365301,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/V0SWEYQGJUKWKHJWT2J1BWLJTOUAXTC0A0VWG0TSVCOXALAK.jpg',
#           'width': 720,
#           'height': 431,
#           'user': {'isSanctioned': False,
#            'firstName': 'Winnie',
#            'lastName': 'D',
#            'countryCode': 'US'},
#           'visibility': 'public'}}]}},
#      {'id': '4ff63dd2e4b01a84ed428bd9',
#       'name': 'Speakeasy bars and secret restaurants in NYC',
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Meng',
#        'lastName': 'H',
#        'countryCode': 'US'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/menghe/list/speakeasy-bars-and-secret-restaurants-in-nyc',
#       'canonicalUrl': 'https://foursquare.com/menghe/list/speakeasy-bars-and-secret-restaurants-in-nyc',
#       'createdAt': 1341537746,
#       'updatedAt': 1467205482,
#       'photo': {'id': '4ee26aab4fc6a6fab596014b',
#        'createdAt': 1323461291,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/Q3HOHYY4THONJUCUCJ5MCMSH1ORZJDO0Z5E4L0PXHUEXQKZQ.jpg',
#        'width': 220,
#        'height': 220,
#        'user': {'isSanctioned': False,
#         'firstName': 'AskMen',
#         'countryCode': 'US',
#         'type': 'page'},
#        'visibility': 'public'},
#       'followers': {'count': 935},
#       'listItems': {'count': 67,
#        'items': [{'id': 'v407f2200f964a5207df21ee3',
#          'createdAt': 1341537952}]}}]}]},
#  'hours': {'status': 'Open until Midnight',
#   'richStatus': {'entities': [], 'text': 'Open until Midnight'},
#   'isOpen': True,
#   'isLocalHoliday': True,
#   'localHolidayName': 'Thanksgiving Day',
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Thu',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:30 AM–2:20 PM'},
#      {'renderedTime': '6:00 PM–Midnight'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '11:30 AM–2:20 PM'},
#      {'renderedTime': '6:00 PM–1:00 AM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '6:00 PM–1:00 AM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '6:00 PM–11:00 PM'}],
#     'segments': []}]},
#  'popular': {'status': 'Likely open',
#   'richStatus': {'entities': [], 'text': 'Likely open'},
#   'isOpen': True,
#   'isLocalHoliday': True,
#   'localHolidayName': 'Thanksgiving Day',
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:00 AM–3:00 PM'},
#      {'renderedTime': '6:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '11:00 AM–3:00 PM'},
#      {'renderedTime': '6:00 PM–Midnight'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '6:00 PM–Midnight'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '6:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Mon–Wed',
#     'open': [{'renderedTime': '11:00 AM–3:00 PM'},
#      {'renderedTime': '6:00 PM–11:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'defaultHours': {'status': 'Open until Midnight',
#   'richStatus': {'entities': [], 'text': 'Open until Midnight'},
#   'isOpen': True,
#   'isLocalHoliday': True,
#   'localHolidayName': 'Thanksgiving Day',
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Thu',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:30 AM–2:20 PM'},
#      {'renderedTime': '6:00 PM–Midnight'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '11:30 AM–2:20 PM'},
#      {'renderedTime': '6:00 PM–1:00 AM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '6:00 PM–1:00 AM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '6:00 PM–11:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$$',
#     'count': 1,
#     'items': [{'displayName': 'Price',
#       'displayValue': '$$$',
#       'priceTier': 3}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. American Express & MasterCard)'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Dessert, Dinner & more',
#     'count': 8,
#     'items': [{'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#      {'displayName': 'Dessert', 'displayValue': 'Dessert'}]},
#    {'type': 'drinks',
#     'name': 'Drinks',
#     'summary': 'Full Bar',
#     'count': 5,
#     'items': [{'displayName': 'Full Bar', 'displayValue': 'Full Bar'}]},
#    {'type': 'parking',
#     'name': 'Parking',
#     'summary': 'Street Parking',
#     'count': 5,
#     'items': [{'displayName': 'Street Parking', 'displayValue': 'Street'}]},
#    {'type': 'restroom',
#     'name': 'Restroom',
#     'summary': 'Restroom',
#     'count': 1,
#     'items': [{'displayName': 'Restroom', 'displayValue': 'Yes'}]},
#    {'type': 'wheelchairAccessible',
#     'name': 'Wheelchair Accessible',
#     'summary': 'Wheelchair Accessible',
#     'count': 1,
#     'items': [{'displayName': 'Wheelchair Accessible',
#       'displayValue': 'Yes'}]}]},
#  'bestPhoto': {'id': '508b65efe4b0a1c84722f185',
#   'createdAt': 1351312879,
#   'source': {'name': 'Foursquare for iOS',
#    'url': 'https://foursquare.com/download/#/iphone'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/22998173_V2m6-bIXuZg38oQW2eilhCK4H3hy2Kuf8kvLPFnl3-0.jpg',
#   'width': 537,
#   'height': 720,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '508b65efe4b0a1c84722f185',
#    'value': -10477560},
#   'highlightTextColor': {'photoId': '508b65efe4b0a1c84722f185', 'value': -1},
#   'algoVersion': 0}}

# %%
#En caso de que el lugar este puntuado, mostrar la puntuación
#En caso de que no, mostrar el mensaje de que no esta disponible
try:
    print(resultJapanese2["response"]["venue"]["rating"])
except:
    print("This venue has not been rated yet.")
# Out:
# 9.0

# %%
#Es una buena puntuación con lo que vamos a investigar cuantas opiniones hay disponibles de la gente que haya 
#comido en el restaurante "Sakagura"

# %%
resultJapanese2["response"]["venue"]["tips"]["count"]
# Out:
# 221

# %%
#Una vez que hemos comprobado el número de opiniones que hay sobre este restaurante, vamos a conseguir
#una opinión al azar de este

#Opinión del Restaurante

limit=1 #Define los límites para que sean mayor o igual al total de consejos para ese restaurante
url=url = "https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}".format(venue_id, CLIENT_ID,
CLIENT_SECRET, VERSION, limit)

TipsJapanese=requests.get(url).json()
TipsJapanese
# Out:
# {'meta': {'code': 200, 'requestId': '5fc0731a9663526c3cf7a367'},
#  'response': {'tips': {'count': 221,
#    'items': [{'id': '55105e7d498e0c0b178e7afd',
#      'createdAt': 1427136125,
#      'text': 'Great date spot. Great food. Finish the meal with uni soba. Eat it lady and the tramp-style and marry that girl. (Cc: my wife). Unrelated, the sake barrel bathrooms have awesome Japanese toilets.',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/55105e7d498e0c0b178e7afd',
#      'photo': {'id': '55105e7e498e52766217f367',
#       'createdAt': 1427136126,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/288292_McMy-XqaVEaXvDu_ZTpOGoWH5e6ePhaqR3XLmcN9Ch0.jpg',
#       'width': 1920,
#       'height': 1439,
#       'visibility': 'public'},
#      'photourl': 'https://fastly.4sqi.net/img/general/original/288292_McMy-XqaVEaXvDu_ZTpOGoWH5e6ePhaqR3XLmcN9Ch0.jpg',
#      'lang': 'en',
#      'likes': {'count': 1,
#       'groups': [{'type': 'others',
#         'count': 1,
#         'items': [{'isSanctioned': False,
#           'firstName': 'Jonas',
#           'lastName': 'K',
#           'countryCode': 'ES'}]}],
#       'summary': '1 like'},
#      'logView': True,
#      'agreeCount': 7,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'isSanctioned': False,
#       'firstName': 'Mark',
#       'lastName': 'K',
#       'countryCode': 'US'},
#      'authorInteractionType': 'liked'}]}}}

# %%
#Vamos a conseguir extraer la opinión del restaurante
tips= TipsJapanese["response"]["tips"]["items"]

tip = TipsJapanese["response"]["tips"]["items"][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'photo', 'photourl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %%
#Formatea el ancho de las columnas y visualiza todos los consejos
pd.set_option("display.max_colwidth",-1)

tips_df=pd.json_normalize(tips)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
filtered_columns =["text","agreeCount", "disagreeCount", "id", "user.firstName", "user.lastName"]
tips_filtered =tips_df.loc[:,filtered_columns]

# %%
#Muestra el consejo

tips_filtered.reindex()
# Out:
#                                                                                                                                                                                                   text  \
# 0  Great date spot. Great food. Finish the meal with uni soba. Eat it lady and the tramp-style and marry that girl. (Cc: my wife). Unrelated, the sake barrel bathrooms have awesome Japanese toilets.
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  7           0              55105e7d498e0c0b178e7afd  Mark
#
#   user.lastName
# 0  K
