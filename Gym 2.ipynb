# %%
import requests #Biblioteca para manejar solicitudes
import pandas as pd #Biblioteca para Análisis de datos
import numpy as np #Biblioteca para manejar datos de una manera vectorizada
import random #Biblioteca para la generación de números aleatorios

# !pip install geopy
from geopy.geocoders import Nominatim #Módulo para convertir una dirección en valores de latitud y longitud

#Bibliotecas para mostrar imágenes

from IPython.display import Image
from IPython.core.display import HTML

#Transformar un archivo JSON en una biblioteca de marco de datos de pandas
from pandas.io.json import json_normalize

! pip install folium==0.5.0
import folium #Biblioteca de representación

print("Folium installed")
print("Libraries imported")
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.50)
# Collecting folium==0.5.0
# Requirement already satisfied: branca in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (0.4.1)
# Requirement already satisfied: jinja2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (3.0.4)
# Installing collected packages: folium
#   Found existing installation: folium 0.11.0
#     Uninstalling folium-0.11.0:
#       Successfully uninstalled folium-0.11.0
# Successfully installed folium-0.5.0
# Folium installed
# Libraries imported

# %%
CLIENT_ID= "VYXHEB1JFDKLQWKXQVDHVO0BIK5COTAA00QDMGTTZSE0GQPI" #Tu ID de Foursquare
CLIENT_SECRET= "5KJIO12I3YHGWNTTX2MFS011R0V2VHRRE5N1CTRPEHYLDZOX" #Tu Foursquare secreto
VERSION="20180604 "
LIMIT=10
print("Your credentials:")
print("CLIENT_ID: " + CLIENT_ID)
print("CLIENT_SECRET:" + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: VYXHEB1JFDKLQWKXQVDHVO0BIK5COTAA00QDMGTTZSE0GQPI
# CLIENT_SECRET:5KJIO12I3YHGWNTTX2MFS011R0V2VHRRE5N1CTRPEHYLDZOX

# %%
#Vamos a trabajar con un Hotel llamado "Hotel Bliss" que está en Nueva York, 
#ubicado en Queens"
Dirección="36-38 Main St, Queens, NY 11354, Estados Unidos"

geolocator =Nominatim(user_agent="foursquare_agent")
location=geolocator.geocode(Dirección)
latitude=location.latitude
longitude=location.longitude
print(latitude, longitude)
# Out:
# 40.761979 -73.83190498503652

# %%
#Ahora, vamos a buscar un gym, que se encuentre a 
#3000 metros de "Hotel Bliss".

search_query="Gym"
radius=3000
print(search_query + ".... OK!")
# Out:
# Gym.... OK!

# %%
#Ahora definimos la correspondiente URL:

url= "https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}".format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=VYXHEB1JFDKLQWKXQVDHVO0BIK5COTAA00QDMGTTZSE0GQPI&client_secret=5KJIO12I3YHGWNTTX2MFS011R0V2VHRRE5N1CTRPEHYLDZOX&ll=40.761979,-73.83190498503652&v=20180604 &query=Gym&radius=3000&limit=10'

# %%
#Realizamos la solicitud de la url
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fbfe5166db05f1868d48adb'},
#  'response': {'venues': [{'id': '54124898498eb4c762dd4406',
#     'name': 'Skyview Parc Gym',
#     'location': {'lat': 40.75758537730301,
#      'lng': -73.83586419053327,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75758537730301,
#        'lng': -73.83586419053327}],
#      'distance': 592,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Queens',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Queens, NY 11354', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606411542',
#     'hasPerk': False},
#    {'id': '4c8f8a40d68c6dcbb91d05a2',
#     'name': 'Fitzgerald Gym',
#     'location': {'address': 'Queens College',
#      'crossStreet': 'at 6530 Kissena Blvd',
#      'lat': 40.73805428308711,
#      'lng': -73.81960911793796,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73805428308711,
#        'lng': -73.81960911793796}],
#      'distance': 2858,
#      'postalCode': '11367',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Queens College (at 6530 Kissena Blvd)',
#       'Flushing, NY 11367',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1b2941735',
#       'name': 'College Gym',
#       'pluralName': 'College Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606411542',
#     'hasPerk': False},
#    {'id': '4d48fd86183f224b5c7cd9a8',
#     'name': 'The Gym',
#     'location': {'lat': 40.765356,
#      'lng': -73.83488,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.765356,
#        'lng': -73.83488}],
#      'distance': 451,
#      'postalCode': '11354',
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['NY 11354', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606411542',
#     'hasPerk': False},
#    {'id': '57470f36498ec1626794e9af',
#     'name': 'PD 109 Gym',
#     'location': {'lat': 40.76236461089549,
#      'lng': -73.82744129292522,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76236461089549,
#        'lng': -73.82744129292522}],
#      'distance': 378,
#      'cc': 'US',
#      'city': 'Queens',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Queens, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606411542',
#     'hasPerk': False},
#    {'id': '4c84579cd34ca1439c4b3e80',
#     'name': 'Gym Metro',
#     'location': {'address': '164-24 Northern Blvd',
#      'crossStreet': 'Sanford Ave',
#      'lat': 40.76032416509134,
#      'lng': -73.80124561272534,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76032416509134,
#        'lng': -73.80124561272534}],
#      'distance': 2591,
#      'postalCode': '11358',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['164-24 Northern Blvd (Sanford Ave)',
#       'Flushing, NY 11358',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606411542',
#     'hasPerk': False},
#    {'id': '4f18a41be4b0242771b0dc92',
#     'name': 'GYM-MyRunningWheeL',
#     'location': {'lat': 40.765720085283974,
#      'lng': -73.82493180876845,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.765720085283974,
#        'lng': -73.82493180876845}],
#      'distance': 720,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Flushing, NY 11354', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606411542',
#     'hasPerk': False},
#    {'id': '4f9f05bce4b060916ab65a8f',
#     'name': 'gym',
#     'location': {'address': 'Hoover Ave, Queens, NY 11435',
#      'lat': 40.77246123927427,
#      'lng': -73.82799268997377,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77246123927427,
#        'lng': -73.82799268997377}],
#      'distance': 1212,
#      'postalCode': '11435',
#      'cc': 'US',
#      'city': 'Queens',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Hoover Ave, Queens, NY 11435',
#       'Queens, NY 11435',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606411542',
#     'hasPerk': False},
#    {'id': '51363087e4b0caef3a2c7943',
#     'name': "Gatita's Gym",
#     'location': {'lat': 40.7637939453125,
#      'lng': -73.82310485839844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7637939453125,
#        'lng': -73.82310485839844}],
#      'distance': 768,
#      'cc': 'US',
#      'city': 'Queens',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Queens, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606411542',
#     'hasPerk': False},
#    {'id': '4e25b85462e12f2b95eab92c',
#     'name': '38th Ave Gym',
#     'location': {'address': '38th Ave',
#      'lat': 40.752986207762774,
#      'lng': -73.85133375350955,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752986207762774,
#        'lng': -73.85133375350955}],
#      'distance': 1919,
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['38th Ave', 'Flushing, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606411542',
#     'hasPerk': False},
#    {'id': '51bd9fc8498ed90edfd8ce66',
#     'name': 'Fairfield Inn Gym',
#     'location': {'lat': 40.7715784983761,
#      'lng': -73.8447234126406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7715784983761,
#        'lng': -73.8447234126406}],
#      'distance': 1519,
#      'cc': 'US',
#      'city': 'Queens',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Queens, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606411542',
#     'hasPerk': False}]}}

# %%
#Asigna la parte relevante de JSON a lugares
venues=results["response"]["venues"]

# %%
#Transforma los lugares en un marco de datos

dataframe=pd.json_normalize(venues)
dataframe.head(30)
# Out:
#                          id                name  \
# 0  54124898498eb4c762dd4406    Skyview Parc Gym
# 1  4c8f8a40d68c6dcbb91d05a2      Fitzgerald Gym
# 2  4d48fd86183f224b5c7cd9a8             The Gym
# 3  57470f36498ec1626794e9af          PD 109 Gym
# 4  4c84579cd34ca1439c4b3e80           Gym Metro
# 5  4f18a41be4b0242771b0dc92  GYM-MyRunningWheeL
# 6  4f9f05bce4b060916ab65a8f                 gym
# 7  51363087e4b0caef3a2c7943        Gatita's Gym
# 8  4e25b85462e12f2b95eab92c        38th Ave Gym
# 9  51bd9fc8498ed90edfd8ce66   Fairfield Inn Gym
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606411542    False
# 1  [{'id': '4bf58dd8d48988d1b2941735', 'name': 'C...  v-1606411542    False
# 2  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606411542    False
# 3  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606411542    False
# 4  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606411542    False
# 5  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1606411542    False
# 6  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606411542    False
# 7  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1606411542    False
# 8  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1606411542    False
# 9  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1606411542    False
#
#    location.lat  location.lng  \
# 0     40.757585    -73.835864
# 1     40.738054    -73.819609
# 2     40.765356    -73.834880
# 3     40.762365    -73.827441
# 4     40.760324    -73.801246
# 5     40.765720    -73.824932
# 6     40.772461    -73.827993
# 7     40.763794    -73.823105
# 8     40.752986    -73.851334
# 9     40.771578    -73.844723
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.75758537730301...                592
# 1  [{'label': 'display', 'lat': 40.73805428308711...               2858
# 2  [{'label': 'display', 'lat': 40.765356, 'lng':...                451
# 3  [{'label': 'display', 'lat': 40.76236461089549...                378
# 4  [{'label': 'display', 'lat': 40.76032416509134...               2591
# 5  [{'label': 'display', 'lat': 40.76572008528397...                720
# 6  [{'label': 'display', 'lat': 40.77246123927427...               1212
# 7  [{'label': 'display', 'lat': 40.7637939453125,...                768
# 8  [{'label': 'display', 'lat': 40.75298620776277...               1919
# 9  [{'label': 'display', 'lat': 40.7715784983761,...               1519
#
#   location.postalCode location.cc location.city location.state  \
# 0               11354          US        Queens             NY
# 1               11367          US      Flushing             NY
# 2               11354          US           NaN       New York
# 3                 NaN          US        Queens             NY
# 4               11358          US      Flushing             NY
# 5               11354          US      Flushing             NY
# 6               11435          US        Queens             NY
# 7                 NaN          US        Queens             NY
# 8                 NaN          US      Flushing             NY
# 9                 NaN          US        Queens             NY
#
#   location.country                          location.formattedAddress  \
# 0    United States                  [Queens, NY 11354, United States]
# 1    United States  [Queens College (at 6530 Kissena Blvd), Flushi...
# 2    United States                          [NY 11354, United States]
# 3    United States                        [Queens, NY, United States]
# 4    United States  [164-24 Northern Blvd (Sanford Ave), Flushing,...
# 5    United States                [Flushing, NY 11354, United States]
# 6    United States  [Hoover Ave, Queens, NY 11435, Queens, NY 1143...
# 7    United States                        [Queens, NY, United States]
# 8    United States            [38th Ave, Flushing, NY, United States]
# 9    United States                        [Queens, NY, United States]
#
#                location.address  location.crossStreet
# 0                           NaN                   NaN
# 1                Queens College  at 6530 Kissena Blvd
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4          164-24 Northern Blvd           Sanford Ave
# 5                           NaN                   NaN
# 6  Hoover Ave, Queens, NY 11435                   NaN
# 7                           NaN                   NaN
# 8                      38th Ave                   NaN
# 9                           NaN                   NaN

# %%
#Mantén solo las columnas que incluyan el nombre del lugar, y cualquier cosas que esté asociada con la localización

filtered_columns =["name","categories"]+[col for col in dataframe.columns if col.startswith("location.")]+["id"]
dataframe_filtered = dataframe.loc[:, filtered_columns]

# %%
#A continuación, vamos a utilizar la función que extrae la categoría del lugar

def get_category_type(row):
    try:
        categories_list = row["categories"]
    except:
        categories_list= row["venue.categories"]
    if len (categories_list)==0:
       return None
    else:
       return categories_list[0]["name"]

# %%
#Se filtra la categoría por cada fila
dataframe_filtered["categories"] = dataframe_filtered.apply(get_category_type, axis=1)

# %%
#Limpiamos los nombres de la columna manteniendo solo el último término
dataframe_filtered.columns =[column.split(".")[-1] for column in dataframe_filtered.columns]

# %%
dataframe_filtered
# Out:
#                  name            categories        lat        lng  \
# 0    Skyview Parc Gym                   Gym  40.757585 -73.835864
# 1      Fitzgerald Gym           College Gym  40.738054 -73.819609
# 2             The Gym                   Gym  40.765356 -73.834880
# 3          PD 109 Gym                   Gym  40.762365 -73.827441
# 4           Gym Metro                   Gym  40.760324 -73.801246
# 5  GYM-MyRunningWheeL  Gym / Fitness Center  40.765720 -73.824932
# 6                 gym                   Gym  40.772461 -73.827993
# 7        Gatita's Gym                   Gym  40.763794 -73.823105
# 8        38th Ave Gym  Gym / Fitness Center  40.752986 -73.851334
# 9   Fairfield Inn Gym  Gym / Fitness Center  40.771578 -73.844723
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 40.75758537730301...       592      11354  US
# 1  [{'label': 'display', 'lat': 40.73805428308711...      2858      11367  US
# 2  [{'label': 'display', 'lat': 40.765356, 'lng':...       451      11354  US
# 3  [{'label': 'display', 'lat': 40.76236461089549...       378        NaN  US
# 4  [{'label': 'display', 'lat': 40.76032416509134...      2591      11358  US
# 5  [{'label': 'display', 'lat': 40.76572008528397...       720      11354  US
# 6  [{'label': 'display', 'lat': 40.77246123927427...      1212      11435  US
# 7  [{'label': 'display', 'lat': 40.7637939453125,...       768        NaN  US
# 8  [{'label': 'display', 'lat': 40.75298620776277...      1919        NaN  US
# 9  [{'label': 'display', 'lat': 40.7715784983761,...      1519        NaN  US
#
#        city     state        country  \
# 0    Queens        NY  United States
# 1  Flushing        NY  United States
# 2       NaN  New York  United States
# 3    Queens        NY  United States
# 4  Flushing        NY  United States
# 5  Flushing        NY  United States
# 6    Queens        NY  United States
# 7    Queens        NY  United States
# 8  Flushing        NY  United States
# 9    Queens        NY  United States
#
#                                     formattedAddress  \
# 0                  [Queens, NY 11354, United States]
# 1  [Queens College (at 6530 Kissena Blvd), Flushi...
# 2                          [NY 11354, United States]
# 3                        [Queens, NY, United States]
# 4  [164-24 Northern Blvd (Sanford Ave), Flushing,...
# 5                [Flushing, NY 11354, United States]
# 6  [Hoover Ave, Queens, NY 11435, Queens, NY 1143...
# 7                        [Queens, NY, United States]
# 8            [38th Ave, Flushing, NY, United States]
# 9                        [Queens, NY, United States]
#
#                         address           crossStreet  \
# 0                           NaN                   NaN
# 1                Queens College  at 6530 Kissena Blvd
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4          164-24 Northern Blvd           Sanford Ave
# 5                           NaN                   NaN
# 6  Hoover Ave, Queens, NY 11435                   NaN
# 7                           NaN                   NaN
# 8                      38th Ave                   NaN
# 9                           NaN                   NaN
#
#                          id
# 0  54124898498eb4c762dd4406
# 1  4c8f8a40d68c6dcbb91d05a2
# 2  4d48fd86183f224b5c7cd9a8
# 3  57470f36498ec1626794e9af
# 4  4c84579cd34ca1439c4b3e80
# 5  4f18a41be4b0242771b0dc92
# 6  4f9f05bce4b060916ab65a8f
# 7  51363087e4b0caef3a2c7943
# 8  4e25b85462e12f2b95eab92c
# 9  51bd9fc8498ed90edfd8ce66

# %%
#Vamos a visualizar los resultados de gimnasios que hemos encontrado
dataframe_filtered.name
# Out:
# 0      Skyview Parc Gym
# 1        Fitzgerald Gym
# 2               The Gym
# 3            PD 109 Gym
# 4             Gym Metro
# 5    GYM-MyRunningWheeL
# 6                   gym
# 7          Gatita's Gym
# 8          38th Ave Gym
# 9     Fairfield Inn Gym
# Name: name, dtype: object

# %%
# !pip install folium --upgrade
# Out:
# Requirement already up-to-date: folium in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.11.0)
# Requirement already satisfied, skipping upgrade: numpy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (1.19.2)
# Requirement already satisfied, skipping upgrade: jinja2>=2.9 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.11.2)
# Requirement already satisfied, skipping upgrade: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.24.0)
# Requirement already satisfied, skipping upgrade: branca>=0.3.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (1.25.11)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (3.0.4)

# %%
gym_map = folium.Map(location=[latitude, longitude], zoom_start=20) #genera una mapa centrado
#añade una marca de círculo naranja para representar "Hotel Bliss"
          
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color="black",
    popup="Hotel Bliss",
    fill=True,
    fill_color="orange",
    fill_opacity=0.6
).add_to(gym_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat,lng],
        radius=8,
        color="black",
        popup=label,
        fill=True,
        fill_color="red",
        fill_opacity=0.6
).add_to(gym_map)

# %%
gym_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#A continuación, vamos a explorar unos cuantos gimnasios. El 1 gimnasio es el
#Fitzgerald Gym:

venue_id="4c8f8a40d68c6dcbb91d05a2"
url = "https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}".format(venue_id, CLIENT_ID,
CLIENT_SECRET, VERSION)
print("Todo ha salido correcto")
# Out:
# Todo ha salido correcto

# %%
#Enviemos la solicitud del get para el resultado

gym1 = requests.get(url).json()
gym1
# Out:
# {'meta': {'code': 200, 'requestId': '5fbfe56fac80632fabb7f151'},
#  'response': {'venue': {'id': '4c8f8a40d68c6dcbb91d05a2',
#    'name': 'Fitzgerald Gym',
#    'contact': {},
#    'location': {'address': 'Queens College',
#     'crossStreet': 'at 6530 Kissena Blvd',
#     'lat': 40.73805428308711,
#     'lng': -73.81960911793796,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.73805428308711,
#       'lng': -73.81960911793796}],
#     'postalCode': '11367',
#     'cc': 'US',
#     'city': 'Flushing',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['Queens College (at 6530 Kissena Blvd)',
#      'Flushing, NY 11367',
#      'United States']},
#    'canonicalUrl': 'https://foursquare.com/v/fitzgerald-gym/4c8f8a40d68c6dcbb91d05a2',
#    'categories': [{'id': '4bf58dd8d48988d1b2941735',
#      'name': 'College Gym',
#      'pluralName': 'College Gyms',
#      'shortName': 'Gym',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#       'suffix': '.png'},
#      'primary': True},
#     {'id': '4bf58dd8d48988d1ae941735',
#      'name': 'University',
#      'pluralName': 'Universities',
#      'shortName': 'University',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#       'suffix': '.png'}},
#     {'id': '4bf58dd8d48988d176941735',
#      'name': 'Gym',
#      'pluralName': 'Gyms',
#      'shortName': 'Gym',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#       'suffix': '.png'}}],
#    'verified': False,
#    'stats': {'tipCount': 1},
#    'likes': {'count': 23,
#     'groups': [{'type': 'others', 'count': 23, 'items': []}],
#     'summary': '23 Likes'},
#    'dislike': False,
#    'ok': False,
#    'rating': 7.3,
#    'ratingColor': 'C5DE35',
#    'ratingSignals': 30,
#    'venueRatingBlacklisted': True,
#    'allowMenuUrlEdit': True,
#    'beenHere': {'count': 0,
#     'unconfirmedCount': 0,
#     'marked': False,
#     'lastCheckinExpiredAt': 0},
#    'specials': {'count': 0, 'items': []},
#    'photos': {'count': 1,
#     'groups': [{'type': 'venue',
#       'name': 'Venue photos',
#       'count': 1,
#       'items': [{'id': '59975272f8cbd46f1c226a06',
#         'createdAt': 1503089266,
#         'prefix': 'https://fastly.4sqi.net/img/general/',
#         'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#         'width': 3888,
#         'height': 2592,
#         'user': {'isSanctioned': False,
#          'firstName': 'pivot_photos',
#          'countryCode': 'US',
#          'type': 'page'},
#         'visibility': 'public'}]}]},
#    'reasons': {'count': 0, 'items': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'createdAt': 1284475456,
#    'tips': {'count': 1,
#     'groups': [{'type': 'others',
#       'name': 'All tips',
#       'count': 1,
#       'items': [{'id': '4d5082d89ffc236a59d119a7',
#         'createdAt': 1297122008,
#         'text': 'Try to steer clear after 4. Its suicide.',
#         'type': 'user',
#         'canonicalUrl': 'https://foursquare.com/item/4d5082d89ffc236a59d119a7',
#         'lang': 'en',
#         'likes': {'count': 1,
#          'groups': [{'type': 'others',
#            'count': 1,
#            'items': [{'isSanctioned': False,
#              'firstName': 'Shannon',
#              'lastName': 'C',
#              'countryCode': 'US'}]}],
#          'summary': '1 like'},
#         'logView': True,
#         'agreeCount': 2,
#         'disagreeCount': 0,
#         'todo': {'count': 0},
#         'user': {'isSanctioned': False,
#          'firstName': 'H Marie',
#          'lastName': 'W',
#          'countryCode': 'US'}}]}]},
#    'shortUrl': 'http://4sq.com/bSJsKi',
#    'timeZone': 'America/New_York',
#    'listed': {'count': 1,
#     'groups': [{'type': 'others',
#       'name': 'Lists from other people',
#       'count': 1,
#       'items': [{'id': '50fc15d5e4b0b7771147885a',
#         'name': 'Places I regularly go',
#         'description': '',
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'Martine',
#          'lastName': 'M',
#          'countryCode': 'US'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/user/45746868/list/places-i-regularly-go',
#         'canonicalUrl': 'https://foursquare.com/user/45746868/list/places-i-regularly-go',
#         'createdAt': 1358697941,
#         'updatedAt': 1362428239,
#         'followers': {'count': 0},
#         'listItems': {'count': 4,
#          'items': [{'id': 'v4c8f8a40d68c6dcbb91d05a2',
#            'createdAt': 1358697947}]}}]}]},
#    'popular': {'status': 'Likely open',
#     'richStatus': {'entities': [], 'text': 'Likely open'},
#     'isOpen': True,
#     'isLocalHoliday': True,
#     'localHolidayName': 'Thanksgiving Day',
#     'timeframes': [{'days': 'Today',
#       'includesToday': True,
#       'open': [{'renderedTime': '10:00 AM–9:00 PM'}],
#       'segments': []},
#      {'days': 'Fri',
#       'open': [{'renderedTime': '11:00 AM–4:00 PM'},
#        {'renderedTime': '6:00 PM–7:00 PM'}],
#       'segments': []},
#      {'days': 'Sat',
#       'open': [{'renderedTime': '8:00 AM–4:00 PM'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': '8:00 AM–5:00 PM'}],
#       'segments': []},
#      {'days': 'Mon',
#       'open': [{'renderedTime': 'Noon–9:00 PM'}],
#       'segments': []},
#      {'days': 'Tue',
#       'open': [{'renderedTime': '8:00 AM–9:00 PM'}],
#       'segments': []},
#      {'days': 'Wed',
#       'open': [{'renderedTime': '10:00 AM–9:00 PM'}],
#       'segments': []}]},
#    'seasonalHours': [],
#    'pageUpdates': {'count': 0, 'items': []},
#    'inbox': {'count': 0, 'items': []},
#    'parent': {'id': '4a6f3aa4f964a520add51fe3',
#     'name': 'Queens College',
#     'location': {'address': '6530 Kissena Blvd',
#      'crossStreet': 'at 65th Ave',
#      'lat': 40.73615824752801,
#      'lng': -73.81680936831667,
#      'postalCode': '11367',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['6530 Kissena Blvd (at 65th Ave)',
#       'Flushing, NY 11367',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'shortName': 'University',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}]},
#    'hierarchy': [{'name': 'Queens College',
#      'lang': 'en',
#      'id': '4a6f3aa4f964a520add51fe3',
#      'canonicalUrl': 'https://foursquare.com/v/queens-college/4a6f3aa4f964a520add51fe3'}],
#    'attributes': {'groups': []},
#    'bestPhoto': {'id': '59975272f8cbd46f1c226a06',
#     'createdAt': 1503089266,
#     'prefix': 'https://fastly.4sqi.net/img/general/',
#     'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#     'width': 3888,
#     'height': 2592,
#     'visibility': 'public'},
#    'colors': {'highlightColor': {'photoId': '59975272f8cbd46f1c226a06',
#      'value': -14145480},
#     'highlightTextColor': {'photoId': '59975272f8cbd46f1c226a06', 'value': -1},
#     'algoVersion': 3}}}}

# %%
#Vamos a definir la variable venues
venues=gym1["response"]["venue"]
venues
# Out:
# {'id': '4c8f8a40d68c6dcbb91d05a2',
#  'name': 'Fitzgerald Gym',
#  'contact': {},
#  'location': {'address': 'Queens College',
#   'crossStreet': 'at 6530 Kissena Blvd',
#   'lat': 40.73805428308711,
#   'lng': -73.81960911793796,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.73805428308711,
#     'lng': -73.81960911793796}],
#   'postalCode': '11367',
#   'cc': 'US',
#   'city': 'Flushing',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['Queens College (at 6530 Kissena Blvd)',
#    'Flushing, NY 11367',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/fitzgerald-gym/4c8f8a40d68c6dcbb91d05a2',
#  'categories': [{'id': '4bf58dd8d48988d1b2941735',
#    'name': 'College Gym',
#    'pluralName': 'College Gyms',
#    'shortName': 'Gym',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d1ae941735',
#    'name': 'University',
#    'pluralName': 'Universities',
#    'shortName': 'University',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#     'suffix': '.png'}},
#   {'id': '4bf58dd8d48988d176941735',
#    'name': 'Gym',
#    'pluralName': 'Gyms',
#    'shortName': 'Gym',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#     'suffix': '.png'}}],
#  'verified': False,
#  'stats': {'tipCount': 1},
#  'likes': {'count': 23,
#   'groups': [{'type': 'others', 'count': 23, 'items': []}],
#   'summary': '23 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 7.3,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 30,
#  'venueRatingBlacklisted': True,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 1,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 1,
#     'items': [{'id': '59975272f8cbd46f1c226a06',
#       'createdAt': 1503089266,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#       'width': 3888,
#       'height': 2592,
#       'user': {'isSanctioned': False,
#        'firstName': 'pivot_photos',
#        'countryCode': 'US',
#        'type': 'page'},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1284475456,
#  'tips': {'count': 1,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 1,
#     'items': [{'id': '4d5082d89ffc236a59d119a7',
#       'createdAt': 1297122008,
#       'text': 'Try to steer clear after 4. Its suicide.',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4d5082d89ffc236a59d119a7',
#       'lang': 'en',
#       'likes': {'count': 1,
#        'groups': [{'type': 'others',
#          'count': 1,
#          'items': [{'isSanctioned': False,
#            'firstName': 'Shannon',
#            'lastName': 'C',
#            'countryCode': 'US'}]}],
#        'summary': '1 like'},
#       'logView': True,
#       'agreeCount': 2,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'isSanctioned': False,
#        'firstName': 'H Marie',
#        'lastName': 'W',
#        'countryCode': 'US'}}]}]},
#  'shortUrl': 'http://4sq.com/bSJsKi',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 1,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 1,
#     'items': [{'id': '50fc15d5e4b0b7771147885a',
#       'name': 'Places I regularly go',
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Martine',
#        'lastName': 'M',
#        'countryCode': 'US'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/45746868/list/places-i-regularly-go',
#       'canonicalUrl': 'https://foursquare.com/user/45746868/list/places-i-regularly-go',
#       'createdAt': 1358697941,
#       'updatedAt': 1362428239,
#       'followers': {'count': 0},
#       'listItems': {'count': 4,
#        'items': [{'id': 'v4c8f8a40d68c6dcbb91d05a2',
#          'createdAt': 1358697947}]}}]}]},
#  'popular': {'status': 'Likely open',
#   'richStatus': {'entities': [], 'text': 'Likely open'},
#   'isOpen': True,
#   'isLocalHoliday': True,
#   'localHolidayName': 'Thanksgiving Day',
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '10:00 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '11:00 AM–4:00 PM'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–4:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '8:00 AM–5:00 PM'}],
#     'segments': []},
#    {'days': 'Mon', 'open': [{'renderedTime': 'Noon–9:00 PM'}], 'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '8:00 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '10:00 AM–9:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'parent': {'id': '4a6f3aa4f964a520add51fe3',
#   'name': 'Queens College',
#   'location': {'address': '6530 Kissena Blvd',
#    'crossStreet': 'at 65th Ave',
#    'lat': 40.73615824752801,
#    'lng': -73.81680936831667,
#    'postalCode': '11367',
#    'cc': 'US',
#    'city': 'Flushing',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['6530 Kissena Blvd (at 65th Ave)',
#     'Flushing, NY 11367',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1ae941735',
#     'name': 'University',
#     'pluralName': 'Universities',
#     'shortName': 'University',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#      'suffix': '.png'},
#     'primary': True}]},
#  'hierarchy': [{'name': 'Queens College',
#    'lang': 'en',
#    'id': '4a6f3aa4f964a520add51fe3',
#    'canonicalUrl': 'https://foursquare.com/v/queens-college/4a6f3aa4f964a520add51fe3'}],
#  'attributes': {'groups': []},
#  'bestPhoto': {'id': '59975272f8cbd46f1c226a06',
#   'createdAt': 1503089266,
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#   'width': 3888,
#   'height': 2592,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '59975272f8cbd46f1c226a06',
#    'value': -14145480},
#   'highlightTextColor': {'photoId': '59975272f8cbd46f1c226a06', 'value': -1},
#   'algoVersion': 3}}

# %%
#En caso de que este calificado, ponemos que muestre la puntuación del gimnasio.
#En caso contrario, mostrar un mensaje de que "este lugar no ha sido puntuado aún"
try:
    print(gym1["response"]["venue"]["rating"])
except:
    print("This venue has not been rated yet.")
# Out:
# 7.3

# %%
#Finalmente, después de encontrar una valoración de un gimnasio, 
#vamos a observar cuantas opiniones tiene

# %%
gym1["response"]["venue"]["tips"]["count"]
# Out:
# 1

# %%
#Una vez que hemos comprobado el número de opiniones que hay sobre este restaurante, 
#vamos a ver la opinión disponible

#Opinión del Gimnasio

limit=1 #Define los límites para que sean mayor o igual al total de consejos para ese restaurante
url=url = "https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}".format(venue_id, CLIENT_ID,
CLIENT_SECRET, VERSION, limit)

TipsJapanese=requests.get(url).json()
TipsJapanese
# Out:
# {'meta': {'code': 200, 'requestId': '5fbfe640f295167c83e0416b'},
#  'response': {'tips': {'count': 1,
#    'items': [{'id': '4d5082d89ffc236a59d119a7',
#      'createdAt': 1297122008,
#      'text': 'Try to steer clear after 4. Its suicide.',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/4d5082d89ffc236a59d119a7',
#      'lang': 'en',
#      'likes': {'count': 1,
#       'groups': [{'type': 'others',
#         'count': 1,
#         'items': [{'isSanctioned': False,
#           'firstName': 'Shannon',
#           'lastName': 'C',
#           'countryCode': 'US'}]}],
#       'summary': '1 like'},
#      'logView': True,
#      'agreeCount': 2,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'isSanctioned': False,
#       'firstName': 'H Marie',
#       'lastName': 'W',
#       'countryCode': 'US'}}]}}}

# %%
#Vamos a conseguir extraer la opinión del gym
tips= TipsJapanese["response"]["tips"]["items"]

tip = TipsJapanese["response"]["tips"]["items"][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user'])

# %%
#Formatea el ancho de las columnas y visualiza el consejo
pd.set_option("display.max_colwidth",-1)

tips_df=pd.json_normalize(tips)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
filtered_columns =["text","agreeCount", "disagreeCount", "id"]
tips_filtered =tips_df.loc[:,filtered_columns]

# %%
#Muestra el consejo

tips_filtered.reindex()
# Out:
#                                        text  agreeCount  disagreeCount  \
# 0  Try to steer clear after 4. Its suicide.  2           0
#
#                          id
# 0  4d5082d89ffc236a59d119a7
