# %%
import requests #Biblioteca para manejar solicitudes
import pandas as pd #Biblioteca para Análisis de datos
import numpy as np #Biblioteca para manejar datos de una manera vectorizada
import random #Biblioteca para la generación de números aleatorios

# !pip install geopy
from geopy.geocoders import Nominatim #Módulo para convertir una dirección en valores de latitud y longitud

#Bibliotecas para mostrar imágenes

from IPython.display import Image
from IPython.core.display import HTML

#Transformar un archivo JSON en una biblioteca de marco de datos de pandas
from pandas.io.json import json_normalize

! pip install folium==0.5.0
import folium #Biblioteca de representación

print("Folium installed")
print("Libraries imported")
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.50)
# Collecting folium==0.5.0
# Requirement already satisfied: branca in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (0.4.1)
# Requirement already satisfied: jinja2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (3.0.4)
# Installing collected packages: folium
#   Found existing installation: folium 0.11.0
#     Uninstalling folium-0.11.0:
#       Successfully uninstalled folium-0.11.0
# Successfully installed folium-0.5.0
# Folium installed
# Libraries imported

# %%
CLIENT_ID= "VYXHEB1JFDKLQWKXQVDHVO0BIK5COTAA00QDMGTTZSE0GQPI" #Tu ID de Foursquare
CLIENT_SECRET= "5KJIO12I3YHGWNTTX2MFS011R0V2VHRRE5N1CTRPEHYLDZOX" #Tu Foursquare secreto
VERSION="20180604 "
LIMIT=10
print("Your credentials:")
print("CLIENT_ID: " + CLIENT_ID)
print("CLIENT_SECRET:" + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: VYXHEB1JFDKLQWKXQVDHVO0BIK5COTAA00QDMGTTZSE0GQPI
# CLIENT_SECRET:5KJIO12I3YHGWNTTX2MFS011R0V2VHRRE5N1CTRPEHYLDZOX

# %%
#Vamos a trabajar con un Hotel llamado "Hotel Bliss"
#que está también en Nueva York, ubicado en Queens"
Dirección="36-38 Main St, Queens, NY 11354, Estados Unidos"

geolocator =Nominatim(user_agent="foursquare_agent")
location=geolocator.geocode(Dirección)
latitude=location.latitude
longitude=location.longitude
print(latitude, longitude)
# Out:
# 40.761979 -73.83190498503652

# %%
#Ahora, vamos a definir la consulta para buscar parque, que se encuentre a 
#3000 metros de "Hotel Bliss".

search_query="Park"
radius=3000
print(search_query + ".... OK!")
# Out:
# Park.... OK!

# %%
#Ahora definimos la correspondiente URL:

url= "https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}".format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=VYXHEB1JFDKLQWKXQVDHVO0BIK5COTAA00QDMGTTZSE0GQPI&client_secret=5KJIO12I3YHGWNTTX2MFS011R0V2VHRRE5N1CTRPEHYLDZOX&ll=40.761979,-73.83190498503652&v=20180604 &query=Park&radius=3000&limit=10'

# %%
#Realizamos la solicitud de la url
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fc08b2c432e02660cd4d3f5'},
#  'response': {'venues': [{'id': '4a3d30adf964a520f0a11fe3',
#     'name': 'Flushing Meadows Corona Park',
#     'location': {'address': 'Great Lakes Ct',
#      'crossStreet': 'Dwight Eisenhower Promenade',
#      'lat': 40.74635,
#      'lng': -73.845093,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74635,
#        'lng': -73.845093}],
#      'distance': 2064,
#      'postalCode': '11368',
#      'cc': 'US',
#      'neighborhood': 'Flushing Meadows-Corona Park',
#      'city': 'Queens',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Great Lakes Ct (Dwight Eisenhower Promenade)',
#       'Queens, NY 11368',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606454060',
#     'hasPerk': False},
#    {'id': '4c03d824f56c2d7f1a601d66',
#     'name': 'Kissena Corridor Park',
#     'location': {'address': 'Elder Ave',
#      'crossStreet': 'Main St',
#      'lat': 40.74790720968901,
#      'lng': -73.82177352905273,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74790720968901,
#        'lng': -73.82177352905273}],
#      'distance': 1784,
#      'postalCode': '11355',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Elder Ave (Main St)',
#       'Flushing, NY 11355',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606454060',
#     'hasPerk': False},
#    {'id': '4b8148a6f964a5208a9d30e3',
#     'name': 'Flushing Meadows Corona Park Aquatic Center',
#     'location': {'address': '131-40 Avery Ave',
#      'crossStreet': 'at 131 St',
#      'lat': 40.751956861586315,
#      'lng': -73.8374305435798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.751956861586315,
#        'lng': -73.8374305435798}],
#      'distance': 1209,
#      'postalCode': '11355',
#      'cc': 'US',
#      'neighborhood': 'Flushing Meadows-Corona Park',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['131-40 Avery Ave (at 131 St)',
#       'Flushing, NY 11355',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606454060',
#     'hasPerk': False},
#    {'id': '4b94025ff964a520ec6034e3',
#     'name': 'Bowne Park',
#     'location': {'address': '29th Ave',
#      'crossStreet': '156th St',
#      'lat': 40.770200366990906,
#      'lng': -73.80769911868802,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.770200366990906,
#        'lng': -73.80769911868802}],
#      'distance': 2236,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['29th Ave (156th St)',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606454060',
#     'hasPerk': False},
#    {'id': '4c5bed609b28d13a854c5570',
#     'name': 'Kissena Park',
#     'location': {'address': 'Oak Ave',
#      'crossStreet': 'btwn Kissena Blvd & 164th St',
#      'lat': 40.74771541879555,
#      'lng': -73.80887669655415,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74771541879555,
#        'lng': -73.80887669655415}],
#      'distance': 2508,
#      'postalCode': '11355',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Oak Ave (btwn Kissena Blvd & 164th St)',
#       'Flushing, NY 11355',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606454060',
#     'hasPerk': False},
#    {'id': '4c093acaa1b32d7f254d97f0',
#     'name': 'Flushing Meadows Corona Skate Park',
#     'location': {'address': 'Avenue of Peace',
#      'lat': 40.74314400397063,
#      'lng': -73.84331166744232,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74314400397063,
#        'lng': -73.84331166744232}],
#      'distance': 2306,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Queens',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Avenue of Peace',
#       'Queens, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d167941735',
#       'name': 'Skate Park',
#       'pluralName': 'Skate Parks',
#       'shortName': 'Skate Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/skate_park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606454060',
#     'hasPerk': False},
#    {'id': '4ab5fbadf964a520457620e3',
#     'name': 'Hermon MacNeil Park',
#     'location': {'address': 'Poppenhusen Avenue',
#      'lat': 40.79087772222991,
#      'lng': -73.85132226744496,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79087772222991,
#        'lng': -73.85132226744496}],
#      'distance': 3609,
#      'postalCode': '10465',
#      'cc': 'US',
#      'city': 'Queens',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Poppenhusen Avenue',
#       'Queens, NY 10465',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606454060',
#     'hasPerk': False},
#    {'id': '4b808501f964a5207b7930e3',
#     'name': 'Park Side',
#     'location': {'address': '107-01 Corona Ave',
#      'lat': 40.743559,
#      'lng': -73.855704,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.743559,
#        'lng': -73.855704}],
#      'distance': 2869,
#      'postalCode': '11368',
#      'cc': 'US',
#      'neighborhood': 'South Corona',
#      'city': 'Corona',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['107-01 Corona Ave',
#       'Corona, NY 11368',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606454060',
#     'hasPerk': False},
#    {'id': '4c4b31eb5609c9b673b6cd90',
#     'name': 'New York Hall of Science Rocket Park',
#     'location': {'lat': 40.74774321341449,
#      'lng': -73.85214351937607,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74774321341449,
#        'lng': -73.85214351937607}],
#      'distance': 2328,
#      'postalCode': '11368',
#      'cc': 'US',
#      'city': 'Corona',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Corona, NY 11368', 'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b79eb',
#       'name': 'Mini Golf',
#       'pluralName': 'Mini Golf Courses',
#       'shortName': 'Mini Golf',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/golfcourse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606454060',
#     'hasPerk': False},
#    {'id': '51c205fc498e2febc3fe122d',
#     'name': 'Fantasy Forest Amusement Park at the Flushing Meadows Carousel',
#     'location': {'address': '111th Street & 55th Avenue',
#      'lat': 40.74325020570866,
#      'lng': -73.84902152588148,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74325020570866,
#        'lng': -73.84902152588148}],
#      'distance': 2535,
#      'postalCode': '11368',
#      'cc': 'US',
#      'city': 'Corona',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['111th Street & 55th Avenue',
#       'Corona, NY 11368',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606454060',
#     'hasPerk': False}]}}

# %%
#Asigna la parte relevante de JSON a lugares
venues=results["response"]["venues"]

# %%
#Transforma los lugares en un marco de datos

dataframe=pd.json_normalize(venues)
dataframe.head(30)
# Out:
#                          id  \
# 0  4a3d30adf964a520f0a11fe3
# 1  4c03d824f56c2d7f1a601d66
# 2  4b8148a6f964a5208a9d30e3
# 3  4b94025ff964a520ec6034e3
# 4  4c5bed609b28d13a854c5570
# 5  4c093acaa1b32d7f254d97f0
# 6  4ab5fbadf964a520457620e3
# 7  4b808501f964a5207b7930e3
# 8  4c4b31eb5609c9b673b6cd90
# 9  51c205fc498e2febc3fe122d
#
#                                                 name  \
# 0                       Flushing Meadows Corona Park
# 1                              Kissena Corridor Park
# 2        Flushing Meadows Corona Park Aquatic Center
# 3                                         Bowne Park
# 4                                       Kissena Park
# 5                 Flushing Meadows Corona Skate Park
# 6                                Hermon MacNeil Park
# 7                                          Park Side
# 8               New York Hall of Science Rocket Park
# 9  Fantasy Forest Amusement Park at the Flushing ...
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1606454060    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1606454060    False
# 2  [{'id': '4bf58dd8d48988d15e941735', 'name': 'P...  v-1606454060    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1606454060    False
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1606454060    False
# 5  [{'id': '4bf58dd8d48988d167941735', 'name': 'S...  v-1606454060    False
# 6  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1606454060    False
# 7  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1606454060    False
# 8  [{'id': '52e81612bcbc57f1066b79eb', 'name': 'M...  v-1606454060    False
# 9  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1606454060    False
#
#              location.address          location.crossStreet  location.lat  \
# 0              Great Lakes Ct   Dwight Eisenhower Promenade     40.746350
# 1                   Elder Ave                       Main St     40.747907
# 2            131-40 Avery Ave                     at 131 St     40.751957
# 3                    29th Ave                      156th St     40.770200
# 4                     Oak Ave  btwn Kissena Blvd & 164th St     40.747715
# 5             Avenue of Peace                           NaN     40.743144
# 6          Poppenhusen Avenue                           NaN     40.790878
# 7           107-01 Corona Ave                           NaN     40.743559
# 8                         NaN                           NaN     40.747743
# 9  111th Street & 55th Avenue                           NaN     40.743250
#
#    location.lng                            location.labeledLatLngs  \
# 0    -73.845093  [{'label': 'display', 'lat': 40.74635, 'lng': ...
# 1    -73.821774  [{'label': 'display', 'lat': 40.74790720968901...
# 2    -73.837431  [{'label': 'display', 'lat': 40.75195686158631...
# 3    -73.807699  [{'label': 'display', 'lat': 40.77020036699090...
# 4    -73.808877  [{'label': 'display', 'lat': 40.74771541879555...
# 5    -73.843312  [{'label': 'display', 'lat': 40.74314400397063...
# 6    -73.851322  [{'label': 'display', 'lat': 40.79087772222991...
# 7    -73.855704  [{'label': 'display', 'lat': 40.743559, 'lng':...
# 8    -73.852144  [{'label': 'display', 'lat': 40.74774321341449...
# 9    -73.849022  [{'label': 'display', 'lat': 40.74325020570866...
#
#    location.distance location.postalCode location.cc  \
# 0               2064               11368          US
# 1               1784               11355          US
# 2               1209               11355          US
# 3               2236               11354          US
# 4               2508               11355          US
# 5               2306               11354          US
# 6               3609               10465          US
# 7               2869               11368          US
# 8               2328               11368          US
# 9               2535               11368          US
#
#           location.neighborhood location.city location.state location.country  \
# 0  Flushing Meadows-Corona Park        Queens             NY    United States
# 1                           NaN      Flushing             NY    United States
# 2  Flushing Meadows-Corona Park      Flushing             NY    United States
# 3                           NaN      Flushing             NY    United States
# 4                           NaN      Flushing             NY    United States
# 5                           NaN        Queens             NY    United States
# 6                           NaN        Queens             NY    United States
# 7                  South Corona        Corona             NY    United States
# 8                           NaN        Corona             NY    United States
# 9                           NaN        Corona             NY    United States
#
#                            location.formattedAddress
# 0  [Great Lakes Ct (Dwight Eisenhower Promenade),...
# 1  [Elder Ave (Main St), Flushing, NY 11355, Unit...
# 2  [131-40 Avery Ave (at 131 St), Flushing, NY 11...
# 3  [29th Ave (156th St), Flushing, NY 11354, Unit...
# 4  [Oak Ave (btwn Kissena Blvd & 164th St), Flush...
# 5  [Avenue of Peace, Queens, NY 11354, United Sta...
# 6  [Poppenhusen Avenue, Queens, NY 10465, United ...
# 7  [107-01 Corona Ave, Corona, NY 11368, United S...
# 8                  [Corona, NY 11368, United States]
# 9  [111th Street & 55th Avenue, Corona, NY 11368,...

# %%
#Mantén solo las columnas que incluyan el nombre del lugar, y cualquier cosas que esté asociada con la localización

filtered_columns =["name","categories"]+[col for col in dataframe.columns if col.startswith("location.")]+["id"]
dataframe_filtered = dataframe.loc[:, filtered_columns]

# %%
#A continuación, vamos a extraer la categoría del lugar

def get_category_type(row):
    try:
        categories_list = row["categories"]
    except:
        categories_list= row["venue.categories"]
    if len (categories_list)==0:
       return None
    else:
       return categories_list[0]["name"]

# %%
#Se filtra la categoría por cada fila
dataframe_filtered["categories"] = dataframe_filtered.apply(get_category_type, axis=1)

# %%
#Limpiamos los nombres de la columna manteniendo solo el último término
dataframe_filtered.columns =[column.split(".")[-1] for column in dataframe_filtered.columns]

# %%
dataframe_filtered
# Out:
#                                                 name          categories  \
# 0                       Flushing Meadows Corona Park                Park
# 1                              Kissena Corridor Park                Park
# 2        Flushing Meadows Corona Park Aquatic Center                Pool
# 3                                         Bowne Park                Park
# 4                                       Kissena Park                Park
# 5                 Flushing Meadows Corona Skate Park          Skate Park
# 6                                Hermon MacNeil Park                Park
# 7                                          Park Side  Italian Restaurant
# 8               New York Hall of Science Rocket Park           Mini Golf
# 9  Fantasy Forest Amusement Park at the Flushing ...                Park
#
#                       address                   crossStreet        lat  \
# 0              Great Lakes Ct   Dwight Eisenhower Promenade  40.746350
# 1                   Elder Ave                       Main St  40.747907
# 2            131-40 Avery Ave                     at 131 St  40.751957
# 3                    29th Ave                      156th St  40.770200
# 4                     Oak Ave  btwn Kissena Blvd & 164th St  40.747715
# 5             Avenue of Peace                           NaN  40.743144
# 6          Poppenhusen Avenue                           NaN  40.790878
# 7           107-01 Corona Ave                           NaN  40.743559
# 8                         NaN                           NaN  40.747743
# 9  111th Street & 55th Avenue                           NaN  40.743250
#
#          lng                                     labeledLatLngs  distance  \
# 0 -73.845093  [{'label': 'display', 'lat': 40.74635, 'lng': ...      2064
# 1 -73.821774  [{'label': 'display', 'lat': 40.74790720968901...      1784
# 2 -73.837431  [{'label': 'display', 'lat': 40.75195686158631...      1209
# 3 -73.807699  [{'label': 'display', 'lat': 40.77020036699090...      2236
# 4 -73.808877  [{'label': 'display', 'lat': 40.74771541879555...      2508
# 5 -73.843312  [{'label': 'display', 'lat': 40.74314400397063...      2306
# 6 -73.851322  [{'label': 'display', 'lat': 40.79087772222991...      3609
# 7 -73.855704  [{'label': 'display', 'lat': 40.743559, 'lng':...      2869
# 8 -73.852144  [{'label': 'display', 'lat': 40.74774321341449...      2328
# 9 -73.849022  [{'label': 'display', 'lat': 40.74325020570866...      2535
#
#   postalCode  cc                  neighborhood      city state        country  \
# 0      11368  US  Flushing Meadows-Corona Park    Queens    NY  United States
# 1      11355  US                           NaN  Flushing    NY  United States
# 2      11355  US  Flushing Meadows-Corona Park  Flushing    NY  United States
# 3      11354  US                           NaN  Flushing    NY  United States
# 4      11355  US                           NaN  Flushing    NY  United States
# 5      11354  US                           NaN    Queens    NY  United States
# 6      10465  US                           NaN    Queens    NY  United States
# 7      11368  US                  South Corona    Corona    NY  United States
# 8      11368  US                           NaN    Corona    NY  United States
# 9      11368  US                           NaN    Corona    NY  United States
#
#                                     formattedAddress                        id
# 0  [Great Lakes Ct (Dwight Eisenhower Promenade),...  4a3d30adf964a520f0a11fe3
# 1  [Elder Ave (Main St), Flushing, NY 11355, Unit...  4c03d824f56c2d7f1a601d66
# 2  [131-40 Avery Ave (at 131 St), Flushing, NY 11...  4b8148a6f964a5208a9d30e3
# 3  [29th Ave (156th St), Flushing, NY 11354, Unit...  4b94025ff964a520ec6034e3
# 4  [Oak Ave (btwn Kissena Blvd & 164th St), Flush...  4c5bed609b28d13a854c5570
# 5  [Avenue of Peace, Queens, NY 11354, United Sta...  4c093acaa1b32d7f254d97f0
# 6  [Poppenhusen Avenue, Queens, NY 10465, United ...  4ab5fbadf964a520457620e3
# 7  [107-01 Corona Ave, Corona, NY 11368, United S...  4b808501f964a5207b7930e3
# 8                  [Corona, NY 11368, United States]  4c4b31eb5609c9b673b6cd90
# 9  [111th Street & 55th Avenue, Corona, NY 11368,...  51c205fc498e2febc3fe122d

# %%
#Vamos a visualizar los resultados de parques que hemos encontrado
dataframe_filtered.name
# Out:
# 0                         Flushing Meadows Corona Park
# 1                                Kissena Corridor Park
# 2          Flushing Meadows Corona Park Aquatic Center
# 3                                           Bowne Park
# 4                                         Kissena Park
# 5                   Flushing Meadows Corona Skate Park
# 6                                  Hermon MacNeil Park
# 7                                            Park Side
# 8                 New York Hall of Science Rocket Park
# 9    Fantasy Forest Amusement Park at the Flushing ...
# Name: name, dtype: object

# %%
#Vamos a mejorar folium con una actualización
# !pip install folium --upgrade
# Out:
# Collecting folium
#   Using cached https://files.pythonhosted.org/packages/a4/f0/44e69d50519880287cc41e7c8a6acc58daa9a9acf5f6afc52bcc70f69a6d/folium-0.11.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: numpy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (1.19.2)
# Requirement already satisfied, skipping upgrade: jinja2>=2.9 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.11.2)
# Requirement already satisfied, skipping upgrade: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.24.0)
# Requirement already satisfied, skipping upgrade: branca>=0.3.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (1.25.11)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Installing collected packages: folium
#   Found existing installation: folium 0.5.0
#     Uninstalling folium-0.5.0:
#       Successfully uninstalled folium-0.5.0
# Successfully installed folium-0.11.0

# %%
Park_map = folium.Map(location=[latitude, longitude], zoom_start=20) #genera una mapa centrado
#añade una marca de círculo naranja para representar "Hotel Bliss"
          
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color="black",
    popup="Hotel Bliss",
    fill=True,
    fill_color="orange",
    fill_opacity=0.6
).add_to(Park_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat,lng],
        radius=8,
        color="black",
        popup=label,
        fill=True,
        fill_color="red",
        fill_opacity=0.6
).add_to(Park_map)

# %%
Park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#A continuación, vamos a explorar unos cuantos parques. 
#El 1 parque es el "Flushing Meadows Corona Park":

venue_id="4a3d30adf964a520f0a11fe3"
url = "https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}".format(venue_id, CLIENT_ID,
CLIENT_SECRET, VERSION)
print("Todo ha salido correcto")
# Out:
# Todo ha salido correcto

# %%
#Enviemos la solicitud del get para el resultado

Park1 = requests.get(url).json()
Park1
# Out:
# {'meta': {'code': 200, 'requestId': '5fc08b3cfa2a142aa65d0c11'},
#  'response': {'venue': {'id': '4a3d30adf964a520f0a11fe3',
#    'name': 'Flushing Meadows Corona Park',
#    'contact': {'phone': '2126399675',
#     'formattedPhone': '(212) 639-9675',
#     'twitter': 'nycparks',
#     'facebook': '104475634308',
#     'facebookUsername': 'BartowPell',
#     'facebookName': 'Bartow-Pell Mansion Museum'},
#    'location': {'address': 'Great Lakes Ct',
#     'crossStreet': 'Dwight Eisenhower Promenade',
#     'lat': 40.74635,
#     'lng': -73.845093,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.74635,
#       'lng': -73.845093}],
#     'postalCode': '11368',
#     'cc': 'US',
#     'neighborhood': 'Flushing Meadows-Corona Park',
#     'city': 'Queens',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['Great Lakes Ct (Dwight Eisenhower Promenade)',
#      'Queens, NY 11368',
#      'United States']},
#    'canonicalUrl': 'https://foursquare.com/v/flushing-meadows-corona-park/4a3d30adf964a520f0a11fe3',
#    'categories': [{'id': '4bf58dd8d48988d163941735',
#      'name': 'Park',
#      'pluralName': 'Parks',
#      'shortName': 'Park',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 84},
#    'url': 'http://nyc.gov/parks',
#    'likes': {'count': 782,
#     'groups': [{'type': 'others', 'count': 782, 'items': []}],
#     'summary': '782 Likes'},
#    'dislike': False,
#    'ok': False,
#    'rating': 9.1,
#    'ratingColor': '00B551',
#    'ratingSignals': 921,
#    'beenHere': {'count': 0,
#     'unconfirmedCount': 0,
#     'marked': False,
#     'lastCheckinExpiredAt': 0},
#    'specials': {'count': 0, 'items': []},
#    'photos': {'count': 1769,
#     'groups': [{'type': 'venue',
#       'name': 'Venue photos',
#       'count': 1769,
#       'items': [{'id': '5182e140498ef80aac4d34a6',
#         'createdAt': 1367531840,
#         'source': {'name': 'Foursquare for Android',
#          'url': 'https://foursquare.com/download/#/android'},
#         'prefix': 'https://fastly.4sqi.net/img/general/',
#         'suffix': '/1087241_uSCL8v-18QdDNSGVd5gZTgsDhFEDVa6C94-D9hD-yxY.jpg',
#         'width': 960,
#         'height': 540,
#         'user': {'isSanctioned': False,
#          'firstName': 'Miles',
#          'lastName': 'H',
#          'countryCode': 'US'},
#         'visibility': 'public'}]}]},
#    'reasons': {'count': 1,
#     'items': [{'summary': 'Lots of people like this place',
#       'type': 'general',
#       'reasonName': 'rawLikesReason'}]},
#    'page': {'pageInfo': {'description': "New York City Department of Parks & Recreation is the steward of 5,000 of New York City’s parks and park properties—that’s 14 percent of the city! You can follow NYC Parks for expert tips in every corner of the city. Be sure to check in at New York City’s parks, playgrounds, recreation centers, monuments, food carts, and facilities to become a true New York explorer! Please read the City of New York's Social Media Customer Use Policy at nyc.gov/socialmediapolicy for information on communicating with Parks through social media. All service requests should be submitted through nyc.gov/311.",
#      'banner': 'https://is1.4sqi.net/userpix/KXPD2QEIPQPKFXPO.gif',
#      'links': {'count': 1, 'items': [{'url': 'http://nyc.gov/parks'}]}},
#     'user': {'isSanctioned': False,
#      'firstName': 'NYC Parks',
#      'countryCode': 'US',
#      'type': 'chain',
#      'tips': {'count': 28819},
#      'lists': {'groups': [{'type': 'created', 'count': 23, 'items': []}]},
#      'bio': ''}},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'createdAt': 1245524141,
#    'tips': {'count': 84,
#     'groups': [{'type': 'others',
#       'name': 'All tips',
#       'count': 84,
#       'items': [{'id': '4eaf01629a521bacdb20fac7',
#         'createdAt': 1320092002,
#         'text': 'The best place to remember why you love Queens contains the Mets stadium, the New York Hall of Science, the home of the US Open, the iconic Unisphere. and the Queens Museum of Art.',
#         'type': 'user',
#         'url': 'http://newyork.timeout.com/things-to-do/2157709/the-best-of-nyc?page=0,4?cmpid=4sq',
#         'canonicalUrl': 'https://foursquare.com/item/4eaf01629a521bacdb20fac7',
#         'lang': 'en',
#         'likes': {'count': 30,
#          'groups': [{'type': 'others', 'count': 30, 'items': []}],
#          'summary': '30 likes'},
#         'logView': True,
#         'agreeCount': 30,
#         'disagreeCount': 0,
#         'todo': {'count': 56},
#         'user': {'isSanctioned': False,
#          'firstName': 'Time Out New York',
#          'countryCode': 'US',
#          'type': 'page'}}]}]},
#    'shortUrl': 'http://4sq.com/7PJK3i',
#    'timeZone': 'America/New_York',
#    'listed': {'count': 434,
#     'groups': [{'type': 'others',
#       'name': 'Lists from other people',
#       'count': 434,
#       'items': [{'id': '4fe9eccde4b04eb2ed705fc3',
#         'name': 'Abandoned NYC',
#         'description': "These are Untapped Cities' favorite abandoned spots in NYC. Some are break-in-able, some open to the public, some only for the intrepid.",
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'Untapped Cities',
#          'countryCode': 'US',
#          'type': 'page'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/untappedcities/list/abandoned-nyc',
#         'canonicalUrl': 'https://foursquare.com/untappedcities/list/abandoned-nyc',
#         'createdAt': 1340730573,
#         'updatedAt': 1426280186,
#         'photo': {'id': '500978aaf136e7d262915206',
#          'createdAt': 1342797994,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/1jUEao1oirtmdKLt6L40YkxfrM2WXekFVxzb7jW3ivY.jpg',
#          'width': 640,
#          'height': 427,
#          'user': {'isSanctioned': False,
#           'firstName': 'Untapped Cities',
#           'countryCode': 'US',
#           'type': 'page'},
#          'visibility': 'public'},
#         'logView': True,
#         'followers': {'count': 1702},
#         'listItems': {'count': 63,
#          'items': [{'id': 't52e01efe498ef9a90c18bc42',
#            'createdAt': 1390419646,
#            'photo': {'id': '529a47a011d2eb88df499249',
#             'createdAt': 1385842592,
#             'prefix': 'https://fastly.4sqi.net/img/general/',
#             'suffix': '/1600606_W3HmtMyu-e4nyXZD4f-ZtxaQGfskcThyBcjYK_49x30.jpg',
#             'width': 720,
#             'height': 960,
#             'user': {'isSanctioned': False,
#              'firstName': 'Daniil',
#              'lastName': 'M',
#              'countryCode': 'EE'},
#             'visibility': 'public'}},
#           {'id': 't5503218e498e7f7ad4a2af8c',
#            'createdAt': 1426268331,
#            'photo': {'id': '5503218a498effaf90b6970a',
#             'createdAt': 1426268554,
#             'prefix': 'https://fastly.4sqi.net/img/general/',
#             'suffix': '/24933846_dOFVGhVb2KjZdu9CJuiOzmUH8DSlr0n1ANA-JGGIOuU.jpg',
#             'width': 640,
#             'height': 360,
#             'user': {'isSanctioned': False,
#              'firstName': 'Untapped Cities',
#              'countryCode': 'US',
#              'type': 'page'},
#             'visibility': 'public'}}]}},
#        {'id': '4ffdb059e4b08c5c1be706c8',
#         'name': 'NYC Public WiFi Hotspots',
#         'description': '',
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'City of New York',
#          'countryCode': 'US',
#          'type': 'page'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/nycgov/list/nyc-public-wifi-hotspots',
#         'canonicalUrl': 'https://foursquare.com/nycgov/list/nyc-public-wifi-hotspots',
#         'createdAt': 1342025817,
#         'updatedAt': 1418247959,
#         'photo': {'id': '4f67b036c2ee09e7b3e39f85',
#          'createdAt': 1332195382,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/eMJwtPayfx1FyrTI1fH7optehO4aMcsz8CEqtNweEks.jpg',
#          'width': 640,
#          'height': 480,
#          'user': {'isSanctioned': False,
#           'firstName': 'NYC Parks',
#           'countryCode': 'US',
#           'type': 'chain'},
#          'visibility': 'public'},
#         'logView': True,
#         'followers': {'count': 1697},
#         'listItems': {'count': 47,
#          'items': [{'id': 'v4a3d30adf964a520f0a11fe3',
#            'createdAt': 1348157374,
#            'photo': {'id': '5053bef5e4b012cb81a9d311',
#             'createdAt': 1347665653,
#             'prefix': 'https://fastly.4sqi.net/img/general/',
#             'suffix': '/35158558_49c5STHYQvoi0sItCeEgcqmhZXZuVAepMlwB-f33zEA.jpg',
#             'width': 540,
#             'height': 720,
#             'user': {'isSanctioned': False,
#              'firstName': 'César',
#              'lastName': 'D',
#              'countryCode': 'CA'},
#             'visibility': 'public'}}]}},
#        {'id': '4ea5c0d78b814c68aca03964',
#         'name': 'Best of NYC 2011',
#         'description': 'Remind yourself why this is the greatest city in the world by experiencing the best of it.',
#         'type': 'others',
#         'user': {'isSanctioned': False,
#          'firstName': 'Time Out New York',
#          'countryCode': 'US',
#          'type': 'page'},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/timeoutnewyork/list/best-of-nyc-2011',
#         'canonicalUrl': 'https://foursquare.com/timeoutnewyork/list/best-of-nyc-2011',
#         'createdAt': 1319485655,
#         'updatedAt': 1407019829,
#         'photo': {'id': '4eb06cf1f9f463d3c3d23c8a',
#          'createdAt': 1320185073,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/IZBOFI2OHBDKEDRTTDORBD4ZWT4HYUTQRZYCD2ENFTI1FU0L.jpg',
#          'width': 492,
#          'height': 330,
#          'user': {'isSanctioned': False,
#           'firstName': 'Time Out New York',
#           'countryCode': 'US',
#           'type': 'page'},
#          'visibility': 'public'},
#         'logView': True,
#         'followers': {'count': 5835},
#         'listItems': {'count': 52,
#          'items': [{'id': 't4eaf01629a521bacdb20fac7',
#            'createdAt': 1320091986,
#            'photo': {'id': '4eb07a51754a93b634d9feb8',
#             'createdAt': 1320188497,
#             'prefix': 'https://fastly.4sqi.net/img/general/',
#             'suffix': '/KENZYFWGJ3KZXQUYR4UFMEEIPH0WLVWPZOP03L2VIHVDXLOO.jpg',
#             'width': 492,
#             'height': 330,
#             'user': {'isSanctioned': False,
#              'firstName': 'Time Out New York',
#              'countryCode': 'US',
#              'type': 'page'},
#             'visibility': 'public'}}]}}]}]},
#    'popular': {'isOpen': False,
#     'isLocalHoliday': False,
#     'timeframes': [{'days': 'Today',
#       'includesToday': True,
#       'open': [{'renderedTime': 'Noon–1:00 PM'},
#        {'renderedTime': '5:00 PM–7:00 PM'}],
#       'segments': []},
#      {'days': 'Sat',
#       'open': [{'renderedTime': '7:00 AM–9:00 PM'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': '7:00 AM–8:00 PM'}],
#       'segments': []},
#      {'days': 'Mon',
#       'open': [{'renderedTime': '8:00 AM–9:00 AM'},
#        {'renderedTime': '3:00 PM–6:00 PM'}],
#       'segments': []},
#      {'days': 'Tue',
#       'open': [{'renderedTime': '8:00 AM–9:00 AM'},
#        {'renderedTime': 'Noon–1:00 PM'},
#        {'renderedTime': '6:00 PM–7:00 PM'}],
#       'segments': []},
#      {'days': 'Wed',
#       'open': [{'renderedTime': '8:00 AM–9:00 AM'},
#        {'renderedTime': '5:00 PM–7:00 PM'}],
#       'segments': []},
#      {'days': 'Thu',
#       'open': [{'renderedTime': '8:00 AM–9:00 AM'},
#        {'renderedTime': '6:00 PM–8:00 PM'}],
#       'segments': []}]},
#    'seasonalHours': [],
#    'pageUpdates': {'count': 0, 'items': []},
#    'inbox': {'count': 0, 'items': []},
#    'attributes': {'groups': [{'type': 'wifi',
#       'name': 'Wi-Fi',
#       'summary': 'Wi-Fi',
#       'count': 1,
#       'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Yes'}]}]},
#    'bestPhoto': {'id': '5182e140498ef80aac4d34a6',
#     'createdAt': 1367531840,
#     'source': {'name': 'Foursquare for Android',
#      'url': 'https://foursquare.com/download/#/android'},
#     'prefix': 'https://fastly.4sqi.net/img/general/',
#     'suffix': '/1087241_uSCL8v-18QdDNSGVd5gZTgsDhFEDVa6C94-D9hD-yxY.jpg',
#     'width': 960,
#     'height': 540,
#     'visibility': 'public'},
#    'colors': {'highlightColor': {'photoId': '5182e140498ef80aac4d34a6',
#      'value': -12019504},
#     'highlightTextColor': {'photoId': '5182e140498ef80aac4d34a6',
#      'value': -16777216},
#     'algoVersion': 3}}}}

# %%
#Vamos a definir la variable venues
venues=Park1["response"]["venue"]
venues
# Out:
# {'id': '4a3d30adf964a520f0a11fe3',
#  'name': 'Flushing Meadows Corona Park',
#  'contact': {'phone': '2126399675',
#   'formattedPhone': '(212) 639-9675',
#   'twitter': 'nycparks',
#   'facebook': '104475634308',
#   'facebookUsername': 'BartowPell',
#   'facebookName': 'Bartow-Pell Mansion Museum'},
#  'location': {'address': 'Great Lakes Ct',
#   'crossStreet': 'Dwight Eisenhower Promenade',
#   'lat': 40.74635,
#   'lng': -73.845093,
#   'labeledLatLngs': [{'label': 'display', 'lat': 40.74635, 'lng': -73.845093}],
#   'postalCode': '11368',
#   'cc': 'US',
#   'neighborhood': 'Flushing Meadows-Corona Park',
#   'city': 'Queens',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['Great Lakes Ct (Dwight Eisenhower Promenade)',
#    'Queens, NY 11368',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/flushing-meadows-corona-park/4a3d30adf964a520f0a11fe3',
#  'categories': [{'id': '4bf58dd8d48988d163941735',
#    'name': 'Park',
#    'pluralName': 'Parks',
#    'shortName': 'Park',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': True,
#  'stats': {'tipCount': 84},
#  'url': 'http://nyc.gov/parks',
#  'likes': {'count': 782,
#   'groups': [{'type': 'others', 'count': 782, 'items': []}],
#   'summary': '782 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 9.1,
#  'ratingColor': '00B551',
#  'ratingSignals': 921,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 1769,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 1769,
#     'items': [{'id': '5182e140498ef80aac4d34a6',
#       'createdAt': 1367531840,
#       'source': {'name': 'Foursquare for Android',
#        'url': 'https://foursquare.com/download/#/android'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/1087241_uSCL8v-18QdDNSGVd5gZTgsDhFEDVa6C94-D9hD-yxY.jpg',
#       'width': 960,
#       'height': 540,
#       'user': {'isSanctioned': False,
#        'firstName': 'Miles',
#        'lastName': 'H',
#        'countryCode': 'US'},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'page': {'pageInfo': {'description': "New York City Department of Parks & Recreation is the steward of 5,000 of New York City’s parks and park properties—that’s 14 percent of the city! You can follow NYC Parks for expert tips in every corner of the city. Be sure to check in at New York City’s parks, playgrounds, recreation centers, monuments, food carts, and facilities to become a true New York explorer! Please read the City of New York's Social Media Customer Use Policy at nyc.gov/socialmediapolicy for information on communicating with Parks through social media. All service requests should be submitted through nyc.gov/311.",
#    'banner': 'https://is1.4sqi.net/userpix/KXPD2QEIPQPKFXPO.gif',
#    'links': {'count': 1, 'items': [{'url': 'http://nyc.gov/parks'}]}},
#   'user': {'isSanctioned': False,
#    'firstName': 'NYC Parks',
#    'countryCode': 'US',
#    'type': 'chain',
#    'tips': {'count': 28819},
#    'lists': {'groups': [{'type': 'created', 'count': 23, 'items': []}]},
#    'bio': ''}},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1245524141,
#  'tips': {'count': 84,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 84,
#     'items': [{'id': '4eaf01629a521bacdb20fac7',
#       'createdAt': 1320092002,
#       'text': 'The best place to remember why you love Queens contains the Mets stadium, the New York Hall of Science, the home of the US Open, the iconic Unisphere. and the Queens Museum of Art.',
#       'type': 'user',
#       'url': 'http://newyork.timeout.com/things-to-do/2157709/the-best-of-nyc?page=0,4?cmpid=4sq',
#       'canonicalUrl': 'https://foursquare.com/item/4eaf01629a521bacdb20fac7',
#       'lang': 'en',
#       'likes': {'count': 30,
#        'groups': [{'type': 'others', 'count': 30, 'items': []}],
#        'summary': '30 likes'},
#       'logView': True,
#       'agreeCount': 30,
#       'disagreeCount': 0,
#       'todo': {'count': 56},
#       'user': {'isSanctioned': False,
#        'firstName': 'Time Out New York',
#        'countryCode': 'US',
#        'type': 'page'}}]}]},
#  'shortUrl': 'http://4sq.com/7PJK3i',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 434,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 434,
#     'items': [{'id': '4fe9eccde4b04eb2ed705fc3',
#       'name': 'Abandoned NYC',
#       'description': "These are Untapped Cities' favorite abandoned spots in NYC. Some are break-in-able, some open to the public, some only for the intrepid.",
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Untapped Cities',
#        'countryCode': 'US',
#        'type': 'page'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/untappedcities/list/abandoned-nyc',
#       'canonicalUrl': 'https://foursquare.com/untappedcities/list/abandoned-nyc',
#       'createdAt': 1340730573,
#       'updatedAt': 1426280186,
#       'photo': {'id': '500978aaf136e7d262915206',
#        'createdAt': 1342797994,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/1jUEao1oirtmdKLt6L40YkxfrM2WXekFVxzb7jW3ivY.jpg',
#        'width': 640,
#        'height': 427,
#        'user': {'isSanctioned': False,
#         'firstName': 'Untapped Cities',
#         'countryCode': 'US',
#         'type': 'page'},
#        'visibility': 'public'},
#       'logView': True,
#       'followers': {'count': 1702},
#       'listItems': {'count': 63,
#        'items': [{'id': 't52e01efe498ef9a90c18bc42',
#          'createdAt': 1390419646,
#          'photo': {'id': '529a47a011d2eb88df499249',
#           'createdAt': 1385842592,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/1600606_W3HmtMyu-e4nyXZD4f-ZtxaQGfskcThyBcjYK_49x30.jpg',
#           'width': 720,
#           'height': 960,
#           'user': {'isSanctioned': False,
#            'firstName': 'Daniil',
#            'lastName': 'M',
#            'countryCode': 'EE'},
#           'visibility': 'public'}},
#         {'id': 't5503218e498e7f7ad4a2af8c',
#          'createdAt': 1426268331,
#          'photo': {'id': '5503218a498effaf90b6970a',
#           'createdAt': 1426268554,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/24933846_dOFVGhVb2KjZdu9CJuiOzmUH8DSlr0n1ANA-JGGIOuU.jpg',
#           'width': 640,
#           'height': 360,
#           'user': {'isSanctioned': False,
#            'firstName': 'Untapped Cities',
#            'countryCode': 'US',
#            'type': 'page'},
#           'visibility': 'public'}}]}},
#      {'id': '4ffdb059e4b08c5c1be706c8',
#       'name': 'NYC Public WiFi Hotspots',
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'City of New York',
#        'countryCode': 'US',
#        'type': 'page'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/nycgov/list/nyc-public-wifi-hotspots',
#       'canonicalUrl': 'https://foursquare.com/nycgov/list/nyc-public-wifi-hotspots',
#       'createdAt': 1342025817,
#       'updatedAt': 1418247959,
#       'photo': {'id': '4f67b036c2ee09e7b3e39f85',
#        'createdAt': 1332195382,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/eMJwtPayfx1FyrTI1fH7optehO4aMcsz8CEqtNweEks.jpg',
#        'width': 640,
#        'height': 480,
#        'user': {'isSanctioned': False,
#         'firstName': 'NYC Parks',
#         'countryCode': 'US',
#         'type': 'chain'},
#        'visibility': 'public'},
#       'logView': True,
#       'followers': {'count': 1697},
#       'listItems': {'count': 47,
#        'items': [{'id': 'v4a3d30adf964a520f0a11fe3',
#          'createdAt': 1348157374,
#          'photo': {'id': '5053bef5e4b012cb81a9d311',
#           'createdAt': 1347665653,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/35158558_49c5STHYQvoi0sItCeEgcqmhZXZuVAepMlwB-f33zEA.jpg',
#           'width': 540,
#           'height': 720,
#           'user': {'isSanctioned': False,
#            'firstName': 'César',
#            'lastName': 'D',
#            'countryCode': 'CA'},
#           'visibility': 'public'}}]}},
#      {'id': '4ea5c0d78b814c68aca03964',
#       'name': 'Best of NYC 2011',
#       'description': 'Remind yourself why this is the greatest city in the world by experiencing the best of it.',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Time Out New York',
#        'countryCode': 'US',
#        'type': 'page'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/timeoutnewyork/list/best-of-nyc-2011',
#       'canonicalUrl': 'https://foursquare.com/timeoutnewyork/list/best-of-nyc-2011',
#       'createdAt': 1319485655,
#       'updatedAt': 1407019829,
#       'photo': {'id': '4eb06cf1f9f463d3c3d23c8a',
#        'createdAt': 1320185073,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/IZBOFI2OHBDKEDRTTDORBD4ZWT4HYUTQRZYCD2ENFTI1FU0L.jpg',
#        'width': 492,
#        'height': 330,
#        'user': {'isSanctioned': False,
#         'firstName': 'Time Out New York',
#         'countryCode': 'US',
#         'type': 'page'},
#        'visibility': 'public'},
#       'logView': True,
#       'followers': {'count': 5835},
#       'listItems': {'count': 52,
#        'items': [{'id': 't4eaf01629a521bacdb20fac7',
#          'createdAt': 1320091986,
#          'photo': {'id': '4eb07a51754a93b634d9feb8',
#           'createdAt': 1320188497,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/KENZYFWGJ3KZXQUYR4UFMEEIPH0WLVWPZOP03L2VIHVDXLOO.jpg',
#           'width': 492,
#           'height': 330,
#           'user': {'isSanctioned': False,
#            'firstName': 'Time Out New York',
#            'countryCode': 'US',
#            'type': 'page'},
#           'visibility': 'public'}}]}}]}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': 'Noon–1:00 PM'},
#      {'renderedTime': '5:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '7:00 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '7:00 AM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '8:00 AM–9:00 AM'},
#      {'renderedTime': '3:00 PM–6:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '8:00 AM–9:00 AM'},
#      {'renderedTime': 'Noon–1:00 PM'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '8:00 AM–9:00 AM'},
#      {'renderedTime': '5:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '8:00 AM–9:00 AM'},
#      {'renderedTime': '6:00 PM–8:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'wifi',
#     'name': 'Wi-Fi',
#     'summary': 'Wi-Fi',
#     'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Yes'}]}]},
#  'bestPhoto': {'id': '5182e140498ef80aac4d34a6',
#   'createdAt': 1367531840,
#   'source': {'name': 'Foursquare for Android',
#    'url': 'https://foursquare.com/download/#/android'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/1087241_uSCL8v-18QdDNSGVd5gZTgsDhFEDVa6C94-D9hD-yxY.jpg',
#   'width': 960,
#   'height': 540,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '5182e140498ef80aac4d34a6',
#    'value': -12019504},
#   'highlightTextColor': {'photoId': '5182e140498ef80aac4d34a6',
#    'value': -16777216},
#   'algoVersion': 3}}

# %%
#En caso de que este calificado, ponemos que muestre la puntuación del parque.
#En caso contrario, mostrar un mensaje de que "este lugar no ha sido puntuado aún"

try:
    print(Park1["response"]["venue"]["rating"])
except:
    print("This venue has not been rated yet.")
# Out:
# 9.1

# %%
#Como podemos ver, el Parque tiene una puntuación notable, así que
#vamos a observar cuantas opiniones tiene el "Flushing Meadows Corona Park"

# %%
Park1["response"]["venue"]["tips"]["count"]
# Out:
# 84

# %%
#Una vez que hemos comprobado el número de opiniones que hay sobre este restaurante, vamos a leer
#uno de ellos

#Opinión del parque

limit=15 #Define los límites para que sean mayor o igual al total de consejos para ese restaurante
url=url = "https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}".format(venue_id, CLIENT_ID,
CLIENT_SECRET, VERSION, limit)

TipsPark1=requests.get(url).json()
TipsPark1
# Out:
# {'meta': {'code': 200, 'requestId': '5fc08b3fed02d54fbfa912cb'},
#  'response': {'tips': {'count': 85,
#    'items': [{'id': '5037ef7be4b0c8e15bfab788',
#      'createdAt': 1345843067,
#      'text': 'This is a great park, pretty spacious and this is the perfect time to go there and check out the tennis U.S. Open! It has great scenery such as the famous Unisphere that has been featured in movies!',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/5037ef7be4b0c8e15bfab788',
#      'lang': 'en',
#      'likes': {'count': 3,
#       'groups': [{'type': 'others',
#         'count': 3,
#         'items': [{'isSanctioned': False,
#           'firstName': 'Mirinha ¤',
#           'lastName': 'M',
#           'countryCode': 'US'},
#          {'isSanctioned': False, 'firstName': 'Justine', 'countryCode': 'US'},
#          {'isSanctioned': False,
#           'firstName': 'Archanna',
#           'lastName': 'D',
#           'countryCode': 'MY'}]}],
#       'summary': '3 likes'},
#      'logView': True,
#      'agreeCount': 14,
#      'disagreeCount': 0,
#      'lastVoteText': 'Upvoted Sep 26',
#      'lastUpvoteTimestamp': 1601146209,
#      'todo': {'count': 2},
#      'user': {'isSanctioned': False,
#       'firstName': 'New York Habitat',
#       'countryCode': 'US',
#       'type': 'chain'}}]}}}

# %%
#Vamos a conseguir extraer la opinión del parque
tips= TipsPark1["response"]["tips"]["items"]

tip = TipsPark1["response"]["tips"]["items"][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'lastVoteText', 'lastUpvoteTimestamp', 'todo', 'user'])

# %%
#Formatea el ancho de las columnas y visualiza el consejo
pd.set_option("display.max_colwidth",-1)

tips_df=pd.json_normalize(tips)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
filtered_columns =["text","agreeCount", "disagreeCount", "id"]
tips_filtered =tips_df.loc[:,filtered_columns]

# %%
#Muestra el consejo

tips_filtered.reindex()
# Out:
#                                                                                                                                                                                                      text  \
# 0  This is a great park, pretty spacious and this is the perfect time to go there and check out the tennis U.S. Open! It has great scenery such as the famous Unisphere that has been featured in movies!
#
#    agreeCount  disagreeCount                        id
# 0  14          0              5037ef7be4b0c8e15bfab788
